# %% [markdown]
# <a href="https://colab.research.google.com/github/DataAnalyticSscience/TextClassification/blob/main/Natural_Language_Processing_for_Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Natural Language Processing for Text Summarization

# %% [markdown]
# ### Natural Language Processing (NLP) for text summarization
# -----
#
# Natural Language Processing (NLP) for text summarization involves the use of computational techniques to understand, interpret, and generate concise and meaningful summaries of longer text documents. This process typically includes several key stages:
#
# 1. **Text Preprocessing:** Before summarizing, the text needs to be cleaned and prepared. This involves removing irrelevant data, normalizing text, and possibly parsing it into sentences or tokens.
# 2. **Understanding Context:** NLP models must understand the context and main ideas of the text. This is often achieved through techniques like Named Entity Recognition (NER), Part-of-Speech (POS) tagging, and dependency parsing.
# 3. **Feature Extraction:** The model identifies key features and important sentences or phrases. Techniques like TF-IDF (Term Frequency-Inverse Document Frequency) or newer neural network-based approaches are used for this purpose.
# 4. **Summarization Techniques:** There are two main types:
#   - Extractive Summarization: This method involves selecting and compiling key sentences from the original text to form a summary. It's simpler but may lack coherence.
#   - **Abstractive Summarization:** More complex, this method involves generating new sentences that capture the essence of the original text, often using advanced models like sequence-to-sequence neural networks.
# 5. **Refinement:** The generated summary is often refined for coherence, fluency, and conciseness. This might involve rephrasing or restructuring sentences.
# 6. **Evaluation:** The quality of the summary is evaluated using metrics like ROUGE (Recall-Oriented Understudy for Gisting Evaluation), which compares the generated summary with a human-written reference summary.
#
# Advancements in deep learning, especially models like BERT, GPT, and their variants, have significantly improved the quality of text summarization, making it more accurate and human-like. These technologies have wide applications, from news aggregation to generating executive reports from extensive documents.

# %% [markdown]
# ### Why NLP for text summarization analysis
# -----
#
# Conducting Natural Language Processing (NLP) for text summarization analysis is essential for several reasons, particularly in our current age of information overload:
#
# 1. **Efficiency in Information Handling:** With the vast amount of textual data available online and in corporate databases, it becomes impractical to read and comprehend everything. Text summarization can condense this information, allowing users to understand content quickly.
# 2. **Time-Saving:** Summarization significantly reduces the time required to get the gist of a document. This is especially valuable in sectors like legal, academic, and business, where professionals need to process large volumes of text daily.
# 3. **Enhanced Accessibility:** Summarization makes information more accessible. For instance, it can help people with reading difficulties, or those who are not fluent in a particular language, to understand the content more easily.
# 4. **Improved Decision Making:** In business and research, executives and scientists can make better-informed decisions when they can quickly access the summarized essence of extensive reports, research papers, or data analyses.
# 5. **Content Curation and Recommendation:** Summarization can be used to curate content tailored to individual preferences, enhancing user experience in apps and websites by providing brief overviews of articles, papers, or books.
# 6. **Knowledge Management and Retrieval:** Summarized texts can be more effectively indexed and retrieved, improving the functionality of search engines and knowledge management systems.
# 7. **Support for Automated Reporting:** In journalism, finance, and weather forecasting, among other fields, text summarization can aid in generating automated reports, saving time and resources.
# 8. **Educational Purposes:** Summarization tools can assist students and educators by providing concise summaries of educational material, aiding in study and revision.
# 9. **Language Processing Research:** Summarization challenges NLP technologies to comprehend and reproduce human language more effectively, driving advancements in AI and machine learning.
#
# By leveraging NLP for text summarization, organizations and individuals can manage, interpret, and utilize textual data more effectively, making informed decisions and staying informed in a fast-paced world.

# %% [markdown]
# ### Objective of this analysis
# -----
#
# In our analysis, we will employ advanced Natural Language Processing (NLP) techniques to meticulously extract and highlight the pivotal sentences from [Google's Q3 2023 earnings transcript](https://abc.xyz/2023-q3-earnings-call/). Our objective is to deeply analyze the transcript of this call, isolating and identifying the key statements made by the speakers. This meticulous approach can help unearth the most critical insights, with a particular focus on several significant areas:
#
# 1. **Investment Perspective for Google Stocks:** By pinpointing the most influential sentences, our analysis will provide valuable insights for investors, aiding them in making more informed decisions about investing in Google's stocks.
# 2. **Deciphering Google's Product Roadmap:** We will delve into the details of Google's strategic plans, shedding light on their most significant upcoming products and innovations. This will offer a clearer understanding of the company's future direction in technology and services.
# 3. **Forecasting Google's Future Earnings Potential:** Our analysis will also focus on extracting insights related to Google's future earnings potential, which is vital for investors, analysts, and the financial community.
#
# Upon the completion of the analysis of Google's earnings call, we will replicate this process to automatically dissect and elucidate the most salient points from [Snap, Inc.'s latest earnings transcript](https://s25.q4cdn.com/442043304/files/doc_financials/2023/q3/Snap-Inc-Q3-2023-Transcript.pdf). This will not only demonstrate the versatility and efficacy of our NLP methodology but also provide crucial insights into another major tech player's performance and strategies.

# %% [markdown]
# ## Install and import requisite packages

# %%
# !pip install goose3

# %%
import re # relugar expression
import nltk # natural language toolkit
import string
from goose3 import Goose
import heapq
from IPython.core.display import HTML

# Tokenization
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# Removing Stop Words
nltk.download('stopwords')
from nltk.corpus import stopwords

# Stemming and Lemmatization
nltk.download('wordnet')
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Frequency Distribution of the Words
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
url = 'https://abc.xyz/2023-q3-earnings-call/'
g = Goose()
data = g.extract(url)

# %%
data.cleaned_text
# Out:
# 'For a PDF version of the transcript, please click here.\n\nThank you for standing by for the Alphabet third quarter 2023 earnings conference call. At this time, all participants are in listen-only mode. After the speaker presentation, there will be a question-and-answer session. To ask a question during the session, you will need to press *1 on your telephone. I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations. Please go ahead.\n\nGood afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call. With us today are Sundar Pichai, Philipp Schindler and Ruth Porat. Now I’ll quickly cover the Safe Harbor.\n\nSome of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking. Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.\n\nActual results could differ materially. Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs. We undertake no obligation to update any forward-looking statement.\n\nDuring this call, we will present both GAAP and non-GAAP financial measures. A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.\n\nOur comments will be on year-over-year comparisons unless we state otherwise. And now I’ll turn the call over to Sundar.\n\nSundar Pichai, CEO Alphabet and Google: Thank you, Jim. And hello, everyone.\n\nI’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.\n\nGoogle turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.\n\nOur product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google. It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.\n\nFirst, improving knowledge and learning. This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.\n\nWe’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery. We’ve also made it easier to understand and debug generated code.\n\nDirect user feedback has been positive, with strong growth in adoption.\n\nIn August, we opened up availability to India and Japan, with more countries and languages to come.\n\nAs we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.\n\nWith generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.\n\nWe are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.\n\nOf course, ads will continue to play an important role in this new Search experience. People are finding ads helpful here, as they provide useful options to take action and connect with businesses.\n\nWe’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.\n\nThe second area we are focused on is boosting creativity and productivity. Bard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early experiment and complem ...

# %%
data.title
# Out:
# '2023 Q3 Earnings Call'

# %% [markdown]
# ## Preprocessing the texts

# %% [markdown]
# ### Format the text for analysis
#
# **If you're starting directly from `data.cleaned_text`:**
#
# This approach is suitable if the text is not split into sentences yet. You might replace full stops with full stops plus newline characters. However, be cautious as this can sometimes break sentences incorrectly (e.g., after abbreviations or decimal numbers).

# %%
original_text = data.cleaned_text.replace('. ', '.\n')

# %%
# Let's preview the text / data
original_text
# Out:
# 'For a PDF version of the transcript, please click here.\n\nThank you for standing by for the Alphabet third quarter 2023 earnings conference call.\nAt this time, all participants are in listen-only mode.\nAfter the speaker presentation, there will be a question-and-answer session.\nTo ask a question during the session, you will need to press *1 on your telephone.\nI would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations.\nPlease go ahead.\n\nGood afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call.\nWith us today are Sundar Pichai, Philipp Schindler and Ruth Porat.\nNow I’ll quickly cover the Safe Harbor.\n\nSome of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking.\nSuch statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.\n\nActual results could differ materially.\nPlease refer to our Form 10-K, including our risk factor section and our Form 10-Qs.\nWe undertake no obligation to update any forward-looking statement.\n\nDuring this call, we will present both GAAP and non-GAAP financial measures.\nA reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.\n\nOur comments will be on year-over-year comparisons unless we state otherwise.\nAnd now I’ll turn the call over to Sundar.\n\nSundar Pichai, CEO Alphabet and Google: Thank you, Jim.\nAnd hello, everyone.\n\nI’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.\n\nGoogle turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.\n\nOur product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google.\nIt’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.\n\nFirst, improving knowledge and learning.\nThis includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.\n\nWe’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery.\nWe’ve also made it easier to understand and debug generated code.\n\nDirect user feedback has been positive, with strong growth in adoption.\n\nIn August, we opened up availability to India and Japan, with more countries and languages to come.\n\nAs we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.\n\nWith generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.\n\nWe are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.\n\nOf course, ads will continue to play an important role in this new Search experience.\nPeople are finding ads helpful here, as they provide useful options to take action and connect with businesses.\n\nWe’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.\n\nThe second area we are focused on is boosting creativity and productivity.\nBard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early expe ...

# %% [markdown]
# ### Step 1: Text Normalization
# This step involves converting all text to lowercase for uniformity and removing punctuation, including newline characters, to clean the text.

# %%
# these are the types of punctuations to be removed
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Convert to lowercase
text = original_text.lower()

# Remove punctuation using translate
text = text.translate(str.maketrans('', '', string.punctuation))

# Remove special characters and extra spaces/newlines using regex
text = re.sub(r'[^\w\s]', '', text)
text = re.sub(r'\s+', ' ', text)

# %%
text
# Out:
# 'for a pdf version of the transcript please click here thank you for standing by for the alphabet third quarter 2023 earnings conference call at this time all participants are in listenonly mode after the speaker presentation there will be a questionandanswer session to ask a question during the session you will need to press 1 on your telephone i would now like to hand the conference over to your speaker today jim friedland director of investor relations please go ahead good afternoon everyone and welcome to alphabets third quarter 2023 earnings conference call with us today are sundar pichai philipp schindler and ruth porat now ill quickly cover the safe harbor some of the statements that we make today regarding our business operations and financial performance may be considered forwardlooking such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties actual results could differ materially please refer to our form 10k including our risk factor section and our form 10qs we undertake no obligation to update any forwardlooking statement during this call we will present both gaap and nongaap financial measures a reconciliation of nongaap to gaap measures is included in todays earnings press release which is distributed and available to the public through our investor relations website located at abcxyzinvestor our comments will be on yearoveryear comparisons unless we state otherwise and now ill turn the call over to sundar sundar pichai ceo alphabet and google thank you jim and hello everyone im pleased with our business results this quarter which demonstrate strong growth in search and youtube and momentum in cloud google turned 25 in september which offered an opportunity to reflect on our progress over the last quarter century and to look ahead to the opportunities enabled by ai we are so excited and confident about our product momentum continued this quarter as you saw with cloud next made on youtube and made by google its all part of our focus on making ai more helpful for everyone and we are making good progress across the four areas that we shared last quarter first improving knowledge and learning this includes our work with the search generative experience which is our experiment to bring generative ai capabilities into search weve learned a lot from people trying it and weve added new capabilities like incorporating videos and images into responses and generating imagery weve also made it easier to understand and debug generated code direct user feedback has been positive with strong growth in adoption in august we opened up availability to india and japan with more countries and languages to come as we add features and expand into new markets were engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users send valuable traffic to publishers and support a healthy open internet with generative ai applied to search we can serve a wider range of information needs and answer new types of questions including those that benefit from multiple perspectives we are surfacing more links with sge and linking to a wider range of sources on the results page creating new opportunities for content to be discovered of course ads will continue to play an important role in this new search experience people are finding ads helpful here as they provide useful options to take action and connect with businesses well experiment with new formats native to sge that use generative ai to create relevant highquality ads customized to every step of the search journey the second area we are focused on is boosting creativity and productivity bard is particularly helpful here its a direct interface to a conversational llm and we think of it as an early experiment and complementary experience to google search bard can now integrate with google apps and services showing relevant information from workspace maps youtube and google flights and h ...

# %% [markdown]
# ### Step 2: Tokenization
# In this step, the normalized text is split into individual words or tokens. This is crucial for many NLP tasks as it breaks down the text into manageable units for analysis.

# %%
# Tokenize the text
tokens = word_tokenize(text)

# %% [markdown]
# ### Step 3: Removing Stop Words
# Stop words (like 'and', 'the', 'is') are removed here. These words are usually filtered out because they occur frequently and don't carry significant meaning for most analysis.

# %%
# Define stop words
# stop_words = set(stopwords.words('english'))
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Filter out stop words from tokens
filtered_tokens = [word for word in tokens if word not in stopwords]

# %%
len(stopwords)
# Out:
# 179

# %% [markdown]
# ### Step 4: Stemming and Lemmatization
# This step involves reducing words to their base or root form through stemming and lemmatization. This helps in standardizing words to their core meaning.

# %%
# Initialize stemmer and lemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
# Apply stemming and lemmatization
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

# %%
# Print the processed tokens
print("Stemmed Tokens:", stemmed_tokens)
print("Lemmatized Tokens:", lemmatized_tokens)
# Out:
# Stemmed Tokens: ['pdf', 'version', 'transcript', 'pleas', 'click', 'thank', 'stand', 'alphabet', 'third', 'quarter', '2023', 'earn', 'confer', 'call', 'time', 'particip', 'listenonli', 'mode', 'speaker', 'present', 'questionandansw', 'session', 'ask', 'question', 'session', 'need', 'press', '1', 'telephon', 'would', 'like', 'hand', 'confer', 'speaker', 'today', 'jim', 'friedland', 'director', 'investor', 'relat', 'pleas', 'go', 'ahead', 'good', 'afternoon', 'everyon', 'welcom', 'alphabet', 'third', 'quarter', '2023', 'earn', 'confer', 'call', 'us', 'today', 'sundar', 'pichai', 'philipp', 'schindler', 'ruth', 'porat', 'ill', 'quickli', 'cover', 'safe', 'harbor', 'statement', 'make', 'today', 'regard', 'busi', 'oper', 'financi', 'perform', 'may', 'consid', 'forwardlook', 'statement', 'base', 'current', 'expect', 'assumpt', 'subject', 'number', 'risk', 'uncertainti', 'actual', 'result', 'could', 'differ', 'materi', 'pleas', 'refer', 'form', '10k', 'includ', 'risk', 'factor', 'section', 'form', '10q', 'undertak', 'oblig', 'updat', 'forwardlook', 'statement', 'call', 'present', 'gaap', 'nongaap', 'financi', 'measur', 'reconcili', 'nongaap', 'gaap', 'measur', 'includ', 'today', 'earn', 'press', 'releas', 'distribut', 'avail', 'public', 'investor', 'relat', 'websit', 'locat', 'abcxyzinvestor', 'comment', 'yearoveryear', 'comparison', 'unless', 'state', 'otherwis', 'ill', 'turn', 'call', 'sundar', 'sundar', 'pichai', 'ceo', 'alphabet', 'googl', 'thank', 'jim', 'hello', 'everyon', 'im', 'pleas', 'busi', 'result', 'quarter', 'demonstr', 'strong', 'growth', 'search', 'youtub', 'momentum', 'cloud', 'googl', 'turn', '25', 'septemb', 'offer', 'opportun', 'reflect', 'progress', 'last', 'quarter', 'centuri', 'look', 'ahead', 'opportun', 'enabl', 'ai', 'excit', 'confid', 'product', 'momentum', 'continu', 'quarter', 'saw', 'cloud', 'next', 'made', 'youtub', 'made', 'googl', 'part', 'focu', 'make', 'ai', 'help', 'everyon', 'make', 'good', 'progress', 'across', 'four', 'area', 'share', 'last', 'quarter', 'first', 'improv', 'knowledg', 'learn', 'includ', 'work', 'search', 'gener', 'experi', 'experi', 'bring', 'gener', 'ai', 'capabl', 'search', 'weve', 'learn', 'lot', 'peopl', 'tri', 'weve', 'ad', 'new', 'capabl', 'like', 'incorpor', 'video', 'imag', 'respons', 'gener', 'imageri', 'weve', 'also', 'made', 'easier', 'understand', 'debug', 'gener', 'code', 'direct', 'user', 'feedback', 'posit', 'strong', 'growth', 'adopt', 'august', 'open', 'avail', 'india', 'japan', 'countri', 'languag', 'come', 'add', 'featur', 'expand', 'new', 'market', 'engag', 'broader', 'ecosystem', 'continu', 'priorit', 'approach', 'add', 'valu', 'user', 'send', 'valuabl', 'traffic', 'publish', 'support', 'healthi', 'open', 'internet', 'gener', 'ai', 'appli', 'search', 'serv', 'wider', 'rang', 'inform', 'need', 'answer', 'new', 'type', 'question', 'includ', 'benefit', 'multipl', 'perspect', 'surfac', 'link', 'sge', 'link', 'wider', 'rang', 'sourc', 'result', 'page', 'creat', 'new', 'opportun', 'content', 'discov', 'cours', 'ad', 'continu', 'play', 'import', 'role', 'new', 'search', 'experi', 'peopl', 'find', 'ad', 'help', 'provid', 'use', 'option', 'take', 'action', 'connect', 'busi', 'well', 'experi', 'new', 'format', 'nativ', 'sge', 'use', 'gener', 'ai', 'creat', 'relev', 'highqual', 'ad', 'custom', 'everi', 'step', 'search', 'journey', 'second', 'area', 'focus', 'boost', 'creativ', 'product', 'bard', 'particularli', 'help', 'direct', 'interfac', 'convers', 'llm', 'think', 'earli', 'experi', 'complementari', 'experi', 'googl', 'search', 'bard', 'integr', 'googl', 'app', 'servic', 'show', 'relev', 'inform', 'workspac', 'map', 'youtub', 'googl', 'flight', 'hotel', 'weve', 'also', 'improv', 'googl', 'featur', 'provid', 'sourc', 'help', 'peopl', 'evalu', 'bard', 'respons', 'explor', 'inform', 'across', 'web', 'earlier', 'month', 'announc', 'assist', 'bard', 'person', 'assist', 'power', 'gener', 'ai', 'combin', 'bard', 'gener', 'reason', 'capabl', 'assist', 'person', 'help', 'inte ...
# Lemmatized Tokens: ['pdf', 'version', 'transcript', 'please', 'click', 'thank', 'standing', 'alphabet', 'third', 'quarter', '2023', 'earnings', 'conference', 'call', 'time', 'participant', 'listenonly', 'mode', 'speaker', 'presentation', 'questionandanswer', 'session', 'ask', 'question', 'session', 'need', 'press', '1', 'telephone', 'would', 'like', 'hand', 'conference', 'speaker', 'today', 'jim', 'friedland', 'director', 'investor', 'relation', 'please', 'go', 'ahead', 'good', 'afternoon', 'everyone', 'welcome', 'alphabet', 'third', 'quarter', '2023', 'earnings', 'conference', 'call', 'u', 'today', 'sundar', 'pichai', 'philipp', 'schindler', 'ruth', 'porat', 'ill', 'quickly', 'cover', 'safe', 'harbor', 'statement', 'make', 'today', 'regarding', 'business', 'operation', 'financial', 'performance', 'may', 'considered', 'forwardlooking', 'statement', 'based', 'current', 'expectation', 'assumption', 'subject', 'number', 'risk', 'uncertainty', 'actual', 'result', 'could', 'differ', 'materially', 'please', 'refer', 'form', '10k', 'including', 'risk', 'factor', 'section', 'form', '10qs', 'undertake', 'obligation', 'update', 'forwardlooking', 'statement', 'call', 'present', 'gaap', 'nongaap', 'financial', 'measure', 'reconciliation', 'nongaap', 'gaap', 'measure', 'included', 'today', 'earnings', 'press', 'release', 'distributed', 'available', 'public', 'investor', 'relation', 'website', 'located', 'abcxyzinvestor', 'comment', 'yearoveryear', 'comparison', 'unless', 'state', 'otherwise', 'ill', 'turn', 'call', 'sundar', 'sundar', 'pichai', 'ceo', 'alphabet', 'google', 'thank', 'jim', 'hello', 'everyone', 'im', 'pleased', 'business', 'result', 'quarter', 'demonstrate', 'strong', 'growth', 'search', 'youtube', 'momentum', 'cloud', 'google', 'turned', '25', 'september', 'offered', 'opportunity', 'reflect', 'progress', 'last', 'quarter', 'century', 'look', 'ahead', 'opportunity', 'enabled', 'ai', 'excited', 'confident', 'product', 'momentum', 'continued', 'quarter', 'saw', 'cloud', 'next', 'made', 'youtube', 'made', 'google', 'part', 'focus', 'making', 'ai', 'helpful', 'everyone', 'making', 'good', 'progress', 'across', 'four', 'area', 'shared', 'last', 'quarter', 'first', 'improving', 'knowledge', 'learning', 'includes', 'work', 'search', 'generative', 'experience', 'experiment', 'bring', 'generative', 'ai', 'capability', 'search', 'weve', 'learned', 'lot', 'people', 'trying', 'weve', 'added', 'new', 'capability', 'like', 'incorporating', 'video', 'image', 'response', 'generating', 'imagery', 'weve', 'also', 'made', 'easier', 'understand', 'debug', 'generated', 'code', 'direct', 'user', 'feedback', 'positive', 'strong', 'growth', 'adoption', 'august', 'opened', 'availability', 'india', 'japan', 'country', 'language', 'come', 'add', 'feature', 'expand', 'new', 'market', 'engaging', 'broader', 'ecosystem', 'continue', 'prioritize', 'approach', 'add', 'value', 'user', 'send', 'valuable', 'traffic', 'publisher', 'support', 'healthy', 'open', 'internet', 'generative', 'ai', 'applied', 'search', 'serve', 'wider', 'range', 'information', 'need', 'answer', 'new', 'type', 'question', 'including', 'benefit', 'multiple', 'perspective', 'surfacing', 'link', 'sge', 'linking', 'wider', 'range', 'source', 'result', 'page', 'creating', 'new', 'opportunity', 'content', 'discovered', 'course', 'ad', 'continue', 'play', 'important', 'role', 'new', 'search', 'experience', 'people', 'finding', 'ad', 'helpful', 'provide', 'useful', 'option', 'take', 'action', 'connect', 'business', 'well', 'experiment', 'new', 'format', 'native', 'sge', 'use', 'generative', 'ai', 'create', 'relevant', 'highquality', 'ad', 'customized', 'every', 'step', 'search', 'journey', 'second', 'area', 'focused', 'boosting', 'creativity', 'productivity', 'bard', 'particularly', 'helpful', 'direct', 'interface', 'conversational', 'llm', 'think', 'early', 'experiment', 'complementary', 'experience', 'google', 'search', 'bard', 'integrate', 'google', 'apps', 'service', 'showing', 'relevant' ...

# %% [markdown]
# ### Step 5: Reassembling Processed Tokens into Formatted Text
# After preprocessing the text, including tokenization, stop word removal, and stemming or lemmatization, this step combines the processed tokens back into a single string. This helps in visualizing the result of preprocessing as a readable text.

# %%
# Reassembling Processed Tokens into Formatted Text

# Using lemmatized tokens for reassembly
formatted_text = ' '.join(lemmatized_tokens)

# Print the formatted text
formatted_text
# Out:
# 'pdf version transcript please click thank standing alphabet third quarter 2023 earnings conference call time participant listenonly mode speaker presentation questionandanswer session ask question session need press 1 telephone would like hand conference speaker today jim friedland director investor relation please go ahead good afternoon everyone welcome alphabet third quarter 2023 earnings conference call u today sundar pichai philipp schindler ruth porat ill quickly cover safe harbor statement make today regarding business operation financial performance may considered forwardlooking statement based current expectation assumption subject number risk uncertainty actual result could differ materially please refer form 10k including risk factor section form 10qs undertake obligation update forwardlooking statement call present gaap nongaap financial measure reconciliation nongaap gaap measure included today earnings press release distributed available public investor relation website located abcxyzinvestor comment yearoveryear comparison unless state otherwise ill turn call sundar sundar pichai ceo alphabet google thank jim hello everyone im pleased business result quarter demonstrate strong growth search youtube momentum cloud google turned 25 september offered opportunity reflect progress last quarter century look ahead opportunity enabled ai excited confident product momentum continued quarter saw cloud next made youtube made google part focus making ai helpful everyone making good progress across four area shared last quarter first improving knowledge learning includes work search generative experience experiment bring generative ai capability search weve learned lot people trying weve added new capability like incorporating video image response generating imagery weve also made easier understand debug generated code direct user feedback positive strong growth adoption august opened availability india japan country language come add feature expand new market engaging broader ecosystem continue prioritize approach add value user send valuable traffic publisher support healthy open internet generative ai applied search serve wider range information need answer new type question including benefit multiple perspective surfacing link sge linking wider range source result page creating new opportunity content discovered course ad continue play important role new search experience people finding ad helpful provide useful option take action connect business well experiment new format native sge use generative ai create relevant highquality ad customized every step search journey second area focused boosting creativity productivity bard particularly helpful direct interface conversational llm think early experiment complementary experience google search bard integrate google apps service showing relevant information workspace map youtube google flight hotel weve also improved google feature provides source help people evaluate bard response explore information across web earlier month announced assistant bard personal assistant powered generative ai combine bard generative reasoning capability assistant personalized help interact text voice image coming month youll able opt android io mobile device collaborative tool workspace youtube also part boost creativity productivity seeing great initial traction third enabling developer business organization build transformative product service example thousand customer partner already using google cloud capture potential ai well share minute fourth building deploying ai responsibly everyone benefit one area focused making sure people easily identify encountering aigenerated content online using new technology powered google deepmind synthid image generated vertex ai watermarked way invisible human eye without reducing image quality underlying work foundational research done team google deepmind google research excited roll theyve working soon expand access new ai service continue make mea ...

# %% [markdown]
# ## Word frequency
#
# Moving to the phase of analyzing word frequency, we'll focus on several key aspects. These steps will help us understand the distribution of words in the text, identify the most frequent words, and evaluate their relative importance based on frequency. Let's break down each step:

# %% [markdown]
# ### Step 1: Frequency Distribution of the Words
# Here, we'll calculate how often each word appears in the text.

# %%
# word_frequency = nltk.FreqDist(nltk.word_tokenize(formatted_text))
# word_frequency

# %%
# Frequency Distribution of the Words

# Assuming 'lemmatized_tokens' is the list of words after preprocessing
freq_dist = FreqDist(lemmatized_tokens)

# Create a dictionary from the frequency distribution
word_freq_dict = dict(freq_dist)

# (Optional) Display the frequency distribution
for word, frequency in freq_dist.items():
    print(word, ":", frequency)
# Out:
# pdf : 1
# version : 1
# transcript : 1
# please : 5
# click : 1
# thank : 20
# standing : 1
# alphabet : 19
# third : 19
# quarter : 43
# 2023 : 6
# earnings : 6
# conference : 5
# call : 10
# time : 6
# participant : 1
# listenonly : 1
# mode : 3
# speaker : 2
# presentation : 1
# questionandanswer : 2
# session : 3
# ask : 4
# question : 34
# need : 5
# press : 3
# 1 : 3
# telephone : 2
# would : 10
# like : 16
# hand : 1
# today : 10
# jim : 4
# friedland : 3
# director : 2
# investor : 4
# relation : 3
# go : 3
# ahead : 9
# good : 8
# afternoon : 1
# everyone : 7
# welcome : 1
# u : 11
# sundar : 18
# pichai : 7
# philipp : 9
# schindler : 5
# ruth : 12
# porat : 6
# ill : 6
# quickly : 3
# cover : 1
# safe : 1
# harbor : 1
# statement : 3
# make : 10
# regarding : 2
# business : 15
# operation : 6
# financial : 6
# performance : 10
# may : 3
# considered : 1
# forwardlooking : 2
# based : 3
# current : 2
# expectation : 3
# assumption : 1
# subject : 1
# number : 15
# risk : 2
# uncertainty : 1
# actual : 1
# result : 15
# could : 8
# differ : 1
# materially : 1
# refer : 1
# form : 2
# 10k : 1
# including : 11
# factor : 3
# section : 1
# 10qs : 1
# undertake : 1
# obligation : 1
# update : 4
# present : 2
# gaap : 2
# nongaap : 2
# measure : 3
# reconciliation : 1
# included : 1
# release : 4
# distributed : 1
# available : 5
# public : 1
# website : 1
# located : 1
# abcxyzinvestor : 1
# comment : 5
# yearoveryear : 2
# comparison : 2
# unless : 2
# state : 2
# otherwise : 2
# turn : 2
# ceo : 6
# google : 63
# hello : 1
# im : 8
# pleased : 11
# demonstrate : 1
# strong : 7
# growth : 37
# search : 30
# youtube : 36
# momentum : 5
# cloud : 26
# turned : 1
# 25 : 3
# september : 4
# offered : 1
# opportunity : 18
# reflect : 3
# progress : 8
# last : 9
# century : 1
# look : 8
# enabled : 1
# ai : 62
# excited : 8
# confident : 1
# product : 25
# continued : 5
# saw : 2
# next : 13
# made : 7
# part : 10
# focus : 4
# making : 7
# helpful : 5
# across : 31
# four : 2
# area : 6
# shared : 3
# first : 20
# improving : 3
# knowledge : 1
# learning : 1
# includes : 2
# work : 13
# generative : 12
# experience : 19
# experiment : 5
# bring : 1
# capability : 8
# weve : 16
# learned : 2
# lot : 9
# people : 18
# trying : 3
# added : 1
# new : 33
# incorporating : 1
# video : 9
# image : 10
# response : 5
# generating : 2
# imagery : 2
# also : 18
# easier : 2
# understand : 2
# debug : 1
# generated : 2
# code : 1
# direct : 5
# user : 16
# feedback : 11
# positive : 6
# adoption : 2
# august : 1
# opened : 1
# availability : 1
# india : 1
# japan : 1
# country : 2
# language : 2
# come : 13
# add : 5
# feature : 12
# expand : 4
# market : 3
# engaging : 3
# broader : 5
# ecosystem : 5
# continue : 16
# prioritize : 1
# approach : 1
# value : 7
# send : 1
# valuable : 1
# traffic : 1
# publisher : 1
# support : 10
# healthy : 2
# open : 10
# internet : 1
# applied : 1
# serve : 2
# wider : 2
# range : 3
# information : 8
# answer : 2
# type : 2
# benefit : 3
# multiple : 5
# perspective : 1
# surfacing : 1
# link : 1
# sge : 7
# linking : 1
# source : 3
# page : 1
# creating : 4
# content : 10
# discovered : 1
# course : 2
# ad : 21
# play : 2
# important : 5
# role : 1
# finding : 2
# provide : 6
# useful : 2
# option : 3
# take : 9
# action : 4
# connect : 3
# well : 25
# format : 3
# native : 1
# use : 8
# create : 10
# relevant : 2
# highquality : 1
# customized : 1
# every : 4
# step : 1
# journey : 3
# second : 18
# focused : 9
# boosting : 1
# creativity : 2
# productivity : 4
# bard : 7
# particularly : 2
# interface : 1
# conversational : 2
# llm : 2
# think : 21
# early : 7
# complementary : 1
# integrate : 1
# apps : 2
# service : 13
# showing : 1
# workspace : 7
# map : 1
# flight : 1
# hotel : 1
# improved : 1
# provides : 3
# help : 10
# evaluate : 1
# explore : 1
# web : 3
# earlier : 4
# month : 7
# announced : 4
# assistant : 5
# personal : 1
# powered : 5
# combine : 3
# reasoning : 1
# personalized : 2
# interact : 1
# text : 2
# voice : 1
# coming : 2
# youll : 1
# able : 2
# opt : 1
# android : 4
# io : 1
# mobile : 6
# device : 1
# collaborative : 1
# tool : 9
# boost : 3
# seeing : 9
# great : 12
# initial : 1
# traction : 1
# enabling : 2
# developer : 5
# organization : 2
# build : 6
# transformative : 2
# example : 7
# thousand : 2
# customer : 20
# partner : 7
# already : 4
# using : 8
# capture : 1
# potential : 4
# share : 3
# minute : 1
# fourth : 9
# building : 1
# deploying : 1
# responsibly : 1
# one : 20
# sure : 4
# easily : 1
# identify : 3
# encountering : 1
# aigenerated : 2
# online : 2
# technology : 4
# deepmind : 3
# synthid : 1
# vertex : 5
# watermarked : 1
# way : 14
# invisible : 1
# human : 1
# eye : 1
# without : 2
# reducing : 1
# quality : 1
# underlying : 1
# foundational : 4
# research : 4
# done : 4
# team : 10
# roll : 1
# theyve : 2
# working : 7
# soon : 1
# access : 3
# meaningful : 3
# investment : 19
# effort : 5
# remain : 6
# committed : 3
# durably : 3
# reengineering : 3
# cost : 16
# base : 5
# order : 1
# capacity : 2
# longterm : 3
# sustainable : 3
# looking : 7
# operate : 2
# effectively : 2
# possible : 9
# biggest : 1
# priority : 4
# turning : 6
# solid : 3
# subscription : 9
# q3 : 7
# nfl : 7
# sunday : 9
# ticket : 9
# live : 2
# receiving : 1
# excellent : 2
# review : 2
# fan : 3
# love : 4
# multiview : 4
# livestream : 3
# game : 2
# single : 1
# screen : 5
# heard : 2
# reliability : 2
# clear : 5
# ability : 7
# execute : 2
# big : 3
# partnership : 3
# excellence : 2
# scale : 9
# really : 19
# engagement : 5
# short : 10
# closing : 2
# monetization : 4
# gap : 1
# average : 4
# 70 : 1
# billion : 25
# daily : 1
# view : 8
# watched : 1
# 2 : 2
# signedin : 1
# dream : 2
# experimental : 1
# allows : 1
# creator : 3
# background : 2
# app : 1
# suite : 2
# production : 1
# editing : 2
# longer : 2
# see : 14
# revenue : 34
# 84 : 2
# 22 : 2
# 60 : 1
# world : 6
# thousandlargest : 1
# company : 6
# showcased : 1
# amazing : 1
# innovation : 6
# entire : 1
# portfolio : 6
# infrastructure : 12
# data : 8
# collaboration : 3
# cybersecurity : 2
# solution : 5
# offer : 3
# advanced : 1
# aioptimized : 1
# train : 1
# model : 12
# half : 2
# funded : 1
# startup : 1
# ai21 : 1
# lab : 1
# contextual : 1
# elemental : 1
# cognition : 1
# writer : 1
# widest : 1
# choice : 2
# accelerator : 2
# a3 : 1
# vms : 1
# nvidias : 1
# h100 : 1
# gpu : 1
# generally : 3
# winning : 1
# tpu : 1
# v5e : 1
# costefficient : 1
# versatile : 1
# date : 2
# top : 5
# platform : 5
# deploy : 1
# aipowered : 6
# application : 3
# 100 : 1
# popular : 1
# thirdparty : 6
# opensource : 1
# conversation : 1
# case : 3
# q2 : 1
# active : 1
# project : 3
# grew : 4
# 7x : 2
# highmark : 1
# health : 1
# member : 1
# material : 1
# duet : 5
# created : 1
# leading : 4
# large : 2
# foundation : 4
# specially : 1
# trained : 1
# productive : 1
# expanding : 2
# integrating : 1
# wide : 1
# helping : 7
# brand : 11
# paypal : 1
# deutsche : 1
# bank : 4
# retailer : 5
# aritzia : 1
# gymshark : 1
# gain : 1
# insight : 2
# better : 4
# faster : 2
# fact : 1
# increasingly : 1
# purpose : 1
# analyzing : 1
# choosing : 1
# provider : 2
# unified : 1
# analyze : 1
# structured : 1
# unstructured : 1
# million : 7
# trusted : 2
# tester : 2
# used : 1
# writing : 2
# refining : 2
# gmail : 1
# doc : 1
# original : 1
# within : 4
# slide : 1
# organizing : 1
# sheet : 1
# enable : 3
# grow : 5
# 10 : 2
# paying : 1
# enterprise : 1
# grupo : 1
# boticario : 1
# unilever : 1
# warner : 1
# music : 3
# integrated : 2
# differentiate : 2
# marketplace : 1
# providing : 2
# assistance : 1
# mandiant : 1
# threat : 1
# intelligence : 2
# chronicle : 1
# security : 7
# command : 1
# center : 4
# reduces : 1
# spend : 3
# running : 1
# seven : 1
# frontline : 1
# expertise : 1
# modern : 1
# infused : 1
# protect : 1
# bt : 1
# jack : 1
# henry : 1
# associate : 1
# covermymeds : 1
# hardware : 4
# unveiled : 1
# introduced : 1
# pixel : 10
# 8 : 6
# pro : 2
# watch : 4
# consumer : 5
# fastestgrowing : 1
# smartphone : 1
# unit : 1
# sold : 1
# year : 15
# brought : 1
# life : 3
# thanks : 12
# combination : 2
# tensor : 2
# g3 : 1
# generation : 3
# tailorbuilt : 1
# chip : 2
# designed : 2
# power : 2
# bringing : 3
# latest : 1
# directly : 2
# newest : 1
# phone : 1
# photo : 1
# remove : 1
# distraction : 1
# generate : 2
# best : 8
# shot : 1
# reduce : 2
# distracting : 1
# sound : 1
# released : 1
# 14 : 1
# accessibility : 1
# want : 6
# mention : 1
# chromebooks : 2
# plus : 1
# category : 1
# chrome : 6
# builtin : 1
# powerful : 1
# get : 7
# regular : 2
# automatic : 1
# operating : 10
# system : 1
# bet : 3
# waymo : 1
# onboarding : 1
# rider : 1
# commercial : 1
# ridehailing : 1
# gradually : 1
# 100000 : 1
# san : 1
# francisco : 1
# waitlist : 1
# austin : 1
# follow : 1
# ridehail : 1
# city : 1
# wing : 1
# walmart : 1
# drone : 1
# delivery : 1
# dallasfort : 1
# worth : 2
# handing : 1
# employee : 1
# around : 8
# innovative : 1
# svp : 3
# cbo : 3
# hi : 1
# start : 5
# give : 6
# color : 2
# three : 2
# key : 2
# retail : 6
# identified : 1
# past : 2
# advertising : 14
# 68 : 2
# 11 : 5
# yearonyear : 8
# led : 4
# vertical : 1
# 12 : 4
# driven : 11
# network : 2
# declined : 1
# 3 : 4
# 21 : 2
# let : 4
# recent : 1
# dramatic : 1
# advance : 1
# everything : 2
# deliver : 5
# profitability : 2
# advertiser : 12
# delightful : 1
# covered : 2
# many : 12
# gml : 2
# significant : 5
# max : 3
# campaign : 6
# demand : 4
# gen : 6
# said : 6
# continuing : 4
# extremely : 1
# still : 7
# reach : 3
# along : 2
# highlight : 2
# innovating : 1
# doubleclick : 1
# core : 1
# dollar : 1
# count : 1
# proven : 1
# pmax : 4
# drive : 3
# reliable : 1
# roi : 4
# meet : 1
# wherever : 1
# funnel : 3
# started : 7
# prepping : 1
# long : 1
# holiday : 5
# season : 5
# theme : 1
# maximum : 3
# day : 3
# thanksgiving : 1
# christmas : 1
# micropeaks : 1
# beyond : 1
# cyber : 1
# 5 : 1
# arming : 1
# planning : 1
# optiscore : 1
# planner : 1
# uncover : 1
# plan : 3
# budget : 2
# target : 1
# stay : 2
# competitive : 1
# smarter : 1
# inventory : 3
# pricing : 1
# strategy : 3
# two : 8
# shifting : 2
# especially : 1
# price : 2
# convenience : 1
# seen : 6
# 4x : 1
# deal : 4
# query : 1
# versus : 6
# period : 3
# 75 : 1
# say : 4
# theyll : 1
# shop : 1
# offering : 4
# free : 6
# shipping : 1
# capitalizing : 1
# trend : 2
# differentiated : 1
# merchant : 4
# promotion : 1
# fulfillment : 1
# improvement : 2
# significantly : 1
# shown : 1
# shopper : 2
# browse : 1
# surprise : 1
# omnichannel : 1
# succeed : 1
# omniproduct : 1
# local : 2
# omnibidding : 1
# store : 2
# goal : 4
# small : 1
# capturing : 1
# incremental : 2
# highvalue : 1
# continues : 1
# shopping : 1
# virtual : 2
# tryon : 2
# apparel : 1
# launched : 5
# june : 1
# hit : 1
# engage : 2
# higher : 5
# rate : 7
# brandprovided : 1
# studio : 1
# another : 2
# launch : 4
# getting : 6
# pilot : 1
# us : 2
# unique : 1
# tailored : 1
# channel : 1
# seasonalize : 1
# shift : 2
# repeating : 1
# intense : 1
# success : 2
# coupled : 1
# multiformat : 1
# youtubes : 2
# connected : 2
# tv : 5
# driver : 2
# investing : 3
# solidify : 1
# position : 1
# place : 6
# mentioned : 2
# watchtime : 2
# overall : 13
# streaming : 1
# destination : 1
# according : 1
# nielsen : 1
# 150 : 2
# watching : 1
# ctv : 1
# whether : 2
# movie : 1
# continuous : 1
# stream : 3
# mrbeast : 1
# creatorled : 1
# viewer : 2
# variety : 1
# giving : 1
# moment : 5
# awesome : 2
# creation : 3
# wonder : 1
# storytelling : 1
# talked : 7
# autodub : 1
# flip : 1
# trim : 1
# existing : 1
# asset : 2
# remix : 1
# clip : 2
# break : 1
# speed : 1
# spotlight : 1
# week : 4
# trending : 1
# major : 1
# cultural : 1
# sponsorship : 1
# there : 6
# infeed : 2
# november : 1
# find : 2
# ideal : 1
# audience : 1
# lowest : 2
# test : 1
# delivering : 3
# 54 : 1
# 42 : 1
# lower : 1
# serving : 2
# skippable : 1
# instream : 2
# earn : 1
# far : 4
# theyre : 4
# driving : 5
# 40 : 1
# alone : 2
# feedbased : 1
# surface : 1
# april : 2
# rolled : 2
# worldwide : 1
# social : 1
# marketer : 1
# scroll : 1
# optimize : 3
# samsung : 1
# toyota : 1
# wrap : 1
# quick : 1
# close : 1
# commitment : 2
# july : 1
# news : 6
# showcase : 2
# curated : 1
# licensing : 1
# program : 1
# publication : 2
# 90 : 1
# regional : 1
# globally : 1
# 2500 : 1
# signed : 1
# 23 : 1
# remains : 1
# end : 2
# trust : 1
# googlers : 1
# everywhere : 1
# incredible : 1
# hard : 3
# dedication : 1
# president : 5
# chief : 5
# officer : 5
# cfo : 5
# level : 6
# followed : 3
# segment : 4
# conclude : 1
# outlook : 2
# consolidated : 1
# 767 : 1
# reported : 3
# constant : 1
# currency : 1
# remained : 2
# largest : 2
# contributor : 2
# term : 6
# expense : 15
# total : 2
# 332 : 1
# 7 : 2
# primarily : 7
# reflecting : 7
# 206 : 1
# 6 : 2
# acquisition : 2
# mainly : 1
# noted : 3
# increase : 6
# partially : 1
# offset : 1
# reduction : 1
# depreciation : 2
# due : 3
# change : 3
# estimated : 2
# starting : 3
# 221 : 1
# following : 1
# rd : 1
# compensation : 1
# ga : 1
# impact : 6
# charge : 1
# related : 4
# legal : 1
# matter : 1
# finally : 3
# sale : 3
# marketing : 2
# relatively : 1
# flat : 1
# income : 5
# 213 : 1
# margin : 4
# 28 : 1
# loss : 2
# 146 : 1
# net : 1
# 197 : 1
# reflects : 3
# effective : 1
# tax : 4
# irs : 1
# foreign : 1
# credit : 1
# outsized : 1
# thirdquarter : 1
# resulted : 1
# catchup : 1
# prior : 1
# delivered : 2
# cash : 7
# flow : 4
# 226 : 1
# 78 : 1
# trailing : 1
# ended : 1
# 120 : 1
# marketable : 1
# reminder : 2
# balance : 3
# benefited : 1
# deferral : 2
# certain : 1
# payment : 4
# october : 2
# 16 : 1
# 105 : 1
# reflected : 2
# 44 : 1
# 77 : 1
# 83 : 1
# nonadvertising : 1
# subscriber : 2
# premium : 1
# 239 : 1
# 27 : 1
# 35 : 1
# gcp : 3
# geography : 1
# industry : 4
# although : 1
# optimization : 3
# per : 2
# seat : 1
# 266 : 1
# 297 : 1
# respect : 3
# historic : 1
# volatility : 1
# substantial : 1
# full : 3
# associated : 1
# q4 : 5
# compared : 1
# buyer : 1
# headwind : 5
# tighter : 1
# targeting : 1
# gotomarket : 1
# ongoing : 4
# difference : 2
# timing : 6
# 6a : 1
# 7a : 1
# vertexai : 1
# invest : 4
# aggressively : 1
# given : 8
# remaining : 1
# profitable : 1
# repeatedly : 1
# stressed : 1
# workstreams : 4
# maintaining : 1
# slower : 2
# pace : 2
# headcount : 1
# prioritization : 1
# reallocation : 1
# talent : 1
# optimizing : 2
# real : 2
# estate : 1
# footprint : 1
# incurred : 1
# 207 : 1
# accelerated : 1
# rent : 1
# engineering : 1
# underway : 2
# improve : 2
# magnitude : 1
# technical : 5
# superb : 1
# efficiency : 7
# streamlining : 1
# supplier : 3
# vendor : 1
# central : 1
# procurement : 1
# sharper : 1
# efficiently : 2
# sequential : 1
# quarteronquarter : 1
# point : 2
# family : 1
# increased : 1
# cac : 2
# previously : 1
# usual : 1
# expect : 4
# heavily : 1
# weighted : 1
# capex : 8
# overwhelmingly : 1
# component : 1
# server : 1
# compute : 1
# somewhat : 3
# muted : 2
# cause : 1
# variability : 1
# meaningfully : 2
# needed : 3
# elevated : 3
# increasing : 2
# 2024 : 5
# star : 1
# prevent : 1
# noise : 1
# mute : 1
# line : 9
# asked : 1
# brian : 4
# nowak : 3
# morgan : 3
# stanley : 3
# taking : 5
# jump : 1
# ball : 1
# debate : 1
# return : 3
# capital : 2
# know : 7
# youre : 3
# utility : 1
# conversion : 2
# something : 3
# sort : 4
# show : 1
# signal : 2
# spoken : 1
# highlevel : 1
# potentially : 1
# changing : 2
# bit : 2
# thats : 8
# truism : 1
# tried : 4
# tick : 1
# going : 8
# keep : 1
# moderated : 1
# supporting : 2
# exciting : 1
# front : 1
# particular : 1
# obviously : 7
# ive : 1
# pretty : 3
# rolling : 3
# transition : 4
# evolve : 1
# decade : 1
# always : 5
# side : 4
# newer : 1
# path : 2
# applies : 1
# optimistic : 2
# whats : 4
# operator : 9
# doug : 2
# anmuth : 2
# jpmorgan : 2
# hoping : 2
# talk : 3
# gemini : 3
# multimodal : 2
# agent : 1
# unlock : 2
# decel : 1
# sign : 2
# workload : 1
# deployment : 1
# combined : 1
# ready : 1
# importantly : 2
# laying : 2
# nextgeneration : 1
# series : 1
# launching : 1
# throughout : 1
# extraordinarily : 1
# impressive : 1
# ground : 1
# highly : 1
# efficient : 1
# api : 1
# integration : 1
# future : 3
# developing : 1
# various : 2
# size : 2
# immediately : 1
# internally : 1
# definitely : 4
# promising : 1
# maybe : 4
# leaned : 1
# challenge : 1
# facing : 2
# interest : 2
# stabilization : 3
# eric : 3
# sheridan : 3
# goldman : 3
# sachs : 3
# much : 6
# guy : 3
# ago : 3
# wanted : 1
# updated : 1
# thought : 2
# might : 2
# aligning : 1
# talking : 1
# lap : 1
# thinking : 2
# broad : 1
# recovery : 1
# element : 1
# faced : 1
# space : 1
# specifically : 2
# performing : 1
# probably : 1
# ultimate : 1
# achieve : 1
# 18 : 1
# similar : 1
# since : 1
# additional : 2
# steer : 1
# thing : 6
# accountlevel : 1
# negative : 1
# keywords : 1
# detail : 1
# lifecycle : 2
# called : 1
# revamped : 1
# adapt : 2
# successful : 1
# creatives : 1
# encouraged : 2
# hearing : 2
# mind : 2
# right : 5
# rapidly : 1
# quite : 2
# unpredictable : 1
# landscape : 1
# wellreceived : 1
# everybody : 1
# ton : 1
# excitement : 1
# nearly : 1
# 80 : 1
# least : 1
# yeah : 2
# essential : 1
# set : 2
# durable : 1
# measurement : 1
# tag : 1
# consent : 1
# different : 5
# whole : 1
# yes : 2
# spending : 1
# living : 1
# room : 1
# benefiting : 1
# strength : 4
# apac : 1
# began : 1
# feel : 4
# lloyd : 2
# walmsley : 2
# ubs : 2
# rollout : 2
# uptake : 1
# airelated : 1
# shrinking : 1
# anything : 3
# else : 1
# intensity : 1
# usage : 1
# gotten : 3
# enough : 2
# geographically : 1
# improves : 1
# finetuning : 1
# true : 1
# north : 1
# comfortable : 2
# trajectory : 1
# worked : 2
# desktop : 1
# aienhanced : 1
# nothing : 2
# organic : 1
# pay : 1
# dividend : 1
# high : 1
# celebrated : 1
# proud : 1
# looked : 3
# stage : 1
# adopted : 1
# curve : 2
# phenomenal : 1
# training : 1
# bar : 2
# none : 1
# michael : 2
# nathanson : 2
# moffettnathanson : 1
# moffett : 1
# multipart : 1
# firstly : 1
# objective : 2
# perform : 1
# lesson : 1
# affect : 1
# appetite : 1
# sport : 1
# forward : 3
# several : 2
# context : 1
# navigation : 1
# chat : 1
# poll : 1
# frankly : 2
# happy : 1
# lack : 1
# latency : 1
# piece : 1
# concrete : 1
# actually : 2
# pick : 1
# basically : 1
# fantastic : 1
# justin : 3
# post : 3
# america : 3
# couple : 1
# pause : 1
# middle : 1
# east : 1
# conflict : 1
# aware : 1
# cant : 2
# tragic : 2
# word : 1
# painful : 1
# broadly : 2
# clearly : 1
# contributing : 2
# attractive : 1
# leverage : 1
# extraordinary : 1
# magic : 1
# ken : 2
# gawrelski : 2
# fargo : 2
# structure : 1
# aidriven : 1
# activity : 1
# centralized : 1
# decentralized : 1
# alluded : 1
# cookie : 1
# deprecation : 1
# planned : 1
# begin : 2
# 1q : 1
# 24 : 4
# testing : 4
# privacy : 3
# sandbox : 3
# received : 1
# amazon : 1
# zoom : 1
# back : 3
# worldclass : 1
# intent : 1
# dont : 1
# similarly : 1
# couldnt : 1
# diverse : 1
# phasing : 1
# cooky : 3
# apis : 2
# preliminary : 1
# interestbased : 1
# showed : 1
# privacypreserving : 1
# preparing : 1
# cookieless : 1
# recently : 1
# q1 : 1
# deprecate : 1
# conducting : 1
# realworld : 1
# ass : 1
# readiness : 1
# effectiveness : 1
# regulator : 1
# private : 1
# mark : 2
# mahaney : 2
# evercore : 2
# isi : 1
# sorry : 1
# referring : 2
# later : 1
# hyperscalers : 1
# aggregate : 1
# main : 1
# relates : 1
# analytics : 1
# others : 1
# sitting : 1
# forecasting : 1
# addition : 1
# contribution : 1
# concludes : 2
# id : 1
# remark : 1
# joining : 1
# speaking : 1
# evening : 1
# participating : 1
# disconnect : 1

# %% [markdown]
# ### Step 2: Find the Frequency of a Specific Word
# This step allows you to input a word and get its frequency from the processed text.

# %%
# # Find the Frequency of a Specific Word

# # Ask the user to input a word
# word_to_check = input("Enter a word to find its frequency: ").lower()

# # Fetch the frequency of the word
# word_frequency = freq_dist.get(word_to_check, 0)

# # Display the frequency
# print(f"The word '{word_to_check}' appears {word_frequency} times in the text.")

# %% [markdown]
# ### Step 3: Looking at the Keys
# Here, we'll list the words (keys of the dictionary) that have been processed.

# %%
# Looking at the Keys
words = list(word_freq_dict.keys())
print(words)
# Out:
# ['pdf', 'version', 'transcript', 'please', 'click', 'thank', 'standing', 'alphabet', 'third', 'quarter', '2023', 'earnings', 'conference', 'call', 'time', 'participant', 'listenonly', 'mode', 'speaker', 'presentation', 'questionandanswer', 'session', 'ask', 'question', 'need', 'press', '1', 'telephone', 'would', 'like', 'hand', 'today', 'jim', 'friedland', 'director', 'investor', 'relation', 'go', 'ahead', 'good', 'afternoon', 'everyone', 'welcome', 'u', 'sundar', 'pichai', 'philipp', 'schindler', 'ruth', 'porat', 'ill', 'quickly', 'cover', 'safe', 'harbor', 'statement', 'make', 'regarding', 'business', 'operation', 'financial', 'performance', 'may', 'considered', 'forwardlooking', 'based', 'current', 'expectation', 'assumption', 'subject', 'number', 'risk', 'uncertainty', 'actual', 'result', 'could', 'differ', 'materially', 'refer', 'form', '10k', 'including', 'factor', 'section', '10qs', 'undertake', 'obligation', 'update', 'present', 'gaap', 'nongaap', 'measure', 'reconciliation', 'included', 'release', 'distributed', 'available', 'public', 'website', 'located', 'abcxyzinvestor', 'comment', 'yearoveryear', 'comparison', 'unless', 'state', 'otherwise', 'turn', 'ceo', 'google', 'hello', 'im', 'pleased', 'demonstrate', 'strong', 'growth', 'search', 'youtube', 'momentum', 'cloud', 'turned', '25', 'september', 'offered', 'opportunity', 'reflect', 'progress', 'last', 'century', 'look', 'enabled', 'ai', 'excited', 'confident', 'product', 'continued', 'saw', 'next', 'made', 'part', 'focus', 'making', 'helpful', 'across', 'four', 'area', 'shared', 'first', 'improving', 'knowledge', 'learning', 'includes', 'work', 'generative', 'experience', 'experiment', 'bring', 'capability', 'weve', 'learned', 'lot', 'people', 'trying', 'added', 'new', 'incorporating', 'video', 'image', 'response', 'generating', 'imagery', 'also', 'easier', 'understand', 'debug', 'generated', 'code', 'direct', 'user', 'feedback', 'positive', 'adoption', 'august', 'opened', 'availability', 'india', 'japan', 'country', 'language', 'come', 'add', 'feature', 'expand', 'market', 'engaging', 'broader', 'ecosystem', 'continue', 'prioritize', 'approach', 'value', 'send', 'valuable', 'traffic', 'publisher', 'support', 'healthy', 'open', 'internet', 'applied', 'serve', 'wider', 'range', 'information', 'answer', 'type', 'benefit', 'multiple', 'perspective', 'surfacing', 'link', 'sge', 'linking', 'source', 'page', 'creating', 'content', 'discovered', 'course', 'ad', 'play', 'important', 'role', 'finding', 'provide', 'useful', 'option', 'take', 'action', 'connect', 'well', 'format', 'native', 'use', 'create', 'relevant', 'highquality', 'customized', 'every', 'step', 'journey', 'second', 'focused', 'boosting', 'creativity', 'productivity', 'bard', 'particularly', 'interface', 'conversational', 'llm', 'think', 'early', 'complementary', 'integrate', 'apps', 'service', 'showing', 'workspace', 'map', 'flight', 'hotel', 'improved', 'provides', 'help', 'evaluate', 'explore', 'web', 'earlier', 'month', 'announced', 'assistant', 'personal', 'powered', 'combine', 'reasoning', 'personalized', 'interact', 'text', 'voice', 'coming', 'youll', 'able', 'opt', 'android', 'io', 'mobile', 'device', 'collaborative', 'tool', 'boost', 'seeing', 'great', 'initial', 'traction', 'enabling', 'developer', 'organization', 'build', 'transformative', 'example', 'thousand', 'customer', 'partner', 'already', 'using', 'capture', 'potential', 'share', 'minute', 'fourth', 'building', 'deploying', 'responsibly', 'one', 'sure', 'easily', 'identify', 'encountering', 'aigenerated', 'online', 'technology', 'deepmind', 'synthid', 'vertex', 'watermarked', 'way', 'invisible', 'human', 'eye', 'without', 'reducing', 'quality', 'underlying', 'foundational', 'research', 'done', 'team', 'roll', 'theyve', 'working', 'soon', 'access', 'meaningful', 'investment', 'effort', 'remain', 'committed', 'durably', 'reengineering', 'cost', 'base', 'order', 'capacity', 'longterm', 'sustainable', 'looking', 'operate', 'effectively', 'pos ...

# %% [markdown]
# ### Step 4: Counting the Number of Keys
# This code will tell us how many unique words (keys) are in our processed text.

# %%
# Counting the Number of Keys
num_keys = len(word_freq_dict)
print("Number of unique words:", num_keys)
# Out:
# Number of unique words: 1432

# %% [markdown]
# ### Step 5: Retrieving the Word with the Highest Frequency and its Count
# This step identifies the word with the highest frequency in the text and displays both the word and its frequency.

# %%
# Retrieving the Word with the Highest Frequency and its Count

# Find the word with the highest frequency
most_common_word, highest_freq = max(freq_dist.items(), key=lambda x: x[1])

# Display the most common word and its frequency
print(f"The word '{most_common_word}' has the highest frequency, appearing {highest_freq} times.")
# Out:
# The word 'google' has the highest frequency, appearing 63 times.

# %% [markdown]
# ### Step 6: Calculating Word Weights Relative to the Highest Frequency
# Finally, we first determine the highest frequency in the text.
# Then, for each word, we calculate its weight by dividing its frequency by the highest frequency. This makes the weight of the most common word 1, and all other words will have a weight between 0 and 1, relative to the most common word.

# %%
# Calculating Word Weights Relative to the Highest Frequency

# Find the highest frequency
_, highest_freq = max(freq_dist.items(), key=lambda x: x[1])

# Calculate the weight of each word based on the highest frequency
word_weights = {word: freq / highest_freq for word, freq in freq_dist.items()}

# Display the word weights
print(word_weights)
# Out:
# {'pdf': 0.015873015873015872, 'version': 0.015873015873015872, 'transcript': 0.015873015873015872, 'please': 0.07936507936507936, 'click': 0.015873015873015872, 'thank': 0.31746031746031744, 'standing': 0.015873015873015872, 'alphabet': 0.30158730158730157, 'third': 0.30158730158730157, 'quarter': 0.6825396825396826, '2023': 0.09523809523809523, 'earnings': 0.09523809523809523, 'conference': 0.07936507936507936, 'call': 0.15873015873015872, 'time': 0.09523809523809523, 'participant': 0.015873015873015872, 'listenonly': 0.015873015873015872, 'mode': 0.047619047619047616, 'speaker': 0.031746031746031744, 'presentation': 0.015873015873015872, 'questionandanswer': 0.031746031746031744, 'session': 0.047619047619047616, 'ask': 0.06349206349206349, 'question': 0.5396825396825397, 'need': 0.07936507936507936, 'press': 0.047619047619047616, '1': 0.047619047619047616, 'telephone': 0.031746031746031744, 'would': 0.15873015873015872, 'like': 0.25396825396825395, 'hand': 0.015873015873015872, 'today': 0.15873015873015872, 'jim': 0.06349206349206349, 'friedland': 0.047619047619047616, 'director': 0.031746031746031744, 'investor': 0.06349206349206349, 'relation': 0.047619047619047616, 'go': 0.047619047619047616, 'ahead': 0.14285714285714285, 'good': 0.12698412698412698, 'afternoon': 0.015873015873015872, 'everyone': 0.1111111111111111, 'welcome': 0.015873015873015872, 'u': 0.1746031746031746, 'sundar': 0.2857142857142857, 'pichai': 0.1111111111111111, 'philipp': 0.14285714285714285, 'schindler': 0.07936507936507936, 'ruth': 0.19047619047619047, 'porat': 0.09523809523809523, 'ill': 0.09523809523809523, 'quickly': 0.047619047619047616, 'cover': 0.015873015873015872, 'safe': 0.015873015873015872, 'harbor': 0.015873015873015872, 'statement': 0.047619047619047616, 'make': 0.15873015873015872, 'regarding': 0.031746031746031744, 'business': 0.23809523809523808, 'operation': 0.09523809523809523, 'financial': 0.09523809523809523, 'performance': 0.15873015873015872, 'may': 0.047619047619047616, 'considered': 0.015873015873015872, 'forwardlooking': 0.031746031746031744, 'based': 0.047619047619047616, 'current': 0.031746031746031744, 'expectation': 0.047619047619047616, 'assumption': 0.015873015873015872, 'subject': 0.015873015873015872, 'number': 0.23809523809523808, 'risk': 0.031746031746031744, 'uncertainty': 0.015873015873015872, 'actual': 0.015873015873015872, 'result': 0.23809523809523808, 'could': 0.12698412698412698, 'differ': 0.015873015873015872, 'materially': 0.015873015873015872, 'refer': 0.015873015873015872, 'form': 0.031746031746031744, '10k': 0.015873015873015872, 'including': 0.1746031746031746, 'factor': 0.047619047619047616, 'section': 0.015873015873015872, '10qs': 0.015873015873015872, 'undertake': 0.015873015873015872, 'obligation': 0.015873015873015872, 'update': 0.06349206349206349, 'present': 0.031746031746031744, 'gaap': 0.031746031746031744, 'nongaap': 0.031746031746031744, 'measure': 0.047619047619047616, 'reconciliation': 0.015873015873015872, 'included': 0.015873015873015872, 'release': 0.06349206349206349, 'distributed': 0.015873015873015872, 'available': 0.07936507936507936, 'public': 0.015873015873015872, 'website': 0.015873015873015872, 'located': 0.015873015873015872, 'abcxyzinvestor': 0.015873015873015872, 'comment': 0.07936507936507936, 'yearoveryear': 0.031746031746031744, 'comparison': 0.031746031746031744, 'unless': 0.031746031746031744, 'state': 0.031746031746031744, 'otherwise': 0.031746031746031744, 'turn': 0.031746031746031744, 'ceo': 0.09523809523809523, 'google': 1.0, 'hello': 0.015873015873015872, 'im': 0.12698412698412698, 'pleased': 0.1746031746031746, 'demonstrate': 0.015873015873015872, 'strong': 0.1111111111111111, 'growth': 0.5873015873015873, 'search': 0.47619047619047616, 'youtube': 0.5714285714285714, 'momentum': 0.07936507936507936, 'cloud': 0.4126984126984127, 'turned': 0.015873015873015872, '25': 0.047619047619047616, 'september': 0.06349206349206349, 'offered': 0.015873015873015872, 'opportunity ...

# %% [markdown]
# ## Sentence tokenization
#
# Moving on to sentence tokenization, we'll work with the original data (for readibility) to split the text into individual sentences. This process is essential in many NLP tasks, particularly those involving analysis at the sentence level, such as summarization or sentiment analysis. Sentence tokenization involves breaking down a large body of text into its constituent sentences, which serves as a basis for further analysis.
#
# Let's proceed with the code for sentence tokenization using NLTK, a popular NLP library in Python:

# %%
# Sentence Tokenization
# Assuming 'original_text' contains your initial, unprocessed text
# original_text = """Your original text here."""

# Perform sentence tokenization
sentences = sent_tokenize(original_text)

# Display the tokenized sentences
for idx, sentence in enumerate(sentences):
    print(f"Sentence {idx + 1}: {sentence}")
# Out:
# Sentence 1: For a PDF version of the transcript, please click here.
# Sentence 2: Thank you for standing by for the Alphabet third quarter 2023 earnings conference call.
# Sentence 3: At this time, all participants are in listen-only mode.
# Sentence 4: After the speaker presentation, there will be a question-and-answer session.
# Sentence 5: To ask a question during the session, you will need to press *1 on your telephone.
# Sentence 6: I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations.
# Sentence 7: Please go ahead.
# Sentence 8: Good afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call.
# Sentence 9: With us today are Sundar Pichai, Philipp Schindler and Ruth Porat.
# Sentence 10: Now I’ll quickly cover the Safe Harbor.
# Sentence 11: Some of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking.
# Sentence 12: Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.
# Sentence 13: Actual results could differ materially.
# Sentence 14: Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs.
# Sentence 15: We undertake no obligation to update any forward-looking statement.
# Sentence 16: During this call, we will present both GAAP and non-GAAP financial measures.
# Sentence 17: A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.
# Sentence 18: Our comments will be on year-over-year comparisons unless we state otherwise.
# Sentence 19: And now I’ll turn the call over to Sundar.
# Sentence 20: Sundar Pichai, CEO Alphabet and Google: Thank you, Jim.
# Sentence 21: And hello, everyone.
# Sentence 22: I’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.
# Sentence 23: Google turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.
# Sentence 24: Our product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google.
# Sentence 25: It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.
# Sentence 26: First, improving knowledge and learning.
# Sentence 27: This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.
# Sentence 28: We’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery.
# Sentence 29: We’ve also made it easier to understand and debug generated code.
# Sentence 30: Direct user feedback has been positive, with strong growth in adoption.
# Sentence 31: In August, we opened up availability to India and Japan, with more countries and languages to come.
# Sentence 32: As we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.
# Sentence 33: With generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.
# Sentence 34: We are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.
# Sentence 35: Of course, ads will continue to play an important role in this new Search experience.
# Sentence 36: People are finding ads helpful here, as they provide useful options to take action and connect with businesses.
# Sentence 37: We’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.
# Sentence 38: The second area we are focused on is boosting creativity and productivity.
# Sentence 39: Bard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early experiment and complementary experience to Google Search.
# Sentence 40: Bard can now integrate with Google apps and services, showing relevant information from Workspace, Maps, YouTube, and Google Flights and hotels.
# Sentence 41: We’ve also improved the “Google it” feature.
# Sentence 42: It provides other sources to help people evaluate Bard’s responses and explore information across the web.
# Sentence 43: Earlier this month, we announced Assistant with Bard -- a personal assistant powered by generative AI.
# Sentence 44: It combines Bard’s generative and reasoning capabilities with Assistant’s personalized help.
# Sentence 45: You can interact with it through text, voice or images, and in the coming months, you’ll be able to opt in on Android and iOS mobile devices.
# Sentence 46: Our collaborative tools in Workspace and YouTube are also part of how we boost creativity and productivity, and they are seeing great initial traction.
# Sentence 47: Third, we are enabling developers, businesses and other organizations to build their own transformative products and services.
# Sentence 48: For example, thousands of customers and partners are already using Google Cloud to capture the potential of AI, and we’ll share more there in a minute.
# Sentence 49: And fourth, we are building and deploying AI responsibly, so that everyone can benefit.
# Sentence 50: One area we are focused on is making sure people can more easily identify when they are encountering AI-generated content online.
# Sentence 51: Using new technology powered by Google DeepMind SynthID, images generated by Vertex AI can be watermarked in a way that is invisible to the human eye, without reducing the image quality.
# Sentence 52: Underlying all this work is the foundational research done by our teams at Google DeepMind and Google Research.
# Sentence 53: We are excited to roll out more of what they’ve been working on soon.
# Sentence 54: As we expand access to our new AI services, we continue to make meaningful investments in support of our AI efforts.
# Sentence 55: We remain committed to durably re-engineering our cost base in order to help create capacity for these investments, in support of long-term, sustainable financial value.
# Sentence 56: Across Alphabet, teams are looking at ways to operate as effectively as possible, focused on their biggest priorities.
# Sentence 57: Turning next to YouTube, which saw solid momentum in both its ads and subscription businesses in Q3.
# Sentence 58: NFL Sunday Ticket is now live and receiving excellent reviews.
# Sentence 59: Fans love our multiview feature, which can livestream up to four games on a single screen.
# Sentence 60: We have heard positive feedback from our partners at the NFL about the new features and livestream reliability.
# Sentence 61: This is a clear example of our ability to execute big partnerships with excellence and at scale.
# Sentence 62: I’m really pleased with the growth and engagement on YouTube Shorts.
# Sentence 63: We continue to work on closing the monetization gap here.
# Sentence 64: Shorts now average over 70 billion daily views and are watched by over 2 billion signed-in users every month.
# Sentence 65: At Made On YouTube in September, we announced new tools that make it easier to create engaging content.
# Sentence 66: Dream Screen is an experimental feature that allows creators to add AI-generated video or image backgrounds to Shorts.
# Sentence 67: And YouTube Create is a new mobile app with a suite of production tools for editing Shorts, longer videos or both.
# Sentence 68: Next, Google Cloud.
# Sentence 69: We see continued growth, with Q3 revenue of $8.4 billion, up 22%.
# Sentence 70: Today, more than 60% of the world’s thousand-largest companies are Google Cloud customers.
# Sentence 71: At Cloud Next, we showcased amazing innovations across our entire portfolio of Infrastructure, Data and AI, Workspace Collaboration, and Cybersecurity solutions.
# Sentence 72: We offer advanced AI-optimized infrastructure to train and serve models at scale, and today, more than half of all funded generative AI startups are Google Cloud customers.
# Sentence 73: This includes AI21 Labs, Contextual, Elemental Cognition, Writer, and more.
# Sentence 74: We continue to provide the widest choice of accelerator options.
# Sentence 75: Our A3 VMs powered by NVIDIA’s H100 GPU are generally available, and we are winning customers with Cloud TPU v5e, our most cost-efficient and versatile accelerator to date.
# Sentence 76: On top of our infrastructure, our Vertex AI platform helps customers build, deploy and scale AI-powered applications.
# Sentence 77: We offer more than 100 models -- including popular third-party and open-source models, as well as tools to quickly build Search and Conversation use cases.
# Sentence 78: From Q2 to Q3, the number of active generative AI projects on Vertex AI grew by 7X, including Highmark Health, which is creating more personalized member materials.
# Sentence 79: Duet AI was created using Google’s leading large foundation models and is specially trained to help users to be more productive on Google Cloud.
# Sentence 80: We continue expanding its capabilities and integrating it across a wide range of Cloud products and services.
# Sentence 81: With Duet AI, we’re helping leading brands like PayPal and Deutsche Bank boost developer productivity.
# Sentence 82: And we are enabling retailers like Aritzia and Gymshark to gain new insights for better and faster business results.
# Sentence 83: In fact, companies are increasingly using AI for the purpose of analyzing data, and customers are choosing Google Cloud because we are the only large cloud provider with a unified platform to analyze structured and unstructured data.
# Sentence 84: In Workspace, thousands of companies and more than a million trusted testers have used Duet AI.
# Sentence 85: They are writing and refining content in Gmail and Docs, creating original images from text within Slides, organizing data in Sheets, and more.
# Sentence 86: These innovations enable us to provide new services and grow our base of 10 million paying customers, including enterprises like Grupo Boticario, Unilever and Warner Music.
# Sentence 87: We also integrated Duet AI across our cybersecurity portfolio to differentiate in the marketplace, providing generative AI-powered assistance in Mandiant Threat Intelligence, Chronicle Security Operations and Security Command Center.
# Sentence 88: This reduces the time security teams spend writing, running and refining searches by seven times.
# Sentence 89: We are the only leading security provider that combines frontline intelligence and expertise, a modern security operations platform, and a trusted cloud foundation, all infused with generative AI -- helping protect customers and partners like BT, Jack Henry and Associates, and CoverMyMeds.
# Sentence 90: Turning to hardware.
# Sentence 91: We unveiled our new products this month.
# Sentence 92: We introduced our new Pixel 8, Pixel 8 Pro and Pixel Watch 2 to very positive consumer feedback and reviews.
# Sentence 93: Pixel is the fastest-growing smartphone brand in our top markets, and the only one that grew in units sold year over year.
# Sentence 94: Our portfolio of Pixel products are brought to life thanks to our combination of foundational technologies -- AI, Android and Google Tensor.
# Sentence 95: Google Tensor G3 is the third generation of our tailor-built chip.
# Sentence 96: It’s designed to power transformative experiences by bringing the latest in Google AI research directly to our newest phones.
# Sentence 97: And new AI-powered editing features in Google Photos on Pixel 8 and Pixel 8 Pro remove distractions, generate the best shot from multiple images, and reduce distracting sounds in videos.
# Sentence 98: Pixel and our third-party ecosystem are powered by Android.
# Sentence 99: We just released Android 14 with more accessibility features.
# Sentence 100: I also want to mention Chromebooks Plus, a new category which provides the best of Chrome on great hardware, with built-in Google apps and powerful AI capabilities.
# Sentence 101: We also shared that Chromebooks will now get regular automatic updates for 10 years -- more than any other operating system.
# Sentence 102: In Other Bets, Waymo is onboarding more riders to its commercial ride-hailing service as it gradually adds over 100,000 people from its San Francisco waitlist.
# Sentence 103: Austin will follow as its next ride-hail city.
# Sentence 104: Wing and Walmart announced a new partnership to provide drone delivery service in the Dallas-Fort Worth area.
# Sentence 105: Before handing over to Philipp, I want to thank our employees around the world who are working to create innovative products and provide great services to people and businesses who use our products.
# Sentence 106: Philipp Schindler, SVP and CBO, Google: Thanks, Sundar.
# Sentence 107: And hi, everyone.
# Sentence 108: I’ll start with our performance for the quarter and then give color into the three key priority areas for Ads -- Google AI, Retail, and YouTube -- that we’ve identified on past calls as opportunities for long-term growth in advertising.
# Sentence 109: Google Services revenues of $68 billion were up 11% year-on-year.
# Sentence 110: In Google Advertising, Search & Other, revenues grew 11% year-on-year, led by solid growth in the Retail vertical.
# Sentence 111: In YouTube Ads, revenues were up 12% year-on-year, driven by growth in both brand and direct response.
# Sentence 112: In Network, revenues declined 3% year-on-year.
# Sentence 113: Google Other revenues were up 21% year-on-year, led by strong growth in YouTube subscription revenues.
# Sentence 114: Let’s start with Google AI.
# Sentence 115: Recent dramatic advances in everything from foundational research models, to LLMs, to generative AI are improving our ability to deliver better performance and profitability for advertisers and more helpful, delightful experiences for users.
# Sentence 116: We covered many innovations last quarter after GML, like our conversational experience in Google Ads, significant updates to Performance Max and new campaign types like Demand Gen.
# And as Sundar said, we’re continuing to experiment with new ad formats on SGE.
# Sentence 117: It’s extremely important to us that in this new experience, advertisers still have the opportunity to reach potential customers along their search journeys.
# Sentence 118: I’ll highlight more ways we’re innovating with the best of Google AI as we double-click into our core business.
# Sentence 119: In retail, we had a great quarter.
# Sentence 120: In a market where every dollar counts, our proven AI-powered solutions like Search and PMax are helping retailers drive reliable, strong ROI and meet customers wherever they are across the funnel.
# Sentence 121: In Q3, we also started prepping retailers for what will be a long holiday season.
# Sentence 122: Let me share some themes.
# Sentence 123: Number one - With the maximum number of days between Thanksgiving and Christmas -- and expectations for many micro-peaks beyond Cyber 5 -- we’re arming businesses with insights and planning tools, including Optiscore and Performance Planner, to uncover new opportunities, plan budgets and targets to stay competitive, and be smarter with their inventory and pricing strategy.
# Sentence 124: Number two - Consumer expectations are shifting, especially around price and convenience.
# Sentence 125: We’ve seen 4X “deals’’ queries during the holidays versus other periods.
# Sentence 126: 75% of users say they’ll shop with those offering free shipping.
# Sentence 127: Retailers are capitalizing on these trends with our differentiated merchant offerings like merchant promotions and fulfillment options, and we’re making improvements to significantly boost the number of deals shown to shoppers in Search this holiday season.
# Sentence 128: Look out for more in the coming days about new ways we’ll help shoppers browse deals across the web this year.
# Sentence 129: Number three - No surprise, Omnichannel is the way to succeed.
# Sentence 130: With our suite of omni-product solutions including Local Inventory Ads, omnibidding, and PMax for Store Goals, retailers big and small are capturing demand and incremental store budgets while engaging with high-value customers.
# Sentence 131: Innovation continues across our shopping and merchant experiences, powered by Google AI.
# Sentence 132: Our virtual try-on tool for apparel launched in June and has been a hit with consumers and brands.
# Sentence 133: Users engage with virtual try-on images at a higher rate versus regular brand-provided images.
# Sentence 134: Product Studio is another launch from GML getting positive feedback in pilot mode.
# Sentence 135: It uses the best of gen AI to help businesses create unique and tailored imagery for free that they can then scale across their channels.
# Sentence 136: We’re seeing early merchant testers using it to “seasonalize” their content for the holidays.
# Sentence 137: Let’s shift to YouTube.
# Sentence 138: It’s worth repeating: our intense focus on creator success coupled with our multiformat strategy are at the center of how we think about YouTube’s long-term growth.
# Sentence 139: Shorts, Connected TV and our subscription offerings are key drivers here, and we’re investing across each to solidify YouTube’s position as the best place to create, the best place to watch and the best place to deliver results.
# Sentence 140: Sundar mentioned watchtime and engagement momentum on Shorts as well as our monetization progress.
# Sentence 141: He also covered subscription growth and NFL Sunday Ticket.
# Sentence 142: As for Connected TV, we continue to be the number one overall streaming destination according to Nielsen.
# Sentence 143: 150 million+ people are watching YouTube on CTV screens every month in the U.S.
# Sentence 144: Whether it’s music videos, NFL Sunday Ticket, free movies, Shorts, a continuous stream of MrBeast or some other creator-led content, viewers want choice and variety and we’re giving it to them all in one place.
# Sentence 145: And to help creators and advertisers connect with these billions of viewers across moments, screens and formats, we’re bringing Google AI to awesome new creation tools and ad solutions.
# Sentence 146: AI will do wonders for creation and storytelling.
# Sentence 147: From Dream Screen and YouTube Create -- which Sundar talked about -- to features that autodub content in multiple languages, flip and trim existing assets, remix and clip videos, and more, we’re just getting started.
# Sentence 148: We’re also helping brands break through at speed and scale across the funnel to drive results.
# Sentence 149: Spotlight Moments launched last week.
# Sentence 150: It uses AI to identify trending content around major cultural moments for brand sponsorship opportunities.
# Sentence 151: There’s Video Reach Campaigns, which are expanding to in-feed and Shorts and will be generally available in November.
# Sentence 152: AI is helping advertisers find as many people as possible in their ideal audience for the lowest possible price.
# Sentence 153: Early tests are delivering 54% more reach at 42% lower cost.
# Sentence 154: And then with Video View campaigns, AI is serving skippable ads across in-stream, in-feed, and Shorts and helping advertisers earn the maximum number of views at the lowest possible cost.
# Sentence 155: So far, they’re driving 40% more views, on average, versus in-stream alone.
# Sentence 156: Then for YouTube and other feed-based surfaces, there’s our new Demand Gen campaign which launched in April, rolled out worldwide last week, and was designed for the needs of today’s social marketers to engage people as they stream, scroll and connect.
# Sentence 157: It combines video and image ads in one campaign, with access to 3 billion users across YouTube and Google, and the ability to optimize and measure across the funnel using Google AI.
# Sentence 158: Demand Gen is already driving success for brands like Samsung and Toyota.
# Sentence 159: Before I wrap, one quick highlight on our close collaboration and commitment to our most important ecosystems and partners.
# Sentence 160: In July, we launched Google News Showcase in the U.S., our curated online news experience and licensing program, with more than 150 news publications, 90% of which are local or regional.
# Sentence 161: Globally, over 2,500 news publications have signed on to News Showcase, and the product is live in 23 countries to date.
# Sentence 162: Our commitment to open access to news and information remains strong.
# Sentence 163: With that, I’ll end with a thank you to our customers and partners around the world for their continued trust and collaboration, and our Googlers everywhere for their incredible hard work and dedication.
# Sentence 164: Ruth, over to you.
# Sentence 165: Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Thank you, Philipp.
# Sentence 166: We are very pleased with our financial results for the third quarter, driven by meaningful growth in Search and YouTube, and momentum in Cloud.
# Sentence 167: My comments will be on year-over-year comparisons for the third quarter, unless I state otherwise.
# Sentence 168: I will start with results at the Alphabet level, followed by segment results, and conclude with our outlook.
# Sentence 169: For the third quarter, our Consolidated Revenues were $76.7 billion, up 11% in both reported and constant currency.
# Sentence 170: Search remained the largest contributor to revenue growth.
# Sentence 171: In terms of expenses, Total Cost of Revenues was $33.2 billion, up 7%, primarily reflecting Other Cost of Revenues of $20.6 billion, which was up 6%.
# Sentence 172: Growth here was primarily driven by Content Acquisition Costs, mainly for YouTube subscription offerings.
# Sentence 173: As noted in our earnings release, the overall increase in data center and other operations costs was partially offset by a reduction in depreciation expense due to the change in estimated useful lives we made starting in the first quarter of the year.
# Sentence 174: Operating expenses were $22.1 billion, up 6%, reflecting the following: First, an increase in R&D expenses, driven primarily by compensation; second, an increase in G&A expenses reflecting the impact of charges related to legal matters; and finally, Sales & Marketing expenses, which were relatively flat to last year.
# Sentence 175: Operating income was $21.3 billion, up 25%, and our operating margin was 28%.
# Sentence 176: Other Income & Expense was a loss of $146 million.
# Sentence 177: Net income was $19.7 billion.
# Sentence 178: This reflects an effective tax rate of 7% in the third quarter from an IRS change related to the use of foreign tax credits which had an outsized impact on the third-quarter rate, because the change resulted in a catch-up for prior periods.
# Sentence 179: We delivered Free Cash Flow of $22.6 billion in the third quarter and $78 billion for the trailing 12 months.
# Sentence 180: We ended the quarter with $120 billion in cash and marketable securities.
# Sentence 181: As a reminder, our cash balance and free cash flow in the second and third quarters benefited from the deferral of certain tax payments to the fourth quarter of 2023.
# Sentence 182: As noted in our earnings release, on October 16 we made an estimated tax payment of $10.5 billion related to this deferral, which will be reflected in our cash balance and free cash flow in the fourth quarter.
# Sentence 183: Turning to segment results, within Google Services, Revenues were $68 billion, up 11%.
# Sentence 184: Google Search and Other advertising revenues of $44 billion in the quarter were up 11%, led again by growth in retail.
# Sentence 185: YouTube advertising revenues of $8 billion, were up 12% driven by both brand advertising and direct response.
# Sentence 186: Network advertising revenues of $7.7 billion were down 3%.
# Sentence 187: Other Revenues were $8.3 billion, up 21%, primarily reflecting growth in YouTube non-advertising revenues, driven by subscriber growth in YouTube TV, followed by YouTube Music Premium.
# Sentence 188: Google Services Operating Income was $23.9 billion, up 27%, and the operating margin was 35%.
# Sentence 189: Turning to the Google Cloud segment, revenues were $8.4 billion for the quarter, up 22%.
# Sentence 190: GCP revenue growth remained strong across geographies, industries and products, although the Q3 year-on-year growth rate reflects the impact of customer optimization efforts.
# Sentence 191: Google Workspace also delivered strong revenue growth, primarily driven by increases in average revenue per seat.
# Sentence 192: Google Cloud had Operating Income of $266 million, and the operating margin was 3%.
# Sentence 193: As to our Other Bets, for the third quarter, revenues were $297 million and the operating loss was $1.2 billion.
# Sentence 194: Turning to our outlook for the business, with respect to Google Services.
# Sentence 195: First, within Advertising, after a period of historic volatility, we were pleased with the year-on-year revenue growth of Search and YouTube advertising in the third quarter.
# Sentence 196: Second, within Other Revenues, in our YouTube subscription products, the substantial growth in revenues primarily reflects subscriber growth.
# Sentence 197: Looking ahead, a full quarter of NFL Sunday Ticket revenues, as well as associated content acquisition costs, will be reflected in Q4 results, compared to only a few weeks in the third quarter.
# Sentence 198: Play had solid growth in the third quarter, driven primarily by an increase in the number of buyers.
# Sentence 199: With respect to Hardware, there is a headwind to revenues in the fourth quarter, reflecting efforts to optimize the portfolio with tighter targeting of our go-to-market investments, as well as the ongoing impact from the difference in launch timing for the Pixel 6a and 7a that we mentioned last quarter.
# Sentence 200: Turning to Google Cloud, we are pleased with the ongoing customer engagement with GCP and Workspace, and the potential benefit of our AI solutions -- including infrastructure and services such as VertexAI and Duet.
# Sentence 201: We continue to invest aggressively, given the significant potential we see, while remaining focused on profitable growth.
# Sentence 202: In terms of expenses and profitability, we’re pleased with our operating performance.
# Sentence 203: As we have repeatedly stressed, we remain focused on durably re-engineering our cost base to create investment capacity to support our growth priorities, most important of which is with AI.
# Sentence 204: We have a number of workstreams in place:
#
# First, we are maintaining a slower pace of headcount growth, reflecting product prioritization and reallocation of talent to support our most important growth opportunities.
# Sentence 205: Second, we remain focused on optimizing our real estate footprint, including how and where we work, to reduce our expense growth.
# Sentence 206: As you can see from our earnings release, we incurred $207 million in accelerated rent and depreciation in the third quarter related to these actions.
# Sentence 207: Third, we have engineering workstreams underway to improve productivity across Alphabet.
# Sentence 208: Given the magnitude of investment in our technical infrastructure, we have a superb team focused on efficiency of our operations there.
# Sentence 209: We are also making progress in streamlining operations across Alphabet through the use of AI.
# Sentence 210: Finally, there are ongoing workstreams that are improving the efficiency of our spend with suppliers and vendors through our central procurement organization.
# Sentence 211: And to be clear, across the portfolio of Other Bets companies, we have also been working to identify opportunities to create sharper focus and to operate more efficiently and effectively.
# Sentence 212: With respect to sequential quarter-on-quarter trends, two further points: First, Cost of Sales in the fourth quarter will reflect both higher hardware costs given Pixel family launches, as well as increased CAC for YouTube as previously noted.
# Sentence 213: Second, as usual, we expect Sales and Marketing expenses to be more heavily weighted to the end of the year in part to support product launches and the holiday season.
# Sentence 214: Finally, our reported capex in Q3 was $8 billion, driven overwhelmingly by investment in our technical infrastructure, with the largest component for servers, followed by data centers, reflecting a meaningful increase in our investments in AI compute.
# Sentence 215: The growth in reported cash capex in Q3 is somewhat muted due to the timing of supplier payments, which can cause variability from quarter to quarter.
# Sentence 216: We continue to invest meaningfully in the technical infrastructure needed to support the opportunities we see in AI across Alphabet and expect elevated levels of investment, increasing in the fourth quarter of 2023 and continuing to grow in 2024.
# Sentence 217: In closing, we remain very excited about the opportunities ahead and committed to deliver sustainable financial value.
# Sentence 218: Sundar, Philipp and I will now take your questions.
# Sentence 219: As a reminder, to ask a question you will need to press star *1 on your telephone.
# Sentence 220: To prevent any background noise, we ask that you please mute your line once your question has been asked.
# Sentence 221: And our first question comes from Brian Nowak with Morgan Stanley.
# Sentence 222: Your line is open.
# Sentence 223: Brian Nowak (Morgan Stanley): Great.
# Sentence 224: Thanks for taking my questions.
# Sentence 225: I have two.
# Sentence 226: The first one is somewhat of a jump ball.
# Sentence 227: There is somewhat of an investor debate about the incremental return on capital to Search when it comes to AI.
# Sentence 228: I know it’s early, but are there any examples that you’re seeing with SGE or Bard on higher utility, higher conversion rates, more engagement?
# Sentence 229: Just something to sort of show signal around the return that could come from these investments?
# Sentence 230: And the second one, Ruth, I know you have spoken a lot about durably re-engineering the cost base.
# Sentence 231: I think in the past you talked about how expenses could grow slower than revenue in 2024.
# Sentence 232: Is that sort of still the high-level way to think about it, or is that potentially changing a bit as investments are continuing?
# Sentence 233: Thanks.
# Sentence 234: Sundar Pichai, CEO Alphabet and Google: Ruth, do you want to take the second part, I’ll take the first?
# Sentence 235: Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Sure.
# Sentence 236: Thanks for that, Brian.
# Sentence 237: Overall, that’s sort of a truism, as you know well, that looking to grow revenues at a faster rate than expenses as we’re focused on delivering sustainable financial value, and so that really takes us to the workstreams which I tried to tick through again.
# Sentence 238: Those remain the driver.
# Sentence 239: They’re the real priority.
# Sentence 240: Those are the efforts that are going to enable us to keep expense growth as moderated as possible while supporting the investment growth that is so exciting in front of us, in particular around AI.
# Sentence 241: Sundar Pichai, CEO Alphabet and Google: To your first part, obviously, we see AI as a foundational platform shift and are excited about the opportunities across our business.
# Sentence 242: It starts with Search.
# Sentence 243: I’ve been pretty pleased with how the user feedback has been on SGE.
# Sentence 244: We are rolling it out to more users.
# Sentence 245: Through it all, we’re making sure the product works well and we are generating value for our ecosystem and that Ads transitions well.
# Sentence 246: I think I view this as, with AI, the opportunity to evolve Search and Assistant over the next decade ahead.
# Sentence 247: And I think as we’ve always seen, when you continue to invest and build great experiences, you can get value on the other side.
# Sentence 248: And I do think over time there will be newer paths, just like we’ve done on YouTube.
# Sentence 249: I think with the AI work, there are subscription models as a possible path as well.
# Sentence 250: Obviously, all of the AI investments we’re doing applies across Cloud, too, and I’m pretty optimistic about what’s ahead there as well.
# Sentence 251: Brian Nowak (Morgan Stanley): Great.
# Sentence 252: Thank you, both.
# Sentence 253: Operator: Your next question comes from Doug Anmuth with JPMorgan.
# Sentence 254: Your line is open.
# Sentence 255: Doug Anmuth (JPMorgan): Thanks for taking the questions.
# Sentence 256: One for Sundar and one for Ruth.
# Sentence 257: Sundar, you talked a lot about AI.
# Sentence 258: I was hoping you could talk more about Gemini and how it will differentiate from other models -- some of the multimodal capabilities and what new experiences or [agents] you think it could unlock and how we should think about timing.
# Sentence 259: And then also just on Cloud, hoping you can talk about some of the factors there on the decel in Cloud and just what you’re seeing in terms of optimizations, and is there any sign of new workload deployments taking place?
# Sentence 260: Thanks.
# Sentence 261: Sundar Pichai, CEO Alphabet and Google: Thanks, good questions.
# Sentence 262: So on Gemini, obviously, it’s an effort from our combined Google DeepMind team.
# Sentence 263: I’m very excited at the progress there and as we’re working through getting the model ready.
# Sentence 264: To me, more importantly, we are just really laying the foundation of what I think of as the next-generation series of models we’ll be launching all throughout 2024.
# Sentence 265: The pace of innovation is extraordinarily impressive to see.
# Sentence 266: We are creating it from the ground up to be multimodal, highly efficient with tool and API integrations, and more importantly, laying the platform to enable future innovations as well.
# Sentence 267: We are developing Gemini in a way that it is going to be available at various sizes and capabilities, and we’ll be using it immediately across all our products internally as well as bringing it out to both developers and Cloud customers through Vertex.
# Sentence 268: So I view it as a journey, and each generation is going to be better than the other.
# Sentence 269: And we are definitely investing, and the early results are very promising.
# Sentence 270: On Cloud, maybe what I would say is, overall, we have definitely started seeing customers looking to optimize spend.
# Sentence 271: We leaned into it to help customers, given some of the challenges they were facing, and so that was a factor.
# Sentence 272: But we are definitely seeing a lot of interest in AI.
# Sentence 273: There are many, many projects underway now.
# Sentence 274: Just on Vertex alone, the number of projects grew over 7X.
# Sentence 275: And so we see signs of stabilization, and I’m optimistic about what’s ahead.
# Sentence 276: Operator: Your next question comes from Eric Sheridan with Goldman Sachs.
# Sentence 277: Your line is now open.
# Sentence 278: Eric Sheridan (Goldman Sachs): Thank you very much for taking the questions.
# Sentence 279: Two, if I could.
# Sentence 280: Sundar, you guys led over a year ago starting with Performance Max, and I wanted to know if we could get your updated thoughts on how AI might impact the broader advertising industry and how you are aligning Alphabet and Google’s goals with AI and where it might take the advertising industry in the years ahead.
# Sentence 281: That would be the first question.
# Sentence 282: And then about a year ago, Philipp and Ruth started talking about some of the brand advertising headwinds that YouTube was facing.
# Sentence 283: As we start to lap those headwinds, how should we be thinking about a broad recovery in brand advertising versus elements of still headwinds that are being faced in the broader Ads spaces, specifically with YouTube?
# Sentence 284: Thank you.
# Sentence 285: Philipp Schindler, SVP and CBO, Google: So maybe I take the first one.
# Sentence 286: We are very pleased with how Performance Max is performing.
# Sentence 287: It gives advertisers really a maximum performance across all inventory from one really AI-powered campaign, and it’s probably the ultimate example of AI in action across our Ads products.
# Sentence 288: It’s delivering excellent ROI.
# Sentence 289: Those using it achieve on average over 18% more conversions at a similar cost per action.
# Sentence 290: Since rolling it out about two years ago, we’ve continued to expand the features, give advertisers additional ways to steer how it works.
# Sentence 291: We have a lot of things, like account-level negative keywords, other details here.
# Sentence 292: We launched new lifecycle goals -- customer lifecycle goals, we called them.
# Sentence 293: A revamped asset creation flow that really helps business adapt and scale their most successful creatives.
# Sentence 294: I think that’s one to watch.
# Sentence 295: We will also continue to build other new PMax features based on all the advertiser feedback we’re seeing.
# Sentence 296: So we are very, very encouraged by the progress here.
# Sentence 297: Overall maybe -- there was a second part to your question, a bit on what we’re hearing from the customers out there.
# Sentence 298: Look, driving ROI and efficiency is still top of mind for many, right?
# Sentence 299: It’s a rapidly shifting and still quite unpredictable consumer landscape out there.
# Sentence 300: Our AI tools are very well-received.
# Sentence 301: AI, gen AI are top of mind for everybody really.
# Sentence 302: There’s a ton of excitement, lots of questions about it.
# Sentence 303: Many understand the value.
# Sentence 304: Nearly 80% of our advertisers already use at least one AI-powered Search Ads product.
# Sentence 305: Yeah, we’re hearing a lot of good feedback on, number one, our Ads AI Essentials, which are really helping to unlock the power of AI and set up for durable ROI growth on the advertiser side.
# Sentence 306: Those are products like the foundation for our data and measurement, things like Google Tag, Consent Mode and so on.
# Sentence 307: Obviously Search and PMax, we talked about it, and then all those gen AI products, all those different ones.
# Sentence 308: So there’s a whole lot of interest in those products.
# Sentence 309: Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Then on to your second question regarding YouTube.
# Sentence 310: As we said, overall, year-on-year growth in revenues was driven by both brand advertising and direct response.
# Sentence 311: But very much to your question, yes, there was a stabilization in spending by advertisers.
# Sentence 312: We’re really pleased about that.
# Sentence 313: We’re particularly pleased about the ongoing performance in the Living Room and on Shorts.
# Sentence 314: And as I said, that’s both watchtime growth and monetization.
# Sentence 315: I would say the other thing benefiting YouTube is the retail strength we talked about with Search -- retail strength in APAC in both Search and YouTube.
# Sentence 316: That really began in the second quarter, continued in the third quarter, but that was another contributor.
# Sentence 317: So quite a number of things going on.
# Sentence 318: Feel good about the results the team was able to deliver here.
# Sentence 319: Eric Sheridan (Goldman Sachs): Thank you so much.
# Sentence 320: Operator: Your next question comes from Lloyd Walmsley with UBS.
# Sentence 321: Your line is open.
# Sentence 322: Lloyd Walmsley (UBS): Great.
# Sentence 323: Thanks for taking the question.
# Sentence 324: Two, if I can.
# Sentence 325: First, as we just think about the rollout of SGE across the user base, how far along is that?
# Sentence 326: And how do you balance the product rollout and consumer uptake versus monetization in that transition?
# Sentence 327: And then the second one, also sort of generative AI-related, how quickly are you guys finding new ways of optimizing?
# Sentence 328: Whether that’s shrinking model sizes, chip efficiencies or anything else.
# Sentence 329: And do you think overall capital intensity of business scales up, or do you just find ways to do this more efficiently as usage scales?
# Sentence 330: Anything you can share there would be great.
# Sentence 331: Thanks.
# Sentence 332: Sundar Pichai, CEO Alphabet and Google: The first part about SGE, we are still in very early days in terms of how much we have rolled it out.
# Sentence 333: But we have definitely gotten it out to enough people, both geographically, across user segments and enough to know that the product is working well.
# Sentence 334: It improves the experience.
# Sentence 335: But there are areas to improve, which we are fine-tuning.
# Sentence 336: Our true north here is getting at the right user experience we want to, and I’m pretty comfortable seeing the trajectory.
# Sentence 337: And we’ve always worked through these transitions, be it from desktop to mobile or from now, mobile to an AI-enhanced experience.
# Sentence 338: So it’s nothing new, and I feel very comfortable that as we go through it, the strength of our teams -- both on the organic side as well as Ads side -- to drive the right experience for users including Ads will pay dividends.
# Sentence 339: I think we’ll continue to make improvements and make progress there.
# Sentence 340: On your second question, at a high level, I would say all through the -- we just celebrated 25 years -- and of all the things I was proud about, when I looked at the strength of the work we’ve done across our infrastructure as a company, our technical infrastructure as a company, and various given stages at a given moment in time, when we adopted new generations of technology.
# Sentence 341: We’ve looked at the cost of it, but then the curves, the efficiency curves we have driven on top of it, has always been phenomenal to see.
# Sentence 342: And I see the current moment as no different.
# Sentence 343: Already through this year, we are driving significant efficiencies, both in our models, in training costs and serving costs, and our ability to adapt what’s needed to the right use case.
# Sentence 344: And so I think we’ll do everything that is needed to make sure we have the leading AI models and infrastructure in the world, bar none.
# Sentence 345: And we will continue driving efficiencies from there.
# Sentence 346: Operator: Your next question comes from Michael Nathanson with MoffettNathanson.
# Sentence 347: Your line is now open.
# Sentence 348: Michael Nathanson (Moffett): Thank you.
# Sentence 349: I’m going to ask you guys a multi-part question on YouTube TV.
# Sentence 350: So, firstly, what were the broader objectives for getting Sunday Ticket?
# Sentence 351: How did it perform versus those objectives?
# Sentence 352: What lessons have you learned from having NFL Sunday Ticket?
# Sentence 353: How does that affect your appetite for more sports going forward?
# Sentence 354: Thanks.
# Sentence 355: Philipp Schindler: So, as Sundar said earlier, we are several weeks into our first season and we are very pleased with how it’s going.
# Sentence 356: I think in the broader context, you have to look at it as our overall YouTube subscription strategy.
# Sentence 357: The great feedback we’ve gotten so far on the YouTube experience is very, very significant.
# Sentence 358: People love the navigation and they love multiview.
# Sentence 359: They love the chats and the polls.
# Sentence 360: And frankly, people are very happy with the lack of latency here.
# Sentence 361: The number one piece of concrete feedback the team has gotten is actually that people want the ability to pick their own games for multiview, which is -- multiview is the awesome feature we started rolling out on YouTube TV that gives fans the ability to basically watch multiple streams here at once.
# Sentence 362: And, yeah, overall, the teams are working hard to build a fantastic experience, and we are really trying to stay focused on getting our first season right and providing the best possible experience really for fans here.
# Sentence 363: Operator: Your next question comes from Justin Post with Bank of America.
# Sentence 364: Your line is now open.
# Sentence 365: Justin Post (Bank of America): Great.
# Sentence 366: Thank you, a couple questions on Q4.
# Sentence 367: Can you provide any color on if there’s been any pause in advertising around the Middle East conflict in October?
# Sentence 368: Anything we should be aware of for Q4?
# Sentence 369: And then second, when we do think about the Sunday Ticket impact, I know you can’t give us revenues or expenses, but overall, would that be a headwind to margins in Q4 or something we should be thinking about?
# Sentence 370: Thank you.
# Sentence 371: Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So look, on the first question, obviously this is a tragic, tragic -- there are no words to talk about what’s going on.
# Sentence 372: And all of our focus has been on supporting our people there and how our products can be as helpful as possible in this very painful time, broadly.
# Sentence 373: And so nothing really to add.
# Sentence 374: And then in terms of the second question, Sunday Ticket, the only thing I tried to call out there is that clearly this is the first full quarter of Sunday Ticket that is contributing overall to the subscription revenues that we see.
# Sentence 375: That’s in part of Other Revenues.
# Sentence 376: Also obviously, it is contributing to higher CAC in the fourth quarter.
# Sentence 377: So tried to make that really clear.
# Sentence 378: And as we look longer term, we expect to generate an attractive return over the life of the deal.
# Sentence 379: We’re continuing to invest in support of this.
# Sentence 380: And excited about the additional opportunities that come out of it working with partners to deliver clips and other opportunities.
# Sentence 381: As we’ve said, we’ve heard positive feedback from our partners at the NFL about the new features and livestream reliability.
# Sentence 382: And this is really a clear example of our ability to execute big partnerships with excellence at scale and really leverage a lot of the extraordinary magic at YouTube and across Google.
# Sentence 383: And that’s what we’re excited about.
# Sentence 384: Justin Post (Bank of America): Great, thank you.
# Sentence 385: Operator: Your next question comes from Ken Gawrelski with Wells Fargo.
# Sentence 386: Your line is now open.
# Sentence 387: Ken Gawrelski (Wells Fargo): Thank you so much.
# Sentence 388: Two questions, if I may.
# Sentence 389: First, how do you think about the future structure of AI-driven Search capabilities?
# Sentence 390: Will activity remain centralized in a search bar, or will it be decentralized and present in many different applications, including on third-party applications?
# Sentence 391: You alluded to Bard being integrated into multiple Google experiences earlier in the call.
# Sentence 392: And then the second question is, any update on the Chrome cookie deprecation planned to begin in 1Q ’24?
# Sentence 393: What have you seen so far based on your early testing of Privacy Sandbox, and what advertiser feedback have you received?
# Sentence 394: Sundar Pichai, CEO Alphabet and Google: On your first question, look, you know, I broadly think of it as people are looking for information.
# Sentence 395: They’ve always looked for it in many, many different ways.
# Sentence 396: We’ve given the product search example.
# Sentence 397: People can directly go to Amazon, as an example, or come to Google.
# Sentence 398: If you zoom back and take an information view of the world, there’s always been many different ways to get it.
# Sentence 399: And part of our work we do in making Search be world-class and give users what they’re looking for is so that we can get at as much of that intent as possible.
# Sentence 400: So I don’t see that changing.
# Sentence 401: With mobile, there were more ways that people could get information, but we worked hard to make Search work better in the mobile world.
# Sentence 402: And similarly, I view with AI, there will be many ways people get information.
# Sentence 403: But it also offers us an opportunity in Search and in Assistant to take it to the next level and answer use cases, which we couldn’t have done before, and expand a diverse set of needs where we are a source.
# Sentence 404: So that’s how I see the opportunity ahead.
# Sentence 405: Philipp Schindler, SVP and CBO, Google: And to the second part of your question: yes, Chrome still plans to begin phasing out third-party cookies in the second half of ’24.
# Sentence 406: In the last several months, Chrome has really made significant progress on the Privacy Sandbox with APIs for developer testing.
# Sentence 407: And they are now generally available in Chrome.
# Sentence 408: Our Ads team is testing these APIs.
# Sentence 409: And as we shared back in April, the preliminary results of our interest-based ads testing showed a combination of what we call privacy-preserving signals and AI optimization actually provides positive results for businesses preparing for a cookieless future.
# Sentence 410: We also recently announced that in Q1 of ’24 we plan to deprecate third-party cookies for 1% of Chrome users, and this will support developers, obviously, in conducting their real-world experiments to assess the readiness and effectiveness of their products without third-party cookies.
# Sentence 411: And we’re overall encouraged by the ecosystem engagement on Privacy Sandbox.
# Sentence 412: We’ll continue to work with the industry and regulators in how these technologies can support the transition to, frankly, a more private web.
# Sentence 413: Operator: And our last question comes from Mark Mahaney with Evercore.
# Sentence 414: Your line is now open.
# Sentence 415: Mark Mahaney (Evercore ISI): Thank you.
# Sentence 416: Two questions, please.
# Sentence 417: Ruth, you talked about these elevated levels of investments in Q4 and in ’24.
# Sentence 418: I’m sorry, were you referring to just CapEx or CapEx and total expenses?
# Sentence 419: And then on the comments around stabilization in Cloud, is this something that you just started to see in the September quarter, or had you seen that starting earlier in the year?
# Sentence 420: And if you just started seeing it in the September quarter, would you have any thoughts on why you would have seen it, why Google Cloud would have seen it maybe later than some of the other hyperscalers?
# Sentence 421: Thank you.
# Sentence 422: Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So I think what you’re referring to was my CapEx comment.
# Sentence 423: I was trying to make the point that we are committed to meaningfully investing in CapEx, given all the opportunities we see.
# Sentence 424: We do continue to expect elevated levels of investment in our technical infrastructure.
# Sentence 425: It will be increasing in the fourth quarter.
# Sentence 426: And talked about some of the difference in timing, muted timing in the third quarter due to the timing of supplier payments.
# Sentence 427: And then tried to make it clear that we will continue to grow CapEx in 2024 -- or more specifically to your question, 2024 aggregate CapEx will be above the full year 2023.
# Sentence 428: So that was the main one.
# Sentence 429: And then as it relates to Cloud, as Sundar said, what we’re really excited about is the revenue growth does reflect healthy customer adoption across the portfolio, and that’s Infrastructure, Data Analytics, it’s Security.
# Sentence 430: And so I can’t comment on others, but we feel good about where we’re sitting here and looking forward.
# Sentence 431: And we’ll let you do the forecasting.
# Sentence 432: GCP growth in the third quarter was above the growth rate for Cloud overall, and we feel really good about the work that they’re doing there.
# Sentence 433: And then, of course, in addition to that is all of the contribution from Google Workspace.
# Sentence 434: Operator: Thank you.
# Sentence 435: And that concludes our question-and-answer session for today.
# Sentence 436: I’d like to turn the conference back over to Jim Friedland for any further remarks.
# Sentence 437: Jim Friedland, Director Investor Relations: Thanks, everyone, for joining us today.
# Sentence 438: We look forward to speaking with you again on our fourth quarter 2023 call.
# Sentence 439: Thank you and have a good evening.
# Sentence 440: Operator: Thank you, everyone.
# Sentence 441: This concludes today’s conference call.
# Sentence 442: Thank you for participating.
# Sentence 443: You may now disconnect.

# %% [markdown]
# Now we have one line for each one of the sentences and we used the original data (`original_text`) here to show the results to the user because it makes no sense to show the results without stopwords or without punctuations. The user would have difficulty reading the results.
#
# In short, the original version of the text is being used to show the results to the user, while the Pre-processed version will be used to perform the mathematical calculations in order to find the best sentences.

# %% [markdown]
# ## Generate the summary (score for sentences)
#
# To generate a score for each sentence in your text, we will follow a multi-step process. This scoring process will involve calculating a score for each sentence based on the words it contains, and then using these scores to identify the most significant sentences for the summary. Let's break down the process:

# %% [markdown]
# ### Step 1: Calculate Scores for Each Sentence
# First, we'll calculate a score for each sentence by summing the weights of the words it contains. Remember, these weights were determined based on word frequency in the previous steps.

# %%
# Calculate Scores for Each Sentence
# Assuming 'sentences' is your list of tokenized sentences
# And 'word_weights' is your dictionary of word weights

sentence_scores = {}

for sentence in sentences:
    words = word_tokenize(sentence.lower())
    sentence_score = sum(word_weights.get(word, 0) for word in words)
    sentence_scores[sentence] = sentence_score

# %%
sentence_scores
# Out:
# {'For a PDF version of the transcript, please click here.': 0.14285714285714285,
#  'Thank you for standing by for the Alphabet third quarter 2023 earnings conference call.': 2.047619047619048,
#  'At this time, all participants are in listen-only mode.': 0.14285714285714285,
#  'After the speaker presentation, there will be a question-and-answer session.': 0.19047619047619047,
#  'To ask a question during the session, you will need to press *1 on your telephone.': 0.8571428571428571,
#  'I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations.': 0.9047619047619048,
#  'Please go ahead.': 0.2698412698412698,
#  'Good afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call.': 1.9841269841269842,
#  'With us today are Sundar Pichai, Philipp Schindler and Ruth Porat.': 1.095238095238095,
#  'Now I’ll quickly cover the Safe Harbor.': 0.09523809523809523,
#  'Some of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking.': 0.9047619047619047,
#  'Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.': 0.3333333333333333,
#  'Actual results could differ materially.': 0.1746031746031746,
#  'Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs.': 0.42857142857142855,
#  'We undertake no obligation to update any forward-looking statement.': 0.14285714285714285,
#  'During this call, we will present both GAAP and non-GAAP financial measures.': 0.31746031746031744,
#  'A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.': 0.6349206349206347,
#  'Our comments will be on year-over-year comparisons unless we state otherwise.': 0.09523809523809523,
#  'And now I’ll turn the call over to Sundar.': 0.47619047619047616,
#  'Sundar Pichai, CEO Alphabet and Google: Thank you, Jim.': 2.174603174603174,
#  'And hello, everyone.': 0.12698412698412698,
#  'I’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.': 3.3492063492063497,
#  'Google turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.': 3.8571428571428568,
#  'Our product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google.': 3.6825396825396823,
#  'It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.': 3.2698412698412698,
#  'First, improving knowledge and learning.': 0.3968253968253968,
#  'This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.': 2.952380952380952,
#  'We’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery.': 1.3809523809523805,
#  'We’ve also made it easier to understand and debug generated code.': 0.5238095238095237,
#  'Direct user feedback has been positive, with strong growth in adoption.': 1.333333333333333,
#  'In August, we opened up availability to India and Japan, with more countries and languages to come.': 0.2857142857142857,
#  'As we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.': 1.7460317460317456,
#  'With generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.': 2.7619047619047614,
#  'We are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.': 1.0,
#  'Of course, ads will continue to play an important role in this new Search experience.': 1.7142857142857142,
#  'People are finding ads helpful here, as they provide useful options to take action and connect with businesses.': 0.7777777777777777,
#  'We’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.': 2.841269841269841,
#  'The second area we are focused on is boosting creativity and productivity.': 0.6349206349206348,
#  'Bard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early experiment and complementary experience to Google Search.': 2.6984126984126986,
#  'Bard can now integrate with Google apps and services, showing relevant information from Workspace, Maps, YouTube, and Google Flights and hotels.': 3.015873015873016,
#  'We’ve also improved the “Google it” feature.': 1.492063492063492,
#  'It provides other sources to help people evaluate Bard’s responses and explore information across the web.': 1.3015873015873016,
#  'Earlier this month, we announced Assistant with Bard -- a personal assistant powered by generative AI.': 1.7777777777777777,
#  'It combines Bard’s generative and reasoning capabilities with Assistant’s personalized help.': 0.5873015873015872,
#  'You can interact with it through text, voice or images, and in the coming months, you’ll be able to opt in on Android and iOS mobile devices.': 0.30158730158730157,
#  'Our collaborative tools in Workspace and YouTube are also part of how we boost creativity and productivity, and they are seeing great initial traction.': 1.6507936507936507,
#  'Third, we are enabling developers, businesses and other organizations to build their own transformative products and services.': 0.4603174603174603,
#  'For example, thousands of customers and partners are already using Google Cloud to capture the potential of AI, and we’ll share more there in a minute.': 2.9365079365079363,
#  'And fourth, we are building and deploying AI responsibly, so that everyone can benefit.': 1.3333333333333333,
#  'One area we are focused on is making sure people can more easily identify when they are encountering AI-generated content online.': 1.2857142857142856,
#  'Using new technology powered by Google DeepMind SynthID, images generated by Vertex AI can be watermarked in a way that is invisible to the human eye, without reducing the image quality.': 3.4603174603174596,
#  'Underlying all this work is the foundational research done by our teams at Google DeepMind and Google Research.': 2.5238095238095237,
#  'We are excited to roll out more of what they’ve been working on soon.': 0.2698412698412698,
#  'As we expand access to our new AI services, we continue to make meaningful investments in support of our AI efforts.': 3.222222222222222,
#  'We remain committed to durably re-engineering our cost base in order to help create capacity for these investments, in support of long-term, sustainable financial value.': 1.3015873015873014,
#  'Across Alphabet, teams are looking at ways to operate as effectively as possible, focused on their biggest priorities.': 1.2698412698412695,
#  'Turning next to YouTube, which saw solid momentum in both its ads and subscription businesses in Q3.': 1.2857142857142856,
#  'NFL Sunday Ticket is now live and receiving excellent reviews.': 0.47619047619047616,
#  'Fans love our multiview feature, which can livestream up to four games on a single screen.': 0.49206349206349204,
#  'We have heard positive feedback from our partners at the NFL about the new features and livestream reliability.': 1.0158730158730158,
#  'This is a clear example of our ability to execute big partnerships with excellence and at scale.': 0.5555555555555556,
#  'I’m really pleased with the growth and engagement on YouTube Shorts.': 1.7142857142857142,
#  'We continue to work on closing the monetization gap here.': 0.5714285714285714,
#  'Shorts now average over 70 billion daily views and are watched by over 2 billion signed-in users every month.': 1.1111111111111112,
#  'At Made On YouTube in September, we announced new tools that make it easier to create engaging content.': 1.8888888888888888,
#  'Dream Screen is an experimental feature that allows creators to add AI-generated video or image backgrounds to Shorts.': 0.7142857142857143,
#  'And YouTube Create is a new mobile app with a suite of production tools for editing Shorts, longer videos or both.': 1.4761904761904758,
#  'Next, Google Cloud.': 1.619047619047619,
#  'We see continued growth, with Q3 revenue of $8.4 billion, up 22%.': 1.968253968253968,
#  'Today, more than 60% of the world’s thousand-largest companies are Google Cloud customers.': 1.6825396825396823,
#  'At Cloud Next, we showcased amazing innovations across our entire portfolio of Infrastructure, Data and AI, Workspace Collaboration, and Cybersecurity solutions.': 2.7460317460317456,
#  'We offer advanced AI-optimized infrastructure to train and serve models at scale, and today, more than half of all funded generative AI startups are Google Cloud customers.': 3.2380952380952377,
#  'This includes AI21 Labs, Contextual, Elemental Cognition, Writer, and more.': 0.1111111111111111,
#  'We continue to provide the widest choice of accelerator options.': 0.42857142857142855,
#  'Our A3 VMs powered by NVIDIA’s H100 GPU are generally available, and we are winning customers with Cloud TPU v5e, our most cost-efficient and versatile accelerator to date.': 0.8095238095238093,
#  'On top of our infrastructure, our Vertex AI platform helps customers build, deploy and scale AI-powered applications.': 1.6666666666666665,
#  'We offer more than 100 models -- including popular third-party and open-source models, as well as tools to quickly build Search and Conversation use cases.': 1.4126984126984126,
#  'From Q2 to Q3, the number of active generative AI projects on Vertex AI grew by 7X, including Highmark Health, which is creating more personalized member materials.': 3.0317460317460307,
#  'Duet AI was created using Google’s leading large foundation models and is specially trained to help users to be more productive on Google Cloud.': 3.9841269841269833,
#  'We continue expanding its capabilities and integrating it across a wide range of Cloud products and services.': 1.2698412698412698,
#  'With Duet AI, we’re helping leading brands like PayPal and Deutsche Bank boost developer productivity.': 1.7777777777777777,
#  'And we are enabling retailers like Aritzia and Gymshark to gain new insights for better and faster business results.': 1.1904761904761905,
#  'In fact, companies are increasingly using AI for the purpose of analyzing data, and customers are choosing Google Cloud because we are the only large cloud provider with a unified platform to analyze structured and unstructured data.': 3.4761904761904754,
#  'In Workspace, thousands of companies and more than a million trusted testers have used Duet AI.': 1.3333333333333333,
#  'They are writing and refining content in Gmail and Docs, creating original images from text within Slides, organizing data in Sheets, and more.': 0.5555555555555556,
#  'These innovations enable us to provide new services and grow our base of 10 million paying customers, including enterprises like Grupo Boticario, Unilever and Warner Music.': 1.5555555555555551,
#  'We also integrated Duet AI across our cybersecurity portfolio to differentiate in the marketplace, providing generative AI-powered assistance in Mandiant Threat Intelligence, Chronicle Security Operations and Security Command Center.': 2.666666666666666,
#  'This reduces the time security teams spend writing, running and refining searches by seven times.': 0.36507936507936506,
#  'We are the only leading security provider that combines frontline intelligence and expertise, a modern security operations platform, and a trusted cloud foundation, all infused with generative AI -- helping protect customers and partners like BT, Jack Henry and Associates, and CoverMyMeds.': 2.6190476190476186,
#  'Turning to hardware.': 0.15873015873015872,
#  'We unveiled our new products this month.': 0.6507936507936509,
#  'We introduced our new Pixel 8, Pixel 8 Pro and Pixel Watch 2 to very positive consumer feedback and reviews.': 1.6825396825396828,
#  'Pixel is the fastest-growing smartphone brand in our top markets, and the only one that grew in units sold year over year.': 1.3015873015873016,
#  'Our portfolio of Pixel products are brought to life thanks to our combination of foundational technologies -- AI, Android and Google Tensor.': 2.6825396825396823,
#  'Google Tensor G3 is the third generation of our tailor-built chip.': 1.4285714285714284,
#  'It’s designed to power transformative experiences by bringing the latest in Google AI research directly to our newest phones.': 2.253968253968254,
#  'And new AI-powered editing features in Google Photos on Pixel 8 and Pixel 8 Pro remove distractions, generate the best shot from multiple images, and reduce distracting sounds in videos.': 2.4126984126984126,
#  'Pixel and our third-party ecosystem are powered by Android.': 0.38095238095238093,
#  'We just released Android 14 with more accessibility features.': 0.1111111111111111,
#  'I also want to mention Chromebooks Plus, a new category which provides the best of Chrome on great hardware, with built-in Google apps and powerful AI capabilities.': 3.5396825396825395,
#  'We also shared that Chromebooks will now get regular automatic updates for 10 years -- more than any other operating system.': 0.73015873015873,
#  'In Other Bets, Waymo is onboarding more riders to its commercial ride-hailing service as it gradually adds over 100,000 people from its San Francisco waitlist.': 0.603174603174603,
#  'Austin will follow as its next ride-hail city.': 0.25396825396825395,
#  'Wing and Walmart announced a new partnership to provide drone delivery service in the Dallas-Fort Worth area.': 1.126984126984127,
#  'Before handing over to Philipp, I want to thank our employees around the world who are working to create innovative products and provide great services to people and businesses who use our products.': 1.7777777777777777,
#  'Philipp Schindler, SVP and CBO, Google: Thanks, Sundar.': 1.7936507936507935,
#  'And hi, everyone.': 0.12698412698412698,
#  'I’ll start with our performance for the quarter and then give color into the three key priority areas for Ads -- Google AI, Retail, and YouTube -- that we’ve identified on past calls as opportunities for long-term growth in advertising.': 4.682539682539682,
#  'Google Services revenues of $68 billion were up 11% year-on-year.': 1.5079365079365077,
#  'In Google Advertising, Search & Other, revenues grew 11% year-on-year, led by solid growth in the Retail vertical.': 2.650793650793651,
#  'In YouTube Ads, revenues were up 12% year-on-year, driven by growth in both brand and direct response.': 1.73015873015873,
#  'In Network, revenues declined 3% year-on-year.': 0.1111111111111111,
#  'Google Other revenues were up 21% year-on-year, led by strong growth in YouTube subscription revenues.': 2.5079365079365075,
#  'Let’s start with Google AI.': 2.126984126984127,
#  'Recent dramatic advances in everything from foundational research models, to LLMs, to generative AI are improving our ability to deliver better performance and profitability for advertisers and more helpful, delightful experiences for users.': 1.9523809523809523,
#  'We covered many innovations last quarter after GML, like our conversational experience in Google Ads, significant updates to Performance Max and new campaign types like Demand Gen.\nAnd as Sundar said, we’re continuing to experiment with new ad formats on SGE.': 5.38095238095238,
#  'It’s extremely important to us that in this new experience, advertisers still have the opportunity to reach potential customers along their search journeys.': 1.9682539682539684,
#  'I’ll highlight more ways we’re innovating with the best of Google AI as we double-click into our core business.': 2.4126984126984126,
#  'In retail, we had a great quarter.': 0.9682539682539683,
#  'In a market where every dollar counts, our proven AI-powered solutions like Search and PMax are helping retailers drive reliable, strong ROI and meet customers wherever they are across the funnel.': 1.8571428571428572,
#  'In Q3, we also started prepping retailers for what will be a long holiday season.': 0.6984126984126982,
#  'Let me share some themes.': 0.1111111111111111,
#  'Number one - With the maximum number of days between Thanksgiving and Christmas -- and expectations for many micro-peaks beyond Cyber 5 -- we’re arming businesses with insights and planning tools, including Optiscore and Performance Planner, to uncover new opportunities, plan budgets and targets to stay competitive, and be smarter with their inventory and pricing strategy.': 2.2698412698412684,
#  'Number two - Consumer expectations are shifting, especially around price and convenience.': 0.6666666666666667,
#  'We’ve seen 4X “deals’’ queries during the holidays versus other periods.': 0.20634920634920634,
#  '75% of users say they’ll shop with those offering free shipping.': 0.2698412698412698,
#  'Retailers are capitalizing on these trends with our differentiated merchant offerings like merchant promotions and fulfillment options, and we’re making improvements to significantly boost the number of deals shown to shoppers in Search this holiday season.': 1.492063492063492,
#  'Look out for more in the coming days about new ways we’ll help shoppers browse deals across the web this year.': 1.634920634920635,
#  'Number three - No surprise, Omnichannel is the way to succeed.': 0.5396825396825395,
#  'With our suite of omni-product solutions including Local Inventory Ads, omnibidding, and PMax for Store Goals, retailers big and small are capturing demand and incremental store budgets while engaging with high-value customers.': 0.6507936507936507,
#  'Innovation continues across our shopping and merchant experiences, powered by Google AI.': 2.746031746031746,
#  'Our virtual try-on tool for apparel launched in June and has been a hit with consumers and brands.': 0.30158730158730157,
#  'Users engage with virtual try-on images at a higher rate versus regular brand-provided images.': 0.38095238095238093,
#  'Product Studio is another launch from GML getting positive feedback in pilot mode.': 0.9682539682539681,
#  'It uses the best of gen AI to help businesses create unique and tailored imagery for free that they can then scale across their channels.': 2.317460317460317,
#  'We’re seeing early merchant testers using it to “seasonalize” their content for the holidays.': 0.6190476190476191,
#  'Let’s shift to YouTube.': 0.6666666666666666,
#  'It’s worth repeating: our intense focus on creator success coupled with our multiformat strategy are at the center of how we think about YouTube’s long-term growth.': 1.8412698412698414,
#  'Shorts, Connected TV and our subscription offerings are key drivers here, and we’re investing across each to solidify YouTube’s position as the best place to create, the best place to watch and the best place to deliver results.': 2.3968253968253967,
#  'Sundar mentioned watchtime and engagement momentum on Shorts as well as our monetization progress.': 1.0952380952380951,
#  'He also covered subscription growth and NFL Sunday Ticket.': 1.4444444444444444,
#  'As for Connected TV, we continue to be the number one overall streaming destination according to Nielsen.': 1.1904761904761902,
#  '150 million+ people are watching YouTube on CTV screens every month in the U.S.': 1.0952380952380951,
#  'Whether it’s music videos, NFL Sunday Ticket, free movies, Shorts, a continuous stream of MrBeast or some other creator-led content, viewers want choice and variety and we’re giving it to them all in one place.': 1.380952380952381,
#  'And to help creators and advertisers connect with these billions of viewers across moments, screens and formats, we’re bringing Google AI to awesome new creation tools and ad solutions.': 3.6666666666666665,
#  'AI will do wonders for creation and storytelling.': 1.0476190476190474,
#  'From Dream Screen and YouTube Create -- which Sundar talked about -- to features that autodub content in multiple languages, flip and trim existing assets, remix and clip videos, and more, we’re just getting started.': 1.7936507936507935,
#  'We’re also helping brands break through at speed and scale across the funnel to drive results.': 1.1587301587301588,
#  'Spotlight Moments launched last week.': 0.30158730158730157,
#  'It uses AI to identify trending content around major cultural moments for brand sponsorship opportunities.': 1.5555555555555551,
#  'There’s Video Reach Campaigns, which are expanding to in-feed and Shorts and will be generally available in November.': 0.4603174603174603,
#  'AI is helping advertisers find as many people as possible in their ideal audience for the lowest possible price.': 1.9841269841269837,
#  'Early tests are delivering 54% more reach at 42% lower cost.': 0.5079365079365079,
#  'And then with Video View campaigns, AI is serving skippable ads across in-stream, in-feed, and Shorts and helping advertisers earn the maximum number of views at the lowest possible cost.': 2.6349206349206344,
#  'So far, they’re driving 40% more views, on average, versus in-stream alone.': 0.3492063492063492,
#  'Then for YouTube and other feed-based surfaces, there’s our new Demand Gen campaign which launched in April, rolled out worldwide last week, and was designed for the needs of today’s social marketers to engage people as they stream, scroll and connect.': 2.4444444444444438,
#  'It combines video and image ads in one campaign, with access to 3 billion users across YouTube and Google, and the ability to optimize and measure across the funnel using Google AI.': 6.142857142857142,
#  'Demand Gen is already driving success for brands like Samsung and Toyota.': 0.6190476190476188,
#  'Before I wrap, one quick highlight on our close collaboration and commitment to our most important ecosystems and partners.': 0.5555555555555556,
#  'In July, we launched Google News Showcase in the U.S., our curated online news experience and licensing program, with more than 150 news publications, 90% of which are local or regional.': 1.8888888888888888,
#  'Globally, over 2,500 news publications have signed on to News Showcase, and the product is live in 23 countries to date.': 0.7301587301587301,
#  'Our commitment to open access to news and information remains strong.': 0.5873015873015872,
#  'With that, I’ll end with a thank you to our customers and partners around the world for their continued trust and collaboration, and our Googlers everywhere for their incredible hard work and dedication.': 1.0317460317460314,
#  'Ruth, over to you.': 0.19047619047619047,
#  'Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Thank you, Philipp.': 2.6666666666666665,
#  'We are very pleased with our financial results for the third quarter, driven by meaningful growth in Search and YouTube, and momentum in Cloud.': 3.6031746031746037,
#  'My comments will be on year-over-year comparisons for the third quarter, unless I state otherwise.': 1.079365079365079,
#  'I will start with results at the Alphabet level, followed by segment results, and conclude with our outlook.': 0.6349206349206348,
#  'For the third quarter, our Consolidated Revenues were $76.7 billion, up 11% in both reported and constant currency.': 1.5555555555555554,
#  'Search remained the largest contributor to revenue growth.': 1.6984126984126986,
#  'In terms of expenses, Total Cost of Revenues was $33.2 billion, up 7%, primarily reflecting Other Cost of Revenues of $20.6 billion, which was up 6%.': 1.619047619047619,
#  'Growth here was primarily driven by Content Acquisition Costs, mainly for YouTube subscription offerings.': 1.7936507936507933,
#  'As noted in our earnings release, the overall increase in data center and other operations costs was partially offset by a reduction in depreciation expense due to the change in estimated useful lives we made starting in the first quarter of the year.': 2.571428571428571,
#  'Operating expenses were $22.1 billion, up 6%, reflecting the following: First, an increase in R&D expenses, driven primarily by compensation; second, an increase in G&A expenses reflecting the impact of charges related to legal matters; and finally, Sales & Marketing expenses, which were relatively flat to last year.': 2.5873015873015874,
#  'Operating income was $21.3 billion, up 25%, and our operating margin was 28%.': 0.9206349206349207,
#  'Other Income & Expense was a loss of $146 million.': 0.47619047619047616,
#  'Net income was $19.7 billion.': 0.49206349206349204,
#  'This reflects an effective tax rate of 7% in the third quarter from an IRS change related to the use of foreign tax credits which had an outsized impact on the third-quarter rate, because the change resulted in a catch-up for prior periods.': 1.8888888888888886,
#  'We delivered Free Cash Flow of $22.6 billion in the third quarter and $78 billion for the trailing 12 months.': 2.174603174603175,
#  'We ended the quarter with $120 billion in cash and marketable securities.': 1.238095238095238,
#  'As a reminder, our cash balance and free cash flow in the second and third quarters benefited from the deferral of certain tax payments to the fourth quarter of 2023.': 2.0952380952380953,
#  'As noted in our earnings release, on October 16 we made an estimated tax payment of $10.5 billion related to this deferral, which will be reflected in our cash balance and free cash flow in the fourth quarter.': 2.3015873015873014,
#  'Turning to segment results, within Google Services, Revenues were $68 billion, up 11%.': 1.73015873015873,
#  'Google Search and Other advertising revenues of $44 billion in the quarter were up 11%, led again by growth in retail.': 3.6190476190476195,
#  'YouTube advertising revenues of $8 billion, were up 12% driven by both brand advertising and direct response.': 2.079365079365079,
#  'Network advertising revenues of $7.7 billion were down 3%.': 0.7142857142857142,
#  'Other Revenues were $8.3 billion, up 21%, primarily reflecting growth in YouTube non-advertising revenues, driven by subscriber growth in YouTube TV, followed by YouTube Music Premium.': 3.9365079365079367,
#  'Google Services Operating Income was $23.9 billion, up 27%, and the operating margin was 35%.': 1.8888888888888886,
#  'Turning to the Google Cloud segment, revenues were $8.4 billion for the quarter, up 22%.': 2.6825396825396823,
#  'GCP revenue growth remained strong across geographies, industries and products, although the Q3 year-on-year growth rate reflects the impact of customer optimization efforts.': 3.1428571428571423,
#  'Google Workspace also delivered strong revenue growth, primarily driven by increases in average revenue per seat.': 3.603174603174603,
#  'Google Cloud had Operating Income of $266 million, and the operating margin was 3%.': 2.0634920634920633,
#  'As to our Other Bets, for the third quarter, revenues were $297 million and the operating loss was $1.2 billion.': 1.6984126984126982,
#  'Turning to our outlook for the business, with respect to Google Services.': 1.4126984126984126,
#  'First, within Advertising, after a period of historic volatility, we were pleased with the year-on-year revenue growth of Search and YouTube advertising in the third quarter.': 4.238095238095238,
#  'Second, within Other Revenues, in our YouTube subscription products, the substantial growth in revenues primarily reflects subscriber growth.': 2.4444444444444446,
#  'Looking ahead, a full quarter of NFL Sunday Ticket revenues, as well as associated content acquisition costs, will be reflected in Q4 results, compared to only a few weeks in the third quarter.': 3.095238095238095,
#  'Play had solid growth in the third quarter, driven primarily by an increase in the number of buyers.': 2.26984126984127,
#  'With respect to Hardware, there is a headwind to revenues in the fourth quarter, reflecting efforts to optimize the portfolio with tighter targeting of our go-to-market investments, as well as the ongoing impact from the difference in launch timing for the Pixel 6a and 7a that we mentioned last quarter.': 3.19047619047619,
#  'Turning to Google Cloud, we are pleased with the ongoing customer engagement with GCP and Workspace, and the potential benefit of our AI solutions -- including infrastructure and services such as VertexAI and Duet.': 3.8571428571428563,
#  'We continue to invest aggressively, given the significant potential we see, while remaining focused on profitable growth.': 1.587301587301587,
#  'In terms of expenses and profitability, we’re pleased with our operating performance.': 0.5238095238095237,
#  'As we have repeatedly stressed, we remain focused on durably re-engineering our cost base to create investment capacity to support our growth priorities, most important of which is with AI.': 2.952380952380952,
#  'We have a number of workstreams in place:\n\nFirst, we are maintaining a slower pace of headcount growth, reflecting product prioritization and reallocation of talent to support our most important growth opportunities.': 2.7777777777777777,
#  'Second, we remain focused on optimizing our real estate footprint, including how and where we work, to reduce our expense growth.': 1.8571428571428572,
#  'As you can see from our earnings release, we incurred $207 million in accelerated rent and depreciation in the third quarter related to these actions.': 1.6349206349206347,
#  'Third, we have engineering workstreams underway to improve productivity across Alphabet.': 1.3015873015873016,
#  'Given the magnitude of investment in our technical infrastructure, we have a superb team focused on efficiency of our operations there.': 1.2380952380952381,
#  'We are also making progress in streamlining operations across Alphabet through the use of AI.': 2.444444444444444,
#  'Finally, there are ongoing workstreams that are improving the efficiency of our spend with suppliers and vendors through our central procurement organization.': 0.5396825396825397,
#  'And to be clear, across the portfolio of Other Bets companies, we have also been working to identify opportunities to create sharper focus and to operate more efficiently and effectively.': 1.4444444444444442,
#  'With respect to sequential quarter-on-quarter trends, two further points: First, Cost of Sales in the fourth quarter will reflect both higher hardware costs given Pixel family launches, as well as increased CAC for YouTube as previously noted.': 3.158730158730158,
#  'Second, as usual, we expect Sales and Marketing expenses to be more heavily weighted to the end of the year in part to support product launches and the holiday season.': 1.5714285714285712,
#  'Finally, our reported capex in Q3 was $8 billion, driven overwhelmingly by investment in our technical infrastructure, with the largest component for servers, followed by data centers, reflecting a meaningful increase in our investments in AI compute.': 3.0634920634920637,
#  'The growth in reported cash capex in Q3 is somewhat muted due to the timing of supplier payments, which can cause variability from quarter to quarter.': 2.650793650793651,
#  'We continue to invest meaningfully in the technical infrastructure needed to support the opportunities we see in AI across Alphabet and expect elevated levels of investment, increasing in the fourth quarter of 2023 and continuing to grow in 2024.': 4.41269841269841,
#  'In closing, we remain very excited about the opportunities ahead and committed to deliver sustainable financial value.': 0.7777777777777777,
#  'Sundar, Philipp and I will now take your questions.': 0.5714285714285714,
#  'As a reminder, to ask a question you will need to press star *1 on your telephone.': 0.8571428571428571,
#  'To prevent any background noise, we ask that you please mute your line once your question has been asked.': 0.9206349206349205,
#  'And our first question comes from Brian Nowak with Morgan Stanley.': 1.0634920634920635,
#  'Your line is open.': 0.30158730158730157,
#  'Brian Nowak (Morgan Stanley): Great.': 0.3968253968253968,
#  'Thanks for taking my questions.': 0.2698412698412698,
#  'I have two.': 0.12698412698412698,
#  'The first one is somewhat of a jump ball.': 0.7142857142857142,
#  'There is somewhat of an investor debate about the incremental return on capital to Search when it comes to AI.': 1.7936507936507935,
#  'I know it’s early, but are there any examples that you’re seeing with SGE or Bard on higher utility, higher conversion rates, more engagement?': 0.9682539682539681,
#  'Just something to sort of show signal around the return that could come from these investments?': 0.6666666666666666,
#  'And the second one, Ruth, I know you have spoken a lot about durably re-engineering the cost base.': 1.4444444444444442,
#  'I think in the past you talked about how expenses could grow slower than revenue in 2024.': 1.3333333333333333,
#  'Is that sort of still the high-level way to think about it, or is that potentially changing a bit as investments are continuing?': 0.873015873015873,
#  'Thanks.': 0.19047619047619047,
#  'Sundar Pichai, CEO Alphabet and Google: Ruth, do you want to take the second part, I’ll take the first?': 3.1269841269841265,
#  'Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Sure.': 2.2698412698412698,
#  'Thanks for that, Brian.': 0.25396825396825395,
#  'Overall, that’s sort of a truism, as you know well, that looking to grow revenues at a faster rate than expenses as we’re focused on delivering sustainable financial value, and so that really takes us to the workstreams which I tried to tick through again.': 2.047619047619048,
#  'Those remain the driver.': 0.12698412698412698,
#  'They’re the real priority.': 0.09523809523809523,
#  'Those are the efforts that are going to enable us to keep expense growth as moderated as possible while supporting the investment growth that is so exciting in front of us, in particular around AI.': 3.317460317460317,
#  'Sundar Pichai, CEO Alphabet and Google: To your first part, obviously, we see AI as a foundational platform shift and are excited about the opportunities across our business.': 4.619047619047619,
#  'It starts with Search.': 0.47619047619047616,
#  'I’ve been pretty pleased with how the user feedback has been on SGE.': 0.7619047619047619,
#  'We are rolling it out to more users.': 0.047619047619047616,
#  'Through it all, we’re making sure the product works well and we are generating value for our ecosystem and that Ads transitions well.': 1.587301587301587,
#  'I think I view this as, with AI, the opportunity to evolve Search and Assistant over the next decade ahead.': 2.666666666666667,
#  'And I think as we’ve always seen, when you continue to invest and build great experiences, you can get value on the other side.': 1.396825396825397,
#  'And I do think over time there will be newer paths, just like we’ve done on YouTube.': 1.4285714285714284,
#  'I think with the AI work, there are subscription models as a possible path as well.': 2.333333333333333,
#  'Obviously, all of the AI investments we’re doing applies across Cloud, too, and I’m pretty optimistic about what’s ahead there as well.': 2.73015873015873,
#  'Thank you, both.': 0.31746031746031744,
#  'Operator: Your next question comes from Doug Anmuth with JPMorgan.': 0.9841269841269841,
#  'Doug Anmuth (JPMorgan): Thanks for taking the questions.': 0.36507936507936506,
#  'One for Sundar and one for Ruth.': 1.1111111111111112,
#  'Sundar, you talked a lot about AI.': 1.5238095238095237,
#  'I was hoping you could talk more about Gemini and how it will differentiate from other models -- some of the multimodal capabilities and what new experiences or [agents] you think it could unlock and how we should think about timing.': 1.7619047619047619,
#  'And then also just on Cloud, hoping you can talk about some of the factors there on the decel in Cloud and just what you’re seeing in terms of optimizations, and is there any sign of new workload deployments taking place?': 2.2857142857142856,
#  'Sundar Pichai, CEO Alphabet and Google: Thanks, good questions.': 2.1111111111111107,
#  'So on Gemini, obviously, it’s an effort from our combined Google DeepMind team.': 1.4603174603174605,
#  'I’m very excited at the progress there and as we’re working through getting the model ready.': 0.7619047619047619,
#  'To me, more importantly, we are just really laying the foundation of what I think of as the next-generation series of models we’ll be launching all throughout 2024.': 0.8888888888888886,
#  'The pace of innovation is extraordinarily impressive to see.': 0.38095238095238093,
#  'We are creating it from the ground up to be multimodal, highly efficient with tool and API integrations, and more importantly, laying the platform to enable future innovations as well.': 0.9365079365079365,
#  'We are developing Gemini in a way that it is going to be available at various sizes and capabilities, and we’ll be using it immediately across all our products internally as well as bringing it out to both developers and Cloud customers through Vertex.': 2.111111111111111,
#  'So I view it as a journey, and each generation is going to be better than the other.': 0.4126984126984127,
#  'And we are definitely investing, and the early results are very promising.': 0.23809523809523808,
#  'On Cloud, maybe what I would say is, overall, we have definitely started seeing customers looking to optimize spend.': 1.4285714285714286,
#  'We leaned into it to help customers, given some of the challenges they were facing, and so that was a factor.': 0.38095238095238093,
#  'But we are definitely seeing a lot of interest in AI.': 1.3650793650793651,
#  'There are many, many projects underway now.': 0.5079365079365079,
#  'Just on Vertex alone, the number of projects grew over 7X.': 0.4444444444444444,
#  'And so we see signs of stabilization, and I’m optimistic about what’s ahead.': 0.4444444444444444,
#  'Operator: Your next question comes from Eric Sheridan with Goldman Sachs.': 1.0793650793650795,
#  'Your line is now open.': 0.30158730158730157,
#  'Eric Sheridan (Goldman Sachs): Thank you very much for taking the questions.': 0.6825396825396826,
#  'Two, if I could.': 0.25396825396825395,
#  'Sundar, you guys led over a year ago starting with Performance Max, and I wanted to know if we could get your updated thoughts on how AI might impact the broader advertising industry and how you are aligning Alphabet and Google’s goals with AI and where it might take the advertising industry in the years ahead.': 5.650793650793651,
#  'That would be the first question.': 1.0158730158730158,
#  'And then about a year ago, Philipp and Ruth started talking about some of the brand advertising headwinds that YouTube was facing.': 1.746031746031746,
#  'As we start to lap those headwinds, how should we be thinking about a broad recovery in brand advertising versus elements of still headwinds that are being faced in the broader Ads spaces, specifically with YouTube?': 1.46031746031746,
#  'Thank you.': 0.31746031746031744,
#  'Philipp Schindler, SVP and CBO, Google: So maybe I take the first one.': 2.1587301587301586,
#  'We are very pleased with how Performance Max is performing.': 0.3968253968253968,
#  'It gives advertisers really a maximum performance across all inventory from one really AI-powered campaign, and it’s probably the ultimate example of AI in action across our Ads products.': 3.4444444444444446,
#  'It’s delivering excellent ROI.': 0.14285714285714285,
#  'Those using it achieve on average over 18% more conversions at a similar cost per action.': 0.5873015873015872,
#  'Since rolling it out about two years ago, we’ve continued to expand the features, give advertisers additional ways to steer how it works.': 0.5238095238095237,
#  'We have a lot of things, like account-level negative keywords, other details here.': 0.42857142857142855,
#  'We launched new lifecycle goals -- customer lifecycle goals, we called them.': 1.0,
#  'A revamped asset creation flow that really helps business adapt and scale their most successful creatives.': 0.9047619047619047,
#  'I think that’s one to watch.': 0.7142857142857142,
#  'We will also continue to build other new PMax features based on all the advertiser feedback we’re seeing.': 1.7777777777777777,
#  'So we are very, very encouraged by the progress here.': 0.15873015873015872,
#  'Overall maybe -- there was a second part to your question, a bit on what we’re hearing from the customers out there.': 1.507936507936508,
#  'Look, driving ROI and efficiency is still top of mind for many, right?': 0.873015873015873,
#  'It’s a rapidly shifting and still quite unpredictable consumer landscape out there.': 0.3968253968253968,
#  'Our AI tools are very well-received.': 0.9841269841269841,
#  'AI, gen AI are top of mind for everybody really.': 2.4920634920634916,
#  'There’s a ton of excitement, lots of questions about it.': 0.12698412698412698,
#  'Many understand the value.': 0.3333333333333333,
#  'Nearly 80% of our advertisers already use at least one AI-powered Search Ads product.': 1.4285714285714284,
#  'Yeah, we’re hearing a lot of good feedback on, number one, our Ads AI Essentials, which are really helping to unlock the power of AI and set up for durable ROI growth on the advertiser side.': 4.46031746031746,
#  'Those are products like the foundation for our data and measurement, things like Google Tag, Consent Mode and so on.': 1.7936507936507935,
#  'Obviously Search and PMax, we talked about it, and then all those gen AI products, all those different ones.': 1.9206349206349205,
#  'So there’s a whole lot of interest in those products.': 0.2857142857142857,
#  'Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Then on to your second question regarding YouTube.': 3.6349206349206344,
#  'As we said, overall, year-on-year growth in revenues was driven by both brand advertising and direct response.': 1.619047619047619,
#  'But very much to your question, yes, there was a stabilization in spending by advertisers.': 0.8253968253968254,
#  'We’re really pleased about that.': 0.47619047619047616,
#  'We’re particularly pleased about the ongoing performance in the Living Room and on Shorts.': 0.4603174603174603,
#  'And as I said, that’s both watchtime growth and monetization.': 0.7777777777777778,
#  'I would say the other thing benefiting YouTube is the retail strength we talked about with Search -- retail strength in APAC in both Search and YouTube.': 2.8730158730158726,
#  'That really began in the second quarter, continued in the third quarter, but that was another contributor.': 2.412698412698412,
#  'So quite a number of things going on.': 0.3968253968253968,
#  'Feel good about the results the team was able to deliver here.': 0.4603174603174603,
#  'Eric Sheridan (Goldman Sachs): Thank you so much.': 0.6031746031746031,
#  'Operator: Your next question comes from Lloyd Walmsley with UBS.': 0.9841269841269841,
#  'Lloyd Walmsley (UBS): Great.': 0.2857142857142857,
#  'Thanks for taking the question.': 0.8095238095238095,
#  'Two, if I can.': 0.12698412698412698,
#  'First, as we just think about the rollout of SGE across the user base, how far along is that?': 1.714285714285714,
#  'And how do you balance the product rollout and consumer uptake versus monetization in that transition?': 0.7936507936507936,
#  'And then the second one, also sort of generative AI-related, how quickly are you guys finding new ways of optimizing?': 1.7777777777777777,
#  'Whether that’s shrinking model sizes, chip efficiencies or anything else.': 0.3333333333333333,
#  'And do you think overall capital intensity of business scales up, or do you just find ways to do this more efficiently as usage scales?': 0.9047619047619047,
#  'Anything you can share there would be great.': 0.5396825396825397,
#  'Sundar Pichai, CEO Alphabet and Google: The first part about SGE, we are still in very early days in terms of how much we have rolled it out.': 2.73015873015873,
#  'But we have definitely gotten it out to enough people, both geographically, across user segments and enough to know that the product is working well.': 2.238095238095238,
#  'It improves the experience.': 0.31746031746031744,
#  'But there are areas to improve, which we are fine-tuning.': 0.12698412698412698,
#  'Our true north here is getting at the right user experience we want to, and I’m pretty comfortable seeing the trajectory.': 1.0952380952380951,
#  'And we’ve always worked through these transitions, be it from desktop to mobile or from now, mobile to an AI-enhanced experience.': 0.6190476190476191,
#  'So it’s nothing new, and I feel very comfortable that as we go through it, the strength of our teams -- both on the organic side as well as Ads side -- to drive the right experience for users including Ads will pay dividends.': 1.9206349206349205,
#  'I think we’ll continue to make improvements and make progress there.': 1.126984126984127,
#  'On your second question, at a high level, I would say all through the -- we just celebrated 25 years -- and of all the things I was proud about, when I looked at the strength of the work we’ve done across our infrastructure as a company, our technical infrastructure as a company, and various given stages at a given moment in time, when we adopted new generations of technology.': 3.825396825396826,
#  'We’ve looked at the cost of it, but then the curves, the efficiency curves we have driven on top of it, has always been phenomenal to see.': 0.9841269841269839,
#  'And I see the current moment as no different.': 0.4126984126984127,
#  'Already through this year, we are driving significant efficiencies, both in our models, in training costs and serving costs, and our ability to adapt what’s needed to the right use case.': 0.9523809523809523,
#  'And so I think we’ll do everything that is needed to make sure we have the leading AI models and infrastructure in the world, bar none.': 2.0158730158730154,
#  'And we will continue driving efficiencies from there.': 0.42857142857142855,
#  'Operator: Your next question comes from Michael Nathanson with MoffettNathanson.': 0.9682539682539681,
#  'Michael Nathanson (Moffett): Thank you.': 0.3968253968253968,
#  'I’m going to ask you guys a multi-part question on YouTube TV.': 1.3809523809523807,
#  'So, firstly, what were the broader objectives for getting Sunday Ticket?': 0.47619047619047616,
#  'How did it perform versus those objectives?': 0.1111111111111111,
#  'What lessons have you learned from having NFL Sunday Ticket?': 0.42857142857142855,
#  'How does that affect your appetite for more sports going forward?': 0.20634920634920634,
#  'Philipp Schindler: So, as Sundar said earlier, we are several weeks into our first season and we are very pleased with how it’s going.': 1.3968253968253967,
#  'I think in the broader context, you have to look at it as our overall YouTube subscription strategy.': 1.5238095238095237,
#  'The great feedback we’ve gotten so far on the YouTube experience is very, very significant.': 1.4285714285714284,
#  'People love the navigation and they love multiview.': 0.49206349206349204,
#  'They love the chats and the polls.': 0.06349206349206349,
#  'And frankly, people are very happy with the lack of latency here.': 0.36507936507936506,
#  'The number one piece of concrete feedback the team has gotten is actually that people want the ability to pick their own games for multiview, which is -- multiview is the awesome feature we started rolling out on YouTube TV that gives fans the ability to basically watch multiple streams here at once.': 2.9365079365079363,
#  'And, yeah, overall, the teams are working hard to build a fantastic experience, and we are really trying to stay focused on getting our first season right and providing the best possible experience really for fans here.': 2.8095238095238093,
#  'Operator: Your next question comes from Justin Post with Bank of America.': 1.0952380952380953,
#  'Justin Post (Bank of America): Great.': 0.3968253968253968,
#  'Thank you, a couple questions on Q4.': 0.4126984126984127,
#  'Can you provide any color on if there’s been any pause in advertising around the Middle East conflict in October?': 0.6666666666666664,
#  'Anything we should be aware of for Q4?': 0.14285714285714285,
#  'And then second, when we do think about the Sunday Ticket impact, I know you can’t give us revenues or expenses, but overall, would that be a headwind to margins in Q4 or something we should be thinking about?': 1.841269841269841,
#  'Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So look, on the first question, obviously this is a tragic, tragic -- there are no words to talk about what’s going on.': 3.634920634920635,
#  'And all of our focus has been on supporting our people there and how our products can be as helpful as possible in this very painful time, broadly.': 0.8412698412698412,
#  'And so nothing really to add.': 0.4126984126984127,
#  'And then in terms of the second question, Sunday Ticket, the only thing I tried to call out there is that clearly this is the first full quarter of Sunday Ticket that is contributing overall to the subscription revenues that we see.': 3.476190476190476,
#  'That’s in part of Other Revenues.': 0.15873015873015872,
#  'Also obviously, it is contributing to higher CAC in the fourth quarter.': 1.3650793650793651,
#  'So tried to make that really clear.': 0.603174603174603,
#  'And as we look longer term, we expect to generate an attractive return over the life of the deal.': 0.5238095238095237,
#  'We’re continuing to invest in support of this.': 0.2857142857142857,
#  'And excited about the additional opportunities that come out of it working with partners to deliver clips and other opportunities.': 0.5555555555555556,
#  'As we’ve said, we’ve heard positive feedback from our partners at the NFL about the new features and livestream reliability.': 1.1111111111111112,
#  'And this is really a clear example of our ability to execute big partnerships with excellence at scale and really leverage a lot of the extraordinary magic at YouTube and across Google.': 3.4126984126984126,
#  'And that’s what we’re excited about.': 0.12698412698412698,
#  'Justin Post (Bank of America): Great, thank you.': 0.7142857142857142,
#  'Operator: Your next question comes from Ken Gawrelski with Wells Fargo.': 0.9841269841269841,
#  'Ken Gawrelski (Wells Fargo): Thank you so much.': 0.5079365079365079,
#  'Two questions, if I may.': 0.1746031746031746,
#  'First, how do you think about the future structure of AI-driven Search capabilities?': 1.1904761904761902,
#  'Will activity remain centralized in a search bar, or will it be decentralized and present in many different applications, including on third-party applications?': 1.126984126984127,
#  'You alluded to Bard being integrated into multiple Google experiences earlier in the call.': 1.4603174603174605,
#  'And then the second question is, any update on the Chrome cookie deprecation planned to begin in 1Q ’24?': 1.1428571428571426,
#  'What have you seen so far based on your early testing of Privacy Sandbox, and what advertiser feedback have you received?': 0.857142857142857,
#  'Sundar Pichai, CEO Alphabet and Google: On your first question, look, you know, I broadly think of it as people are looking for information.': 3.7777777777777772,
#  'They’ve always looked for it in many, many different ways.': 0.5873015873015872,
#  'We’ve given the product search example.': 1.111111111111111,
#  'People can directly go to Amazon, as an example, or come to Google.': 1.6984126984126984,
#  'If you zoom back and take an information view of the world, there’s always been many different ways to get it.': 1.1111111111111112,
#  'And part of our work we do in making Search be world-class and give users what they’re looking for is so that we can get at as much of that intent as possible.': 1.5238095238095237,
#  'So I don’t see that changing.': 0.25396825396825395,
#  'With mobile, there were more ways that people could get information, but we worked hard to make Search work better in the mobile world.': 2.015873015873016,
#  'And similarly, I view with AI, there will be many ways people get information.': 1.9365079365079367,
#  'But it also offers us an opportunity in Search and in Assistant to take it to the next level and answer use cases, which we couldn’t have done before, and expand a diverse set of needs where we are a source.': 1.9841269841269835,
#  'So that’s how I see the opportunity ahead.': 0.6507936507936507,
#  'Philipp Schindler, SVP and CBO, Google: And to the second part of your question: yes, Chrome still plans to begin phasing out third-party cookies in the second half of ’24.': 2.9682539682539675,
#  'In the last several months, Chrome has really made significant progress on the Privacy Sandbox with APIs for developer testing.': 1.1587301587301586,
#  'And they are now generally available in Chrome.': 0.2222222222222222,
#  'Our Ads team is testing these APIs.': 0.25396825396825395,
#  'And as we shared back in April, the preliminary results of our interest-based ads testing showed a combination of what we call privacy-preserving signals and AI optimization actually provides positive results for businesses preparing for a cookieless future.': 1.6984126984126984,
#  'We also recently announced that in Q1 of ’24 we plan to deprecate third-party cookies for 1% of Chrome users, and this will support developers, obviously, in conducting their real-world experiments to assess the readiness and effectiveness of their products without third-party cookies.': 0.9999999999999999,
#  'And we’re overall encouraged by the ecosystem engagement on Privacy Sandbox.': 0.49206349206349204,
#  'We’ll continue to work with the industry and regulators in how these technologies can support the transition to, frankly, a more private web.': 0.8412698412698412,
#  'Operator: And our last question comes from Mark Mahaney with Evercore.': 0.9206349206349206,
#  'Mark Mahaney (Evercore ISI): Thank you.': 0.42857142857142855,
#  'Two questions, please.': 0.20634920634920634,
#  'Ruth, you talked about these elevated levels of investments in Q4 and in ’24.': 0.49206349206349204,
#  'I’m sorry, were you referring to just CapEx or CapEx and total expenses?': 0.3333333333333333,
#  'And then on the comments around stabilization in Cloud, is this something that you just started to see in the September quarter, or had you seen that starting earlier in the year?': 2.1587301587301586,
#  'And if you just started seeing it in the September quarter, would you have any thoughts on why you would have seen it, why Google Cloud would have seen it maybe later than some of the other hyperscalers?': 3.174603174603174,
#  'Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So I think what you’re referring to was my CapEx comment.': 2.777777777777778,
#  'I was trying to make the point that we are committed to meaningfully investing in CapEx, given all the opportunities we see.': 0.8412698412698413,
#  'We do continue to expect elevated levels of investment in our technical infrastructure.': 0.9365079365079365,
#  'It will be increasing in the fourth quarter.': 0.8571428571428572,
#  'And talked about some of the difference in timing, muted timing in the third quarter due to the timing of supplier payments.': 1.5396825396825398,
#  'And then tried to make it clear that we will continue to grow CapEx in 2024 -- or more specifically to your question, 2024 aggregate CapEx will be above the full year 2023.': 2.015873015873016,
#  'So that was the main one.': 0.3333333333333333,
#  'And then as it relates to Cloud, as Sundar said, what we’re really excited about is the revenue growth does reflect healthy customer adoption across the portfolio, and that’s Infrastructure, Data Analytics, it’s Security.': 3.825396825396825,
#  'And so I can’t comment on others, but we feel good about where we’re sitting here and looking forward.': 0.4603174603174603,
#  'And we’ll let you do the forecasting.': 0.07936507936507936,
#  'GCP growth in the third quarter was above the growth rate for Cloud overall, and we feel really good about the work that they’re doing there.': 3.7301587301587302,
#  'And then, of course, in addition to that is all of the contribution from Google Workspace.': 1.1746031746031746,
#  'Operator: Thank you.': 0.4603174603174603,
#  'And that concludes our question-and-answer session for today.': 0.23809523809523808,
#  'I’d like to turn the conference back over to Jim Friedland for any further remarks.': 0.5238095238095237,
#  'Jim Friedland, Director Investor Relations: Thanks, everyone, for joining us today.': 0.7142857142857142,
#  'We look forward to speaking with you again on our fourth quarter 2023 call.': 1.2698412698412698,
#  'Thank you and have a good evening.': 0.4603174603174603,
#  'Operator: Thank you, everyone.': 0.5714285714285714,
#  'This concludes today’s conference call.': 0.42857142857142855,
#  'Thank you for participating.': 0.3333333333333333,
#  'You may now disconnect.': 0.06349206349206349}

# %%
sentence_scores['And we’ll let you do the forecasting.']
# Out:
# 0.07936507936507936

# %%
sentence_scores.keys()
# Out:
# dict_keys(['For a PDF version of the transcript, please click here.', 'Thank you for standing by for the Alphabet third quarter 2023 earnings conference call.', 'At this time, all participants are in listen-only mode.', 'After the speaker presentation, there will be a question-and-answer session.', 'To ask a question during the session, you will need to press *1 on your telephone.', 'I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations.', 'Please go ahead.', 'Good afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call.', 'With us today are Sundar Pichai, Philipp Schindler and Ruth Porat.', 'Now I’ll quickly cover the Safe Harbor.', 'Some of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking.', 'Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.', 'Actual results could differ materially.', 'Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs.', 'We undertake no obligation to update any forward-looking statement.', 'During this call, we will present both GAAP and non-GAAP financial measures.', 'A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.', 'Our comments will be on year-over-year comparisons unless we state otherwise.', 'And now I’ll turn the call over to Sundar.', 'Sundar Pichai, CEO Alphabet and Google: Thank you, Jim.', 'And hello, everyone.', 'I’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.', 'Google turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.', 'Our product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google.', 'It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.', 'First, improving knowledge and learning.', 'This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.', 'We’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery.', 'We’ve also made it easier to understand and debug generated code.', 'Direct user feedback has been positive, with strong growth in adoption.', 'In August, we opened up availability to India and Japan, with more countries and languages to come.', 'As we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.', 'With generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.', 'We are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.', 'Of course, ads will continue to play an important role in this new Search experience.', 'People are finding ads helpful here, as they provide useful options to take action and connect with businesses.', 'We’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.', 'The second area we are focused on is boosting creativity and productivity.', 'Bard is particularly helpful here; it’s a direct interface to a conversa ...

# %% [markdown]
# ### Step 2: Order Sentences by Score Value
# Next, we will sort the sentences based on their calculated scores to identify which ones have the highest significance.

# %%
# Order Sentences by Score Value
sorted_sentences = sorted(sentence_scores.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_sentences
# Out:
# [('It combines video and image ads in one campaign, with access to 3 billion users across YouTube and Google, and the ability to optimize and measure across the funnel using Google AI.',
#   6.142857142857142),
#  ('Sundar, you guys led over a year ago starting with Performance Max, and I wanted to know if we could get your updated thoughts on how AI might impact the broader advertising industry and how you are aligning Alphabet and Google’s goals with AI and where it might take the advertising industry in the years ahead.',
#   5.650793650793651),
#  ('We covered many innovations last quarter after GML, like our conversational experience in Google Ads, significant updates to Performance Max and new campaign types like Demand Gen.\nAnd as Sundar said, we’re continuing to experiment with new ad formats on SGE.',
#   5.38095238095238),
#  ('I’ll start with our performance for the quarter and then give color into the three key priority areas for Ads -- Google AI, Retail, and YouTube -- that we’ve identified on past calls as opportunities for long-term growth in advertising.',
#   4.682539682539682),
#  ('Sundar Pichai, CEO Alphabet and Google: To your first part, obviously, we see AI as a foundational platform shift and are excited about the opportunities across our business.',
#   4.619047619047619),
#  ('Yeah, we’re hearing a lot of good feedback on, number one, our Ads AI Essentials, which are really helping to unlock the power of AI and set up for durable ROI growth on the advertiser side.',
#   4.46031746031746),
#  ('We continue to invest meaningfully in the technical infrastructure needed to support the opportunities we see in AI across Alphabet and expect elevated levels of investment, increasing in the fourth quarter of 2023 and continuing to grow in 2024.',
#   4.41269841269841),
#  ('First, within Advertising, after a period of historic volatility, we were pleased with the year-on-year revenue growth of Search and YouTube advertising in the third quarter.',
#   4.238095238095238),
#  ('Duet AI was created using Google’s leading large foundation models and is specially trained to help users to be more productive on Google Cloud.',
#   3.9841269841269833),
#  ('Other Revenues were $8.3 billion, up 21%, primarily reflecting growth in YouTube non-advertising revenues, driven by subscriber growth in YouTube TV, followed by YouTube Music Premium.',
#   3.9365079365079367),
#  ('Google turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about.',
#   3.8571428571428568),
#  ('Turning to Google Cloud, we are pleased with the ongoing customer engagement with GCP and Workspace, and the potential benefit of our AI solutions -- including infrastructure and services such as VertexAI and Duet.',
#   3.8571428571428563),
#  ('On your second question, at a high level, I would say all through the -- we just celebrated 25 years -- and of all the things I was proud about, when I looked at the strength of the work we’ve done across our infrastructure as a company, our technical infrastructure as a company, and various given stages at a given moment in time, when we adopted new generations of technology.',
#   3.825396825396826),
#  ('And then as it relates to Cloud, as Sundar said, what we’re really excited about is the revenue growth does reflect healthy customer adoption across the portfolio, and that’s Infrastructure, Data Analytics, it’s Security.',
#   3.825396825396825),
#  ('Sundar Pichai, CEO Alphabet and Google: On your first question, look, you know, I broadly think of it as people are looking for information.',
#   3.7777777777777772),
#  ('GCP growth in the third quarter was above the growth rate for Cloud overall, and we feel really good about the work that they’re doing there.',
#   3.7301587301587302),
#  ('Our product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google.',
#   3.6825396825396823),
#  ('And to help creators and advertisers connect with these billions of viewers across moments, screens and formats, we’re bringing Google AI to awesome new creation tools and ad solutions.',
#   3.6666666666666665),
#  ('Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So look, on the first question, obviously this is a tragic, tragic -- there are no words to talk about what’s going on.',
#   3.634920634920635),
#  ('Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Then on to your second question regarding YouTube.',
#   3.6349206349206344),
#  ('Google Search and Other advertising revenues of $44 billion in the quarter were up 11%, led again by growth in retail.',
#   3.6190476190476195),
#  ('We are very pleased with our financial results for the third quarter, driven by meaningful growth in Search and YouTube, and momentum in Cloud.',
#   3.6031746031746037),
#  ('Google Workspace also delivered strong revenue growth, primarily driven by increases in average revenue per seat.',
#   3.603174603174603),
#  ('I also want to mention Chromebooks Plus, a new category which provides the best of Chrome on great hardware, with built-in Google apps and powerful AI capabilities.',
#   3.5396825396825395),
#  ('And then in terms of the second question, Sunday Ticket, the only thing I tried to call out there is that clearly this is the first full quarter of Sunday Ticket that is contributing overall to the subscription revenues that we see.',
#   3.476190476190476),
#  ('In fact, companies are increasingly using AI for the purpose of analyzing data, and customers are choosing Google Cloud because we are the only large cloud provider with a unified platform to analyze structured and unstructured data.',
#   3.4761904761904754),
#  ('Using new technology powered by Google DeepMind SynthID, images generated by Vertex AI can be watermarked in a way that is invisible to the human eye, without reducing the image quality.',
#   3.4603174603174596),
#  ('It gives advertisers really a maximum performance across all inventory from one really AI-powered campaign, and it’s probably the ultimate example of AI in action across our Ads products.',
#   3.4444444444444446),
#  ('And this is really a clear example of our ability to execute big partnerships with excellence at scale and really leverage a lot of the extraordinary magic at YouTube and across Google.',
#   3.4126984126984126),
#  ('I’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud.',
#   3.3492063492063497),
#  ('Those are the efforts that are going to enable us to keep expense growth as moderated as possible while supporting the investment growth that is so exciting in front of us, in particular around AI.',
#   3.317460317460317),
#  ('It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter.',
#   3.2698412698412698),
#  ('We offer advanced AI-optimized infrastructure to train and serve models at scale, and today, more than half of all funded generative AI startups are Google Cloud customers.',
#   3.2380952380952377),
#  ('As we expand access to our new AI services, we continue to make meaningful investments in support of our AI efforts.',
#   3.222222222222222),
#  ('With respect to Hardware, there is a headwind to revenues in the fourth quarter, reflecting efforts to optimize the portfolio with tighter targeting of our go-to-market investments, as well as the ongoing impact from the difference in launch timing for the Pixel 6a and 7a that we mentioned last quarter.',
#   3.19047619047619),
#  ('And if you just started seeing it in the September quarter, would you have any thoughts on why you would have seen it, why Google Cloud would have seen it maybe later than some of the other hyperscalers?',
#   3.174603174603174),
#  ('With respect to sequential quarter-on-quarter trends, two further points: First, Cost of Sales in the fourth quarter will reflect both higher hardware costs given Pixel family launches, as well as increased CAC for YouTube as previously noted.',
#   3.158730158730158),
#  ('GCP revenue growth remained strong across geographies, industries and products, although the Q3 year-on-year growth rate reflects the impact of customer optimization efforts.',
#   3.1428571428571423),
#  ('Sundar Pichai, CEO Alphabet and Google: Ruth, do you want to take the second part, I’ll take the first?',
#   3.1269841269841265),
#  ('Looking ahead, a full quarter of NFL Sunday Ticket revenues, as well as associated content acquisition costs, will be reflected in Q4 results, compared to only a few weeks in the third quarter.',
#   3.095238095238095),
#  ('Finally, our reported capex in Q3 was $8 billion, driven overwhelmingly by investment in our technical infrastructure, with the largest component for servers, followed by data centers, reflecting a meaningful increase in our investments in AI compute.',
#   3.0634920634920637),
#  ('From Q2 to Q3, the number of active generative AI projects on Vertex AI grew by 7X, including Highmark Health, which is creating more personalized member materials.',
#   3.0317460317460307),
#  ('Bard can now integrate with Google apps and services, showing relevant information from Workspace, Maps, YouTube, and Google Flights and hotels.',
#   3.015873015873016),
#  ('Philipp Schindler, SVP and CBO, Google: And to the second part of your question: yes, Chrome still plans to begin phasing out third-party cookies in the second half of ’24.',
#   2.9682539682539675),
#  ('This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search.',
#   2.952380952380952),
#  ('As we have repeatedly stressed, we remain focused on durably re-engineering our cost base to create investment capacity to support our growth priorities, most important of which is with AI.',
#   2.952380952380952),
#  ('For example, thousands of customers and partners are already using Google Cloud to capture the potential of AI, and we’ll share more there in a minute.',
#   2.9365079365079363),
#  ('The number one piece of concrete feedback the team has gotten is actually that people want the ability to pick their own games for multiview, which is -- multiview is the awesome feature we started rolling out on YouTube TV that gives fans the ability to basically watch multiple streams here at once.',
#   2.9365079365079363),
#  ('I would say the other thing benefiting YouTube is the retail strength we talked about with Search -- retail strength in APAC in both Search and YouTube.',
#   2.8730158730158726),
#  ('We’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey.',
#   2.841269841269841),
#  ('And, yeah, overall, the teams are working hard to build a fantastic experience, and we are really trying to stay focused on getting our first season right and providing the best possible experience really for fans here.',
#   2.8095238095238093),
#  ('Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: So I think what you’re referring to was my CapEx comment.',
#   2.777777777777778),
#  ('We have a number of workstreams in place:\n\nFirst, we are maintaining a slower pace of headcount growth, reflecting product prioritization and reallocation of talent to support our most important growth opportunities.',
#   2.7777777777777777),
#  ('With generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives.',
#   2.7619047619047614),
#  ('Innovation continues across our shopping and merchant experiences, powered by Google AI.',
#   2.746031746031746),
#  ('At Cloud Next, we showcased amazing innovations across our entire portfolio of Infrastructure, Data and AI, Workspace Collaboration, and Cybersecurity solutions.',
#   2.7460317460317456),
#  ('Obviously, all of the AI investments we’re doing applies across Cloud, too, and I’m pretty optimistic about what’s ahead there as well.',
#   2.73015873015873),
#  ('Sundar Pichai, CEO Alphabet and Google: The first part about SGE, we are still in very early days in terms of how much we have rolled it out.',
#   2.73015873015873),
#  ('Bard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early experiment and complementary experience to Google Search.',
#   2.6984126984126986),
#  ('Our portfolio of Pixel products are brought to life thanks to our combination of foundational technologies -- AI, Android and Google Tensor.',
#   2.6825396825396823),
#  ('Turning to the Google Cloud segment, revenues were $8.4 billion for the quarter, up 22%.',
#   2.6825396825396823),
#  ('I think I view this as, with AI, the opportunity to evolve Search and Assistant over the next decade ahead.',
#   2.666666666666667),
#  ('Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Thank you, Philipp.',
#   2.6666666666666665),
#  ('We also integrated Duet AI across our cybersecurity portfolio to differentiate in the marketplace, providing generative AI-powered assistance in Mandiant Threat Intelligence, Chronicle Security Operations and Security Command Center.',
#   2.666666666666666),
#  ('In Google Advertising, Search & Other, revenues grew 11% year-on-year, led by solid growth in the Retail vertical.',
#   2.650793650793651),
#  ('The growth in reported cash capex in Q3 is somewhat muted due to the timing of supplier payments, which can cause variability from quarter to quarter.',
#   2.650793650793651),
#  ('And then with Video View campaigns, AI is serving skippable ads across in-stream, in-feed, and Shorts and helping advertisers earn the maximum number of views at the lowest possible cost.',
#   2.6349206349206344),
#  ('We are the only leading security provider that combines frontline intelligence and expertise, a modern security operations platform, and a trusted cloud foundation, all infused with generative AI -- helping protect customers and partners like BT, Jack Henry and Associates, and CoverMyMeds.',
#   2.6190476190476186),
#  ('Operating expenses were $22.1 billion, up 6%, reflecting the following: First, an increase in R&D expenses, driven primarily by compensation; second, an increase in G&A expenses reflecting the impact of charges related to legal matters; and finally, Sales & Marketing expenses, which were relatively flat to last year.',
#   2.5873015873015874),
#  ('As noted in our earnings release, the overall increase in data center and other operations costs was partially offset by a reduction in depreciation expense due to the change in estimated useful lives we made starting in the first quarter of the year.',
#   2.571428571428571),
#  ('Underlying all this work is the foundational research done by our teams at Google DeepMind and Google Research.',
#   2.5238095238095237),
#  ('Google Other revenues were up 21% year-on-year, led by strong growth in YouTube subscription revenues.',
#   2.5079365079365075),
#  ('AI, gen AI are top of mind for everybody really.', 2.4920634920634916),
#  ('Second, within Other Revenues, in our YouTube subscription products, the substantial growth in revenues primarily reflects subscriber growth.',
#   2.4444444444444446),
#  ('We are also making progress in streamlining operations across Alphabet through the use of AI.',
#   2.444444444444444),
#  ('Then for YouTube and other feed-based surfaces, there’s our new Demand Gen campaign which launched in April, rolled out worldwide last week, and was designed for the needs of today’s social marketers to engage people as they stream, scroll and connect.',
#   2.4444444444444438),
#  ('And new AI-powered editing features in Google Photos on Pixel 8 and Pixel 8 Pro remove distractions, generate the best shot from multiple images, and reduce distracting sounds in videos.',
#   2.4126984126984126),
#  ('I’ll highlight more ways we’re innovating with the best of Google AI as we double-click into our core business.',
#   2.4126984126984126),
#  ('That really began in the second quarter, continued in the third quarter, but that was another contributor.',
#   2.412698412698412),
#  ('Shorts, Connected TV and our subscription offerings are key drivers here, and we’re investing across each to solidify YouTube’s position as the best place to create, the best place to watch and the best place to deliver results.',
#   2.3968253968253967),
#  ('I think with the AI work, there are subscription models as a possible path as well.',
#   2.333333333333333),
#  ('It uses the best of gen AI to help businesses create unique and tailored imagery for free that they can then scale across their channels.',
#   2.317460317460317),
#  ('As noted in our earnings release, on October 16 we made an estimated tax payment of $10.5 billion related to this deferral, which will be reflected in our cash balance and free cash flow in the fourth quarter.',
#   2.3015873015873014),
#  ('And then also just on Cloud, hoping you can talk about some of the factors there on the decel in Cloud and just what you’re seeing in terms of optimizations, and is there any sign of new workload deployments taking place?',
#   2.2857142857142856),
#  ('Play had solid growth in the third quarter, driven primarily by an increase in the number of buyers.',
#   2.26984126984127),
#  ('Ruth Porat, President and Chief Investment Officer; CFO, Alphabet and Google: Sure.',
#   2.2698412698412698),
#  ('Number one - With the maximum number of days between Thanksgiving and Christmas -- and expectations for many micro-peaks beyond Cyber 5 -- we’re arming businesses with insights and planning tools, including Optiscore and Performance Planner, to uncover new opportunities, plan budgets and targets to stay competitive, and be smarter with their inventory and pricing strategy.',
#   2.2698412698412684),
#  ('It’s designed to power transformative experiences by bringing the latest in Google AI research directly to our newest phones.',
#   2.253968253968254),
#  ('But we have definitely gotten it out to enough people, both geographically, across user segments and enough to know that the product is working well.',
#   2.238095238095238),
#  ('We delivered Free Cash Flow of $22.6 billion in the third quarter and $78 billion for the trailing 12 months.',
#   2.174603174603175),
#  ('Sundar Pichai, CEO Alphabet and Google: Thank you, Jim.',
#   2.174603174603174),
#  ('Philipp Schindler, SVP and CBO, Google: So maybe I take the first one.',
#   2.1587301587301586),
#  ('And then on the comments around stabilization in Cloud, is this something that you just started to see in the September quarter, or had you seen that starting earlier in the year?',
#   2.1587301587301586),
#  ('Let’s start with Google AI.', 2.126984126984127),
#  ('We are developing Gemini in a way that it is going to be available at various sizes and capabilities, and we’ll be using it immediately across all our products internally as well as bringing it out to both developers and Cloud customers through Vertex.',
#   2.111111111111111),
#  ('Sundar Pichai, CEO Alphabet and Google: Thanks, good questions.',
#   2.1111111111111107),
#  ('As a reminder, our cash balance and free cash flow in the second and third quarters benefited from the deferral of certain tax payments to the fourth quarter of 2023.',
#   2.0952380952380953),
#  ('YouTube advertising revenues of $8 billion, were up 12% driven by both brand advertising and direct response.',
#   2.079365079365079),
#  ('Google Cloud had Operating Income of $266 million, and the operating margin was 3%.',
#   2.0634920634920633),
#  ('Thank you for standing by for the Alphabet third quarter 2023 earnings conference call.',
#   2.047619047619048),
#  ('Overall, that’s sort of a truism, as you know well, that looking to grow revenues at a faster rate than expenses as we’re focused on delivering sustainable financial value, and so that really takes us to the workstreams which I tried to tick through again.',
#   2.047619047619048),
#  ('With mobile, there were more ways that people could get information, but we worked hard to make Search work better in the mobile world.',
#   2.015873015873016),
#  ('And then tried to make it clear that we will continue to grow CapEx in 2024 -- or more specifically to your question, 2024 aggregate CapEx will be above the full year 2023.',
#   2.015873015873016),
#  ('And so I think we’ll do everything that is needed to make sure we have the leading AI models and infrastructure in the world, bar none.',
#   2.0158730158730154),
#  ('Good afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call.',
#   1.9841269841269842),
#  ('AI is helping advertisers find as many people as possible in their ideal audience for the lowest possible price.',
#   1.9841269841269837),
#  ('But it also offers us an opportunity in Search and in Assistant to take it to the next level and answer use cases, which we couldn’t have done before, and expand a diverse set of needs where we are a source.',
#   1.9841269841269835),
#  ('It’s extremely important to us that in this new experience, advertisers still have the opportunity to reach potential customers along their search journeys.',
#   1.9682539682539684),
#  ('We see continued growth, with Q3 revenue of $8.4 billion, up 22%.',
#   1.968253968253968),
#  ('Recent dramatic advances in everything from foundational research models, to LLMs, to generative AI are improving our ability to deliver better performance and profitability for advertisers and more helpful, delightful experiences for users.',
#   1.9523809523809523),
#  ('And similarly, I view with AI, there will be many ways people get information.',
#   1.9365079365079367),
#  ('Obviously Search and PMax, we talked about it, and then all those gen AI products, all those different ones.',
#   1.9206349206349205),
#  ('So it’s nothing new, and I feel very comfortable that as we go through it, the strength of our teams -- both on the organic side as well as Ads side -- to drive the right experience for users including Ads will pay dividends.',
#   1.9206349206349205),
#  ('At Made On YouTube in September, we announced new tools that make it easier to create engaging content.',
#   1.8888888888888888),
#  ('In July, we launched Google News Showcase in the U.S., our curated online news experience and licensing program, with more than 150 news publications, 90% of which are local or regional.',
#   1.8888888888888888),
#  ('This reflects an effective tax rate of 7% in the third quarter from an IRS change related to the use of foreign tax credits which had an outsized impact on the third-quarter rate, because the change resulted in a catch-up for prior periods.',
#   1.8888888888888886),
#  ('Google Services Operating Income was $23.9 billion, up 27%, and the operating margin was 35%.',
#   1.8888888888888886),
#  ('In a market where every dollar counts, our proven AI-powered solutions like Search and PMax are helping retailers drive reliable, strong ROI and meet customers wherever they are across the funnel.',
#   1.8571428571428572),
#  ('Second, we remain focused on optimizing our real estate footprint, including how and where we work, to reduce our expense growth.',
#   1.8571428571428572),
#  ('It’s worth repeating: our intense focus on creator success coupled with our multiformat strategy are at the center of how we think about YouTube’s long-term growth.',
#   1.8412698412698414),
#  ('And then second, when we do think about the Sunday Ticket impact, I know you can’t give us revenues or expenses, but overall, would that be a headwind to margins in Q4 or something we should be thinking about?',
#   1.841269841269841),
#  ('Philipp Schindler, SVP and CBO, Google: Thanks, Sundar.',
#   1.7936507936507935),
#  ('From Dream Screen and YouTube Create -- which Sundar talked about -- to features that autodub content in multiple languages, flip and trim existing assets, remix and clip videos, and more, we’re just getting started.',
#   1.7936507936507935),
#  ('There is somewhat of an investor debate about the incremental return on capital to Search when it comes to AI.',
#   1.7936507936507935),
#  ('Those are products like the foundation for our data and measurement, things like Google Tag, Consent Mode and so on.',
#   1.7936507936507935),
#  ('Growth here was primarily driven by Content Acquisition Costs, mainly for YouTube subscription offerings.',
#   1.7936507936507933),
#  ('Earlier this month, we announced Assistant with Bard -- a personal assistant powered by generative AI.',
#   1.7777777777777777),
#  ('With Duet AI, we’re helping leading brands like PayPal and Deutsche Bank boost developer productivity.',
#   1.7777777777777777),
#  ('Before handing over to Philipp, I want to thank our employees around the world who are working to create innovative products and provide great services to people and businesses who use our products.',
#   1.7777777777777777),
#  ('We will also continue to build other new PMax features based on all the advertiser feedback we’re seeing.',
#   1.7777777777777777),
#  ('And then the second one, also sort of generative AI-related, how quickly are you guys finding new ways of optimizing?',
#   1.7777777777777777),
#  ('I was hoping you could talk more about Gemini and how it will differentiate from other models -- some of the multimodal capabilities and what new experiences or [agents] you think it could unlock and how we should think about timing.',
#   1.7619047619047619),
#  ('And then about a year ago, Philipp and Ruth started talking about some of the brand advertising headwinds that YouTube was facing.',
#   1.746031746031746),
#  ('As we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet.',
#   1.7460317460317456),
#  ('In YouTube Ads, revenues were up 12% year-on-year, driven by growth in both brand and direct response.',
#   1.73015873015873),
#  ('Turning to segment results, within Google Services, Revenues were $68 billion, up 11%.',
#   1.73015873015873),
#  ('Of course, ads will continue to play an important role in this new Search experience.',
#   1.7142857142857142),
#  ('I’m really pleased with the growth and engagement on YouTube Shorts.',
#   1.7142857142857142),
#  ('First, as we just think about the rollout of SGE across the user base, how far along is that?',
#   1.714285714285714),
#  ('Search remained the largest contributor to revenue growth.',
#   1.6984126984126986),
#  ('People can directly go to Amazon, as an example, or come to Google.',
#   1.6984126984126984),
#  ('And as we shared back in April, the preliminary results of our interest-based ads testing showed a combination of what we call privacy-preserving signals and AI optimization actually provides positive results for businesses preparing for a cookieless future.',
#   1.6984126984126984),
#  ('As to our Other Bets, for the third quarter, revenues were $297 million and the operating loss was $1.2 billion.',
#   1.6984126984126982),
#  ('We introduced our new Pixel 8, Pixel 8 Pro and Pixel Watch 2 to very positive consumer feedback and reviews.',
#   1.6825396825396828),
#  ('Today, more than 60% of the world’s thousand-largest companies are Google Cloud customers.',
#   1.6825396825396823),
#  ('On top of our infrastructure, our Vertex AI platform helps customers build, deploy and scale AI-powered applications.',
#   1.6666666666666665),
#  ('Our collaborative tools in Workspace and YouTube are also part of how we boost creativity and productivity, and they are seeing great initial traction.',
#   1.6507936507936507),
#  ('Look out for more in the coming days about new ways we’ll help shoppers browse deals across the web this year.',
#   1.634920634920635),
#  ('As you can see from our earnings release, we incurred $207 million in accelerated rent and depreciation in the third quarter related to these actions.',
#   1.6349206349206347),
#  ('Next, Google Cloud.', 1.619047619047619),
#  ('In terms of expenses, Total Cost of Revenues was $33.2 billion, up 7%, primarily reflecting Other Cost of Revenues of $20.6 billion, which was up 6%.',
#   1.619047619047619),
#  ('As we said, overall, year-on-year growth in revenues was driven by both brand advertising and direct response.',
#   1.619047619047619),
#  ('We continue to invest aggressively, given the significant potential we see, while remaining focused on profitable growth.',
#   1.587301587301587),
#  ('Through it all, we’re making sure the product works well and we are generating value for our ecosystem and that Ads transitions well.',
#   1.587301587301587),
#  ('Second, as usual, we expect Sales and Marketing expenses to be more heavily weighted to the end of the year in part to support product launches and the holiday season.',
#   1.5714285714285712),
#  ('For the third quarter, our Consolidated Revenues were $76.7 billion, up 11% in both reported and constant currency.',
#   1.5555555555555554),
#  ('These innovations enable us to provide new services and grow our base of 10 million paying customers, including enterprises like Grupo Boticario, Unilever and Warner Music.',
#   1.5555555555555551),
#  ('It uses AI to identify trending content around major cultural moments for brand sponsorship opportunities.',
#   1.5555555555555551),
#  ('And talked about some of the difference in timing, muted timing in the third quarter due to the timing of supplier payments.',
#   1.5396825396825398),
#  ('Sundar, you talked a lot about AI.', 1.5238095238095237),
#  ('I think in the broader context, you have to look at it as our overall YouTube subscription strategy.',
#   1.5238095238095237),
#  ('And part of our work we do in making Search be world-class and give users what they’re looking for is so that we can get at as much of that intent as possible.',
#   1.5238095238095237),
#  ('Overall maybe -- there was a second part to your question, a bit on what we’re hearing from the customers out there.',
#   1.507936507936508),
#  ('Google Services revenues of $68 billion were up 11% year-on-year.',
#   1.5079365079365077),
#  ('We’ve also improved the “Google it” feature.', 1.492063492063492),
#  ('Retailers are capitalizing on these trends with our differentiated merchant offerings like merchant promotions and fulfillment options, and we’re making improvements to significantly boost the number of deals shown to shoppers in Search this holiday season.',
#   1.492063492063492),
#  ('And YouTube Create is a new mobile app with a suite of production tools for editing Shorts, longer videos or both.',
#   1.4761904761904758),
#  ('So on Gemini, obviously, it’s an effort from our combined Google DeepMind team.',
#   1.4603174603174605),
#  ('You alluded to Bard being integrated into multiple Google experiences earlier in the call.',
#   1.4603174603174605),
#  ('As we start to lap those headwinds, how should we be thinking about a broad recovery in brand advertising versus elements of still headwinds that are being faced in the broader Ads spaces, specifically with YouTube?',
#   1.46031746031746),
#  ('He also covered subscription growth and NFL Sunday Ticket.',
#   1.4444444444444444),
#  ('And to be clear, across the portfolio of Other Bets companies, we have also been working to identify opportunities to create sharper focus and to operate more efficiently and effectively.',
#   1.4444444444444442),
#  ('And the second one, Ruth, I know you have spoken a lot about durably re-engineering the cost base.',
#   1.4444444444444442),
#  ('On Cloud, maybe what I would say is, overall, we have definitely started seeing customers looking to optimize spend.',
#   1.4285714285714286),
#  ('Google Tensor G3 is the third generation of our tailor-built chip.',
#   1.4285714285714284),
#  ('And I do think over time there will be newer paths, just like we’ve done on YouTube.',
#   1.4285714285714284),
#  ('Nearly 80% of our advertisers already use at least one AI-powered Search Ads product.',
#   1.4285714285714284),
#  ('The great feedback we’ve gotten so far on the YouTube experience is very, very significant.',
#   1.4285714285714284),
#  ('We offer more than 100 models -- including popular third-party and open-source models, as well as tools to quickly build Search and Conversation use cases.',
#   1.4126984126984126),
#  ('Turning to our outlook for the business, with respect to Google Services.',
#   1.4126984126984126),
#  ('And I think as we’ve always seen, when you continue to invest and build great experiences, you can get value on the other side.',
#   1.396825396825397),
#  ('Philipp Schindler: So, as Sundar said earlier, we are several weeks into our first season and we are very pleased with how it’s going.',
#   1.3968253968253967),
#  ('Whether it’s music videos, NFL Sunday Ticket, free movies, Shorts, a continuous stream of MrBeast or some other creator-led content, viewers want choice and variety and we’re giving it to them all in one place.',
#   1.380952380952381),
#  ('I’m going to ask you guys a multi-part question on YouTube TV.',
#   1.3809523809523807),
#  ('We’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery.',
#   1.3809523809523805),
#  ('But we are definitely seeing a lot of interest in AI.', 1.3650793650793651),
#  ('Also obviously, it is contributing to higher CAC in the fourth quarter.',
#   1.3650793650793651),
#  ('And fourth, we are building and deploying AI responsibly, so that everyone can benefit.',
#   1.3333333333333333),
#  ('In Workspace, thousands of companies and more than a million trusted testers have used Duet AI.',
#   1.3333333333333333),
#  ('I think in the past you talked about how expenses could grow slower than revenue in 2024.',
#   1.3333333333333333),
#  ('Direct user feedback has been positive, with strong growth in adoption.',
#   1.333333333333333),
#  ('It provides other sources to help people evaluate Bard’s responses and explore information across the web.',
#   1.3015873015873016),
#  ('Pixel is the fastest-growing smartphone brand in our top markets, and the only one that grew in units sold year over year.',
#   1.3015873015873016),
#  ('Third, we have engineering workstreams underway to improve productivity across Alphabet.',
#   1.3015873015873016),
#  ('We remain committed to durably re-engineering our cost base in order to help create capacity for these investments, in support of long-term, sustainable financial value.',
#   1.3015873015873014),
#  ('One area we are focused on is making sure people can more easily identify when they are encountering AI-generated content online.',
#   1.2857142857142856),
#  ('Turning next to YouTube, which saw solid momentum in both its ads and subscription businesses in Q3.',
#   1.2857142857142856),
#  ('We continue expanding its capabilities and integrating it across a wide range of Cloud products and services.',
#   1.2698412698412698),
#  ('We look forward to speaking with you again on our fourth quarter 2023 call.',
#   1.2698412698412698),
#  ('Across Alphabet, teams are looking at ways to operate as effectively as possible, focused on their biggest priorities.',
#   1.2698412698412695),
#  ('Given the magnitude of investment in our technical infrastructure, we have a superb team focused on efficiency of our operations there.',
#   1.2380952380952381),
#  ('We ended the quarter with $120 billion in cash and marketable securities.',
#   1.238095238095238),
#  ('And we are enabling retailers like Aritzia and Gymshark to gain new insights for better and faster business results.',
#   1.1904761904761905),
#  ('As for Connected TV, we continue to be the number one overall streaming destination according to Nielsen.',
#   1.1904761904761902),
#  ('First, how do you think about the future structure of AI-driven Search capabilities?',
#   1.1904761904761902),
#  ('And then, of course, in addition to that is all of the contribution from Google Workspace.',
#   1.1746031746031746),
#  ('We’re also helping brands break through at speed and scale across the funnel to drive results.',
#   1.1587301587301588),
#  ('In the last several months, Chrome has really made significant progress on the Privacy Sandbox with APIs for developer testing.',
#   1.1587301587301586),
#  ('And then the second question is, any update on the Chrome cookie deprecation planned to begin in 1Q ’24?',
#   1.1428571428571426),
#  ('Wing and Walmart announced a new partnership to provide drone delivery service in the Dallas-Fort Worth area.',
#   1.126984126984127),
#  ('I think we’ll continue to make improvements and make progress there.',
#   1.126984126984127),
#  ('Will activity remain centralized in a search bar, or will it be decentralized and present in many different applications, including on third-party applications?',
#   1.126984126984127),
#  ('Shorts now average over 70 billion daily views and are watched by over 2 billion signed-in users every month.',
#   1.1111111111111112),
#  ('One for Sundar and one for Ruth.', 1.1111111111111112),
#  ('As we’ve said, we’ve heard positive feedback from our partners at the NFL about the new features and livestream reliability.',
#   1.1111111111111112),
#  ('If you zoom back and take an information view of the world, there’s always been many different ways to get it.',
#   1.1111111111111112),
#  ('We’ve given the product search example.', 1.111111111111111),
#  ('Operator: Your next question comes from Justin Post with Bank of America.',
#   1.0952380952380953),
#  ('Sundar mentioned watchtime and engagement momentum on Shorts as well as our monetization progress.',
#   1.0952380952380951),
#  ('150 million+ people are watching YouTube on CTV screens every month in the U.S.',
#   1.0952380952380951),
#  ('Our true north here is getting at the right user experience we want to, and I’m pretty comfortable seeing the trajectory.',
#   1.0952380952380951),
#  ('With us today are Sundar Pichai, Philipp Schindler and Ruth Porat.',
#   1.095238095238095),
#  ('Operator: Your next question comes from Eric Sheridan with Goldman Sachs.',
#   1.0793650793650795),
#  ('My comments will be on year-over-year comparisons for the third quarter, unless I state otherwise.',
#   1.079365079365079),
#  ('And our first question comes from Brian Nowak with Morgan Stanley.',
#   1.0634920634920635),
#  ('AI will do wonders for creation and storytelling.', 1.0476190476190474),
#  ('With that, I’ll end with a thank you to our customers and partners around the world for their continued trust and collaboration, and our Googlers everywhere for their incredible hard work and dedication.',
#   1.0317460317460314),
#  ('We have heard positive feedback from our partners at the NFL about the new features and livestream reliability.',
#   1.0158730158730158),
#  ('That would be the first question.', 1.0158730158730158),
#  ('We are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered.',
#   1.0),
#  ('We launched new lifecycle goals -- customer lifecycle goals, we called them.',
#   1.0),
#  ('We also recently announced that in Q1 of ’24 we plan to deprecate third-party cookies for 1% of Chrome users, and this will support developers, obviously, in conducting their real-world experiments to assess the readiness and effectiveness of their products without third-party cookies.',
#   0.9999999999999999),
#  ('Operator: Your next question comes from Doug Anmuth with JPMorgan.',
#   0.9841269841269841),
#  ('Our AI tools are very well-received.', 0.9841269841269841),
#  ('Operator: Your next question comes from Lloyd Walmsley with UBS.',
#   0.9841269841269841),
#  ('Operator: Your next question comes from Ken Gawrelski with Wells Fargo.',
#   0.9841269841269841),
#  ('We’ve looked at the cost of it, but then the curves, the efficiency curves we have driven on top of it, has always been phenomenal to see.',
#   0.9841269841269839),
#  ('In retail, we had a great quarter.', 0.9682539682539683),
#  ('Product Studio is another launch from GML getting positive feedback in pilot mode.',
#   0.9682539682539681),
#  ('I know it’s early, but are there any examples that you’re seeing with SGE or Bard on higher utility, higher conversion rates, more engagement?',
#   0.9682539682539681),
#  ('Operator: Your next question comes from Michael Nathanson with MoffettNathanson.',
#   0.9682539682539681),
#  ('Already through this year, we are driving significant efficiencies, both in our models, in training costs and serving costs, and our ability to adapt what’s needed to the right use case.',
#   0.9523809523809523),
#  ('We are creating it from the ground up to be multimodal, highly efficient with tool and API integrations, and more importantly, laying the platform to enable future innovations as well.',
#   0.9365079365079365),
#  ('We do continue to expect elevated levels of investment in our technical infrastructure.',
#   0.9365079365079365),
#  ('Operating income was $21.3 billion, up 25%, and our operating margin was 28%.',
#   0.9206349206349207),
#  ('Operator: And our last question comes from Mark Mahaney with Evercore.',
#   0.9206349206349206),
#  ('To prevent any background noise, we ask that you please mute your line once your question has been asked.',
#   0.9206349206349205),
#  ('I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations.',
#   0.9047619047619048),
#  ('Some of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking.',
#   0.9047619047619047),
#  ('A revamped asset creation flow that really helps business adapt and scale their most successful creatives.',
#   0.9047619047619047),
#  ('And do you think overall capital intensity of business scales up, or do you just find ways to do this more efficiently as usage scales?',
#   0.9047619047619047),
#  ('To me, more importantly, we are just really laying the foundation of what I think of as the next-generation series of models we’ll be launching all throughout 2024.',
#   0.8888888888888886),
#  ('Is that sort of still the high-level way to think about it, or is that potentially changing a bit as investments are continuing?',
#   0.873015873015873),
#  ('Look, driving ROI and efficiency is still top of mind for many, right?',
#   0.873015873015873),
#  ('It will be increasing in the fourth quarter.', 0.8571428571428572),
#  ('To ask a question during the session, you will need to press *1 on your telephone.',
#   0.8571428571428571),
#  ('As a reminder, to ask a question you will need to press star *1 on your telephone.',
#   0.8571428571428571),
#  ('What have you seen so far based on your early testing of Privacy Sandbox, and what advertiser feedback have you received?',
#   0.857142857142857),
#  ('I was trying to make the point that we are committed to meaningfully investing in CapEx, given all the opportunities we see.',
#   0.8412698412698413),
#  ('And all of our focus has been on supporting our people there and how our products can be as helpful as possible in this very painful time, broadly.',
#   0.8412698412698412),
#  ('We’ll continue to work with the industry and regulators in how these technologies can support the transition to, frankly, a more private web.',
#   0.8412698412698412),
#  ('But very much to your question, yes, there was a stabilization in spending by advertisers.',
#   0.8253968253968254),
#  ('Thanks for taking the question.', 0.8095238095238095),
#  ('Our A3 VMs powered by NVIDIA’s H100 GPU are generally available, and we are winning customers with Cloud TPU v5e, our most cost-efficient and versatile accelerator to date.',
#   0.8095238095238093),
#  ('And how do you balance the product rollout and consumer uptake versus monetization in that transition?',
#   0.7936507936507936),
#  ('And as I said, that’s both watchtime growth and monetization.',
#   0.7777777777777778),
#  ('People are finding ads helpful here, as they provide useful options to take action and connect with businesses.',
#   0.7777777777777777),
#  ('In closing, we remain very excited about the opportunities ahead and committed to deliver sustainable financial value.',
#   0.7777777777777777),
#  ('I’ve been pretty pleased with how the user feedback has been on SGE.',
#   0.7619047619047619),
#  ('I’m very excited at the progress there and as we’re working through getting the model ready.',
#   0.7619047619047619),
#  ('Globally, over 2,500 news publications have signed on to News Showcase, and the product is live in 23 countries to date.',
#   0.7301587301587301),
#  ('We also shared that Chromebooks will now get regular automatic updates for 10 years -- more than any other operating system.',
#   0.73015873015873),
#  ('Dream Screen is an experimental feature that allows creators to add AI-generated video or image backgrounds to Shorts.',
#   0.7142857142857143),
#  ('Network advertising revenues of $7.7 billion were down 3%.',
#   0.7142857142857142),
#  ('The first one is somewhat of a jump ball.', 0.7142857142857142),
#  ('I think that’s one to watch.', 0.7142857142857142),
#  ('Justin Post (Bank of America): Great, thank you.', 0.7142857142857142),
#  ('Jim Friedland, Director Investor Relations: Thanks, everyone, for joining us today.',
#   0.7142857142857142),
#  ('In Q3, we also started prepping retailers for what will be a long holiday season.',
#   0.6984126984126982),
#  ('Eric Sheridan (Goldman Sachs): Thank you very much for taking the questions.',
#   0.6825396825396826),
#  ('Number two - Consumer expectations are shifting, especially around price and convenience.',
#   0.6666666666666667),
#  ('Let’s shift to YouTube.', 0.6666666666666666),
#  ('Just something to sort of show signal around the return that could come from these investments?',
#   0.6666666666666666),
#  ('Can you provide any color on if there’s been any pause in advertising around the Middle East conflict in October?',
#   0.6666666666666664),
#  ('We unveiled our new products this month.', 0.6507936507936509),
#  ('With our suite of omni-product solutions including Local Inventory Ads, omnibidding, and PMax for Store Goals, retailers big and small are capturing demand and incremental store budgets while engaging with high-value customers.',
#   0.6507936507936507),
#  ('So that’s how I see the opportunity ahead.', 0.6507936507936507),
#  ('The second area we are focused on is boosting creativity and productivity.',
#   0.6349206349206348),
#  ('I will start with results at the Alphabet level, followed by segment results, and conclude with our outlook.',
#   0.6349206349206348),
#  ('A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor.',
#   0.6349206349206347),
#  ('We’re seeing early merchant testers using it to “seasonalize” their content for the holidays.',
#   0.6190476190476191),
#  ('And we’ve always worked through these transitions, be it from desktop to mobile or from now, mobile to an AI-enhanced experience.',
#   0.6190476190476191),
#  ('Demand Gen is already driving success for brands like Samsung and Toyota.',
#   0.6190476190476188),
#  ('Eric Sheridan (Goldman Sachs): Thank you so much.', 0.6031746031746031),
#  ('In Other Bets, Waymo is onboarding more riders to its commercial ride-hailing service as it gradually adds over 100,000 people from its San Francisco waitlist.',
#   0.603174603174603),
#  ('So tried to make that really clear.', 0.603174603174603),
#  ('It combines Bard’s generative and reasoning capabilities with Assistant’s personalized help.',
#   0.5873015873015872),
#  ('Our commitment to open access to news and information remains strong.',
#   0.5873015873015872),
#  ('Those using it achieve on average over 18% more conversions at a similar cost per action.',
#   0.5873015873015872),
#  ('They’ve always looked for it in many, many different ways.',
#   0.5873015873015872),
#  ('We continue to work on closing the monetization gap here.',
#   0.5714285714285714),
#  ('Sundar, Philipp and I will now take your questions.', 0.5714285714285714),
#  ('Operator: Thank you, everyone.', 0.5714285714285714),
#  ('This is a clear example of our ability to execute big partnerships with excellence and at scale.',
#   0.5555555555555556),
#  ('They are writing and refining content in Gmail and Docs, creating original images from text within Slides, organizing data in Sheets, and more.',
#   0.5555555555555556),
#  ('Before I wrap, one quick highlight on our close collaboration and commitment to our most important ecosystems and partners.',
#   0.5555555555555556),
#  ('And excited about the additional opportunities that come out of it working with partners to deliver clips and other opportunities.',
#   0.5555555555555556),
#  ('Finally, there are ongoing workstreams that are improving the efficiency of our spend with suppliers and vendors through our central procurement organization.',
#   0.5396825396825397),
#  ('Anything you can share there would be great.', 0.5396825396825397),
#  ('Number three - No surprise, Omnichannel is the way to succeed.',
#   0.5396825396825395),
#  ('We’ve also made it easier to understand and debug generated code.',
#   0.5238095238095237),
#  ('In terms of expenses and profitability, we’re pleased with our operating performance.',
#   0.5238095238095237),
#  ('Since rolling it out about two years ago, we’ve continued to expand the features, give advertisers additional ways to steer how it works.',
#   0.5238095238095237),
#  ('And as we look longer term, we expect to generate an attractive return over the life of the deal.',
#   0.5238095238095237),
#  ('I’d like to turn the conference back over to Jim Friedland for any further remarks.',
#   0.5238095238095237),
#  ('Early tests are delivering 54% more reach at 42% lower cost.',
#   0.5079365079365079),
#  ('There are many, many projects underway now.', 0.5079365079365079),
#  ('Ken Gawrelski (Wells Fargo): Thank you so much.', 0.5079365079365079),
#  ('Fans love our multiview feature, which can livestream up to four games on a single screen.',
#   0.49206349206349204),
#  ('Net income was $19.7 billion.', 0.49206349206349204),
#  ('People love the navigation and they love multiview.', 0.49206349206349204),
#  ('And we’re overall encouraged by the ecosystem engagement on Privacy Sandbox.',
#   0.49206349206349204),
#  ('Ruth, you talked about these elevated levels of investments in Q4 and in ’24.',
#   0.49206349206349204),
#  ('And now I’ll turn the call over to Sundar.', 0.47619047619047616),
#  ('NFL Sunday Ticket is now live and receiving excellent reviews.',
#   0.47619047619047616),
#  ('Other Income & Expense was a loss of $146 million.', 0.47619047619047616),
#  ('It starts with Search.', 0.47619047619047616),
#  ('We’re really pleased about that.', 0.47619047619047616),
#  ('So, firstly, what were the broader objectives for getting Sunday Ticket?',
#   0.47619047619047616),
#  ('Third, we are enabling developers, businesses and other organizations to build their own transformative products and services.',
#   0.4603174603174603),
#  ('There’s Video Reach Campaigns, which are expanding to in-feed and Shorts and will be generally available in November.',
#   0.4603174603174603),
#  ('We’re particularly pleased about the ongoing performance in the Living Room and on Shorts.',
#   0.4603174603174603),
#  ('Feel good about the results the team was able to deliver here.',
#   0.4603174603174603),
#  ('And so I can’t comment on others, but we feel good about where we’re sitting here and looking forward.',
#   0.4603174603174603),
#  ('Operator: Thank you.', 0.4603174603174603),
#  ('Thank you and have a good evening.', 0.4603174603174603),
#  ('Just on Vertex alone, the number of projects grew over 7X.',
#   0.4444444444444444),
#  ('And so we see signs of stabilization, and I’m optimistic about what’s ahead.',
#   0.4444444444444444),
#  ('Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs.',
#   0.42857142857142855),
#  ('We continue to provide the widest choice of accelerator options.',
#   0.42857142857142855),
#  ('We have a lot of things, like account-level negative keywords, other details here.',
#   0.42857142857142855),
#  ('And we will continue driving efficiencies from there.',
#   0.42857142857142855),
#  ('What lessons have you learned from having NFL Sunday Ticket?',
#   0.42857142857142855),
#  ('Mark Mahaney (Evercore ISI): Thank you.', 0.42857142857142855),
#  ('This concludes today’s conference call.', 0.42857142857142855),
#  ('So I view it as a journey, and each generation is going to be better than the other.',
#   0.4126984126984127),
#  ('And I see the current moment as no different.', 0.4126984126984127),
#  ('Thank you, a couple questions on Q4.', 0.4126984126984127),
#  ('And so nothing really to add.', 0.4126984126984127),
#  ('First, improving knowledge and learning.', 0.3968253968253968),
#  ('Brian Nowak (Morgan Stanley): Great.', 0.3968253968253968),
#  ('We are very pleased with how Performance Max is performing.',
#   0.3968253968253968),
#  ('It’s a rapidly shifting and still quite unpredictable consumer landscape out there.',
#   0.3968253968253968),
#  ('So quite a number of things going on.', 0.3968253968253968),
#  ('Michael Nathanson (Moffett): Thank you.', 0.3968253968253968),
#  ('Justin Post (Bank of America): Great.', 0.3968253968253968),
#  ('Pixel and our third-party ecosystem are powered by Android.',
#   0.38095238095238093),
#  ('Users engage with virtual try-on images at a higher rate versus regular brand-provided images.',
#   0.38095238095238093),
#  ('The pace of innovation is extraordinarily impressive to see.',
#   0.38095238095238093),
#  ('We leaned into it to help customers, given some of the challenges they were facing, and so that was a factor.',
#   0.38095238095238093),
#  ('This reduces the time security teams spend writing, running and refining searches by seven times.',
#   0.36507936507936506),
#  ('Doug Anmuth (JPMorgan): Thanks for taking the questions.',
#   0.36507936507936506),
#  ('And frankly, people are very happy with the lack of latency here.',
#   0.36507936507936506),
#  ('So far, they’re driving 40% more views, on average, versus in-stream alone.',
#   0.3492063492063492),
#  ('Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties.',
#   0.3333333333333333),
#  ('Many understand the value.', 0.3333333333333333),
#  ('Whether that’s shrinking model sizes, chip efficiencies or anything else.',
#   0.3333333333333333),
#  ('I’m sorry, were you referring to just CapEx or CapEx and total expenses?',
#   0.3333333333333333),
#  ('So that was the main one.', 0.3333333333333333),
#  ('Thank you for participating.', 0.3333333333333333),
#  ('During this call, we will present both GAAP and non-GAAP financial measures.',
#   0.31746031746031744),
#  ('Thank you, both.', 0.31746031746031744),
#  ('Thank you.', 0.31746031746031744),
#  ('It improves the experience.', 0.31746031746031744),
#  ('You can interact with it through text, voice or images, and in the coming months, you’ll be able to opt in on Android and iOS mobile devices.',
#   0.30158730158730157),
#  ('Our virtual try-on tool for apparel launched in June and has been a hit with consumers and brands.',
#   0.30158730158730157),
#  ('Spotlight Moments launched last week.', 0.30158730158730157),
#  ('Your line is open.', 0.30158730158730157),
#  ('Your line is now open.', 0.30158730158730157),
#  ('In August, we opened up availability to India and Japan, with more countries and languages to come.',
#   0.2857142857142857),
#  ('So there’s a whole lot of interest in those products.', 0.2857142857142857),
#  ('Lloyd Walmsley (UBS): Great.', 0.2857142857142857),
#  ('We’re continuing to invest in support of this.', 0.2857142857142857),
#  ('Please go ahead.', 0.2698412698412698),
#  ('We are excited to roll out more of what they’ve been working on soon.',
#   0.2698412698412698),
#  ('75% of users say they’ll shop with those offering free shipping.',
#   0.2698412698412698),
#  ('Thanks for taking my questions.', 0.2698412698412698),
#  ('Austin will follow as its next ride-hail city.', 0.25396825396825395),
#  ('Thanks for that, Brian.', 0.25396825396825395),
#  ('Two, if I could.', 0.25396825396825395),
#  ('So I don’t see that changing.', 0.25396825396825395),
#  ('Our Ads team is testing these APIs.', 0.25396825396825395),
#  ('And we are definitely investing, and the early results are very promising.',
#   0.23809523809523808),
#  ('And that concludes our question-and-answer session for today.',
#   0.23809523809523808),
#  ('And they are now generally available in Chrome.', 0.2222222222222222),
#  ('We’ve seen 4X “deals’’ queries during the holidays versus other periods.',
#   0.20634920634920634),
#  ('How does that affect your appetite for more sports going forward?',
#   0.20634920634920634),
#  ('Two questions, please.', 0.20634920634920634),
#  ('After the speaker presentation, there will be a question-and-answer session.',
#   0.19047619047619047),
#  ('Ruth, over to you.', 0.19047619047619047),
#  ('Thanks.', 0.19047619047619047),
#  ('Actual results could differ materially.', 0.1746031746031746),
#  ('Two questions, if I may.', 0.1746031746031746),
#  ('Turning to hardware.', 0.15873015873015872),
#  ('So we are very, very encouraged by the progress here.',
#   0.15873015873015872),
#  ('That’s in part of Other Revenues.', 0.15873015873015872),
#  ('For a PDF version of the transcript, please click here.',
#   0.14285714285714285),
#  ('At this time, all participants are in listen-only mode.',
#   0.14285714285714285),
#  ('We undertake no obligation to update any forward-looking statement.',
#   0.14285714285714285),
#  ('It’s delivering excellent ROI.', 0.14285714285714285),
#  ('Anything we should be aware of for Q4?', 0.14285714285714285),
#  ('And hello, everyone.', 0.12698412698412698),
#  ('And hi, everyone.', 0.12698412698412698),
#  ('I have two.', 0.12698412698412698),
#  ('Those remain the driver.', 0.12698412698412698),
#  ('There’s a ton of excitement, lots of questions about it.',
#   0.12698412698412698),
#  ('Two, if I can.', 0.12698412698412698),
#  ('But there are areas to improve, which we are fine-tuning.',
#   0.12698412698412698),
#  ('And that’s what we’re excited about.', 0.12698412698412698),
#  ('This includes AI21 Labs, Contextual, Elemental Cognition, Writer, and more.',
#   0.1111111111111111),
#  ('We just released Android 14 with more accessibility features.',
#   0.1111111111111111),
#  ('In Network, revenues declined 3% year-on-year.', 0.1111111111111111),
#  ('Let me share some themes.', 0.1111111111111111),
#  ('How did it perform versus those objectives?', 0.1111111111111111),
#  ('Now I’ll quickly cover the Safe Harbor.', 0.09523809523809523),
#  ('Our comments will be on year-over-year comparisons unless we state otherwise.',
#   0.09523809523809523),
#  ('They’re the real priority.', 0.09523809523809523),
#  ('And we’ll let you do the forecasting.', 0.07936507936507936),
#  ('They love the chats and the polls.', 0.06349206349206349),
#  ('You may now disconnect.', 0.06349206349206349),
#  ('We are rolling it out to more users.', 0.047619047619047616)]

# %% [markdown]
# ### Step 3: Select the Best Sentences for Summary
# Finally, we will select a subset of the highest-scoring sentences to create the final summary. The number of sentences to include can be adjusted based on your requirements.

# %%
# Select the Best Sentences for Summary

# You can adjust the number of sentences to include in the summary
number_of_sentences_in_summary = 5

best_sentences = [sentence for sentence, score in sorted_sentences[:number_of_sentences_in_summary]]
final_summary = ' '.join(best_sentences)

# Display the final summary
final_summary
# Out:
# 'It combines video and image ads in one campaign, with access to 3 billion users across YouTube and Google, and the ability to optimize and measure across the funnel using Google AI. Sundar, you guys led over a year ago starting with Performance Max, and I wanted to know if we could get your updated thoughts on how AI might impact the broader advertising industry and how you are aligning Alphabet and Google’s goals with AI and where it might take the advertising industry in the years ahead. We covered many innovations last quarter after GML, like our conversational experience in Google Ads, significant updates to Performance Max and new campaign types like Demand Gen.\nAnd as Sundar said, we’re continuing to experiment with new ad formats on SGE. I’ll start with our performance for the quarter and then give color into the three key priority areas for Ads -- Google AI, Retail, and YouTube -- that we’ve identified on past calls as opportunities for long-term growth in advertising. Sundar Pichai, CEO Alphabet and Google: To your first part, obviously, we see AI as a foundational platform shift and are excited about the opportunities across our business.'

# %% [markdown]
# ## Visualizing the summary in HTML
# Visualizing the summary in HTML is a great way to present the results of your text summarization in a more readable and visually appealing format. HTML allows for customization in the presentation, such as using different styles, colors, and formatting to enhance the readability of the summary. Here's a basic approach to visualizing your summary in HTML:

# %% [markdown]
# ### Step 1: Sentence Tokenization
# First, we tokenize the original text into individual sentences. This step assumes you have your original text in the original_text variable.

# %%
# Tokenize the text into sentences
sentence_list = sent_tokenize(original_text)

# %% [markdown]
# ### Step 2: Identifying Best Sentences
# Make sure you have identified the best sentences (for instance, the sentences with the highest scores from your previous analysis).

# %%
# Assuming 'best_sentences' is a list of the top sentences from your analysis
# Example:
# best_sentences = ['sentence1', 'sentence2', ...]

# %% [markdown]
# ### Step 3: Visualizing the Summary in HTML
# Now, use HTML formatting within the Jupyter Notebook to highlight these best sentences.

# %%
text = ''
display(HTML(f'<h2>Summary</h2>'))

for sentence in sentence_list:
    # Highlight the best sentences
    if sentence in best_sentences:
        text += ' ' + f"<mark>{sentence}</mark>"
    else:
        text += ' ' + sentence

# Display the text with highlighted best sentences
display(HTML(f"""{text}"""))
# Out:
# <h2>Summary</h2>
#  For a PDF version of the transcript, please click here. Thank you for standing by for the Alphabet third quarter 2023 earnings conference call. At this time, all participants are in listen-only mode. After the speaker presentation, there will be a question-and-answer session. To ask a question during the session, you will need to press *1 on your telephone. I would now like to hand the conference over to your speaker today Jim Friedland, Director of Investor Relations. Please go ahead. Good afternoon, everyone, and welcome to Alphabet’s Third Quarter 2023 Earnings conference call. With us today are Sundar Pichai, Philipp Schindler and Ruth Porat. Now I’ll quickly cover the Safe Harbor. Some of the statements that we make today regarding our business, operations and financial performance may be considered forward-looking. Such statements are based on current expectations and assumptions that are subject to a number of risks and uncertainties. Actual results could differ materially. Please refer to our Form 10-K, including our risk factor section and our Form 10-Qs. We undertake no obligation to update any forward-looking statement. During this call, we will present both GAAP and non-GAAP financial measures. A reconciliation of non-GAAP to GAAP measures is included in today’s earnings press release, which is distributed and available to the public through our Investor Relations website located at abc.xyz/investor. Our comments will be on year-over-year comparisons unless we state otherwise. And now I’ll turn the call over to Sundar. Sundar Pichai, CEO Alphabet and Google: Thank you, Jim. And hello, everyone. I’m pleased with our business results this quarter, which demonstrate strong growth in Search and YouTube, and momentum in Cloud. Google turned 25 in September, which offered an opportunity to reflect on our progress over the last quarter century, and to look ahead to the opportunities enabled by AI we are so excited and confident about. Our product momentum continued this quarter, as you saw with Cloud Next, Made on YouTube and Made by Google. It’s all part of our focus on making AI more helpful for everyone, and we are making good progress across the four areas that we shared last quarter. First, improving knowledge and learning. This includes our work with the Search Generative Experience, which is our experiment to bring generative AI capabilities into Search. We’ve learned a lot from people trying it, and we’ve added new capabilities, like incorporating videos and images into responses and generating imagery. We’ve also made it easier to understand and debug generated code. Direct user feedback has been positive, with strong growth in adoption. In August, we opened up availability to India and Japan, with more countries and languages to come. As we add features and expand into new markets, we’re engaging with the broader ecosystem and will continue to prioritize approaches that add value for our users, send valuable traffic to publishers, and support a healthy, open Internet. With generative AI applied to Search, we can serve a wider range of information needs and answer new types of questions, including those that benefit from multiple perspectives. We are surfacing more links with SGE, and linking to a wider range of sources on the results page, creating new opportunities for content to be discovered. Of course, ads will continue to play an important role in this new Search experience. People are finding ads helpful here, as they provide useful options to take action and connect with businesses. We’ll experiment with new formats native to SGE that use generative AI to create relevant, high-quality ads, customized to every step of the search journey. The second area we are focused on is boosting creativity and productivity. Bard is particularly helpful here; it’s a direct interface to a conversational LLM, and we think of it as an early experiment and complementary experience to Google Search. Bard can now integrate w ...

# %% [markdown]
# ## Extracting texts from the Internet
# To test our text summarization algorithm with real-world data, we can apply it to [Snapchat's Third Quarter 2023 Financial Results](https://investor.snap.com/news/news-details/2023/Snap-Inc.-Announces-Third-Quarter-2023-Financial-Results/default.aspx). This involves several steps, including extracting the text from the internet, preprocessing it, and then applying your summarization algorithm. Here's how you can approach this:

# %% [markdown]
# ### Step 1: Extracting Text from the Internet
# You'll need to locate the webpage containing Snapchat's Third Quarter 2023 Financial Results. Then, use a Python library like requests and BeautifulSoup (or goose3 if the page is complex) to extract the text.

# %%
# URL of the webpage containing the financial results
url = 'https://investor.snap.com/news/news-details/2023/Snap-Inc.-Announces-Third-Quarter-2023-Financial-Results/default.aspx'

# Initialize Goose
g = Goose()

# Fetch and extract content
article = g.extract(url=url)
extracted_text = article.cleaned_text

# Print the extracted text or proceed with processing
extracted_text
# Out:
# 'Snap Inc. (NYSE: SNAP) today announced financial results for the quarter ended September 30, 2023.\n\n“Our revenue returned to positive growth in Q3, increasing 5% year-over-year and flowing through to positive adjusted EBITDA as our reprioritized cost structure demonstrated the leverage in our business model,” said Evan Spiegel, CEO. “We are focused on improving our advertising platform to drive higher return on investment for our advertising partners, and we have evolved our go-to-market efforts to better serve our partners and drive customer success.”\n\nJerry Hunter, Chief Operating Officer, has notified Snap that he will retire. Mr. Hunter joined Snap seven years ago and served an important role in building the company’s engineering and business structures. Mr. Hunter’s duties and responsibilities will be transitioned by the end of the month and he will continue to support Snap through July 1, 2024 to help ensure this transition is effective.\n\n“I am deeply grateful to Jerry for the meaningful contributions he has made over his many years at Snap,” said Evan Spiegel. “His work to improve our advertising platform, serve our community, and build a strong team has helped lay the foundation for our future growth.”\n\nSnap Inc. also announced today its board of directors has authorized a stock repurchase program of up to $500 million of its Class A common stock. Repurchases of the Class A common stock may be made from time to time, either through open market transactions (including through Rule 10b5-1 trading plans) or through privately negotiated transactions in accordance with applicable securities laws. The timing and actual number of shares repurchased will depend on a variety of factors, including stock price, trading volume, market and economic conditions, and other general business considerations. Repurchases under the program have been authorized for 12 months but the program may be modified, suspended, or terminated at any time.\n\nThe goal of the program is to utilize the company’s strong balance sheet to opportunistically offset a portion of the dilution related to the issuance of restricted stock units to employees as part of the overall compensation program designed to foster an ownership culture.\n\nRepurchases under this program will be funded from existing cash and cash equivalents. As of September 30, 2023, Snap had $3.6 billion in cash, cash equivalents, and marketable securities.\n• Revenue was $1,189 million, compared to $1,128 million in the prior year, an increase of 5% year-over-year.\n• Net loss was $368 million, compared to $360 million in the prior year.\n• Adjusted EBITDA was $40 million, compared to $73 million in the prior year.\n• Operating cash flow was $13 million, compared to $56 million in the prior year.\n• Free Cash Flow was $(61) million, compared to $18 million in the prior year.\n• Trailing twelve months operating cash flow was $207 million and trailing twelve months Free Cash Flow was $2 million.\n\nWe grew and deepened our engagement with our community:\n• DAUs were 406 million in Q3 2023, an increase of 43 million, or 12%, year-over-year.\n• Since launching My AI, our AI-powered chatbot, over 200 million people have sent over 20 billion messages, which we believe makes My AI among the most widely used AI chatbots available today.\n• We launched our new Generative AI powered feature called Dreams, which enables Snapchatters to create generative AI selfies.\n• We are seeing more creators posting content to Snapchat, with nearly three times more public Stories posted in the US compared to Q3 2022.\n\nWe are focused on accelerating and diversifying our revenue growth:\n• We returned to positive revenue growth this quarter as we continue to execute against our strategy of accelerating and diversifying our revenue growth.\n• During Q3, we implemented over 17 major machine learning ranking and optimization improvements for App, Web, and Dynamic Product Ad (DPA) optimization goals.\n• We lau ...

# %%
article.title
# Out:
# 'Snap Inc. Announces Third Quarter 2023 Financial Results'

# %%
len(extracted_text)
# Out:
# 17046

# %% [markdown]
# ### Step 2: Preprocessing the Extracted Text
# Apply the same preprocessing steps to the extracted text, such as lowercasing, tokenization, removing stop words, and possibly stemming or lemmatization.

# %%
# Preprocessing
text = extracted_text.lower()
words = word_tokenize(text)

# Remove stop words
# stop_words = set(stopwords.words('english'))
stopwords = nltk.corpus.stopwords.words('english')
filtered_words = [word for word in words if word not in stopwords]

# Optional: Stemming or Lemmatization
stemmer = PorterStemmer()
lemmatized_words = [stemmer.stem(word) for word in filtered_words]

# %% [markdown]
# ### Step 3: Applying the Summarization Algorithm
# Tokenize the text into sentences, calculate scores based on word frequency, and select the best sentences.

# %%
# Tokenize into sentences
sentences = sent_tokenize(extracted_text)

# Calculate word frequencies
freq_dist = FreqDist(lemmatized_words)

# Score each sentence
sentence_scores = {}
for sentence in sentences:
    sentence_words = word_tokenize(sentence.lower())
    sentence_scores[sentence] = sum(freq_dist.get(word, 0) for word in sentence_words)

# Sort and select top sentences for summary
sorted_sentences = sorted(sentence_scores.items(), key=lambda x: x[1], reverse=True)
number_of_sentences_in_summary = 8
best_sentences = [sentence for sentence, _ in sorted_sentences[:number_of_sentences_in_summary]]

# %% [markdown]
# ### Step 4: Visualizing the Summary
# Finally, display the summary using HTML in a Jupyter Notebook environment.

# %%
def visualize(title, sentence_list, best_sentences):
    from IPython.display import HTML
    text = ''

    display(HTML(f'<h1>Summary - {title}</h1>'))
    for sentence in sentence_list:
        if sentence in best_sentences:
            text += ' ' + str(sentence).replace(sentence, f"<mark>{sentence}</mark>")
        else:
            text += ' ' + sentence
    display(HTML(f"""{text}"""))

# Usage of the function
visualize("Snapchat's Third Quarter 2023 Financial Results", sentences, best_sentences)
# Out:
# <h1>Summary - Snapchat's Third Quarter 2023 Financial Results</h1>
#  Snap Inc. (NYSE: SNAP) today announced financial results for the quarter ended September 30, 2023. “Our revenue returned to positive growth in Q3, increasing 5% year-over-year and flowing through to positive adjusted EBITDA as our reprioritized cost structure demonstrated the leverage in our business model,” said Evan Spiegel, CEO. “We are focused on improving our advertising platform to drive higher return on investment for our advertising partners, and we have evolved our go-to-market efforts to better serve our partners and drive customer success.”
#
# Jerry Hunter, Chief Operating Officer, has notified Snap that he will retire. Mr. Hunter joined Snap seven years ago and served an important role in building the company’s engineering and business structures. Mr. Hunter’s duties and responsibilities will be transitioned by the end of the month and he will continue to support Snap through July 1, 2024 to help ensure this transition is effective. “I am deeply grateful to Jerry for the meaningful contributions he has made over his many years at Snap,” said Evan Spiegel. “His work to improve our advertising platform, serve our community, and build a strong team has helped lay the foundation for our future growth.”
#
# Snap Inc. also announced today its board of directors has authorized a stock repurchase program of up to $500 million of its Class A common stock. Repurchases of the Class A common stock may be made from time to time, either through open market transactions (including through Rule 10b5-1 trading plans) or through privately negotiated transactions in accordance with applicable securities laws. The timing and actual number of shares repurchased will depend on a variety of factors, including stock price, trading volume, market and economic conditions, and other general business considerations. Repurchases under the program have been authorized for 12 months but the program may be modified, suspended, or terminated at any time. The goal of the program is to utilize the company’s strong balance sheet to opportunistically offset a portion of the dilution related to the issuance of restricted stock units to employees as part of the overall compensation program designed to foster an ownership culture. Repurchases under this program will be funded from existing cash and cash equivalents. As of September 30, 2023, Snap had $3.6 billion in cash, cash equivalents, and marketable securities. • Revenue was $1,189 million, compared to $1,128 million in the prior year, an increase of 5% year-over-year. • Net loss was $368 million, compared to $360 million in the prior year. • Adjusted EBITDA was $40 million, compared to $73 million in the prior year. • Operating cash flow was $13 million, compared to $56 million in the prior year. • Free Cash Flow was $(61) million, compared to $18 million in the prior year. • Trailing twelve months operating cash flow was $207 million and trailing twelve months Free Cash Flow was $2 million. We grew and deepened our engagement with our community:
# • DAUs were 406 million in Q3 2023, an increase of 43 million, or 12%, year-over-year. • Since launching My AI, our AI-powered chatbot, over 200 million people have sent over 20 billion messages, which we believe makes My AI among the most widely used AI chatbots available today. • We launched our new Generative AI powered feature called Dreams, which enables Snapchatters to create generative AI selfies. • We are seeing more creators posting content to Snapchat, with nearly three times more public Stories posted in the US compared to Q3 2022. We are focused on accelerating and diversifying our revenue growth:
# • We returned to positive revenue growth this quarter as we continue to execute against our strategy of accelerating and diversifying our revenue growth. • During Q3, we implemented over 17 major machine learning ranking and optimization improvements for App, Web, and Dynamic Product Ad (DPA) optimization goals. <mark>• We launched our Total Takeover solution, which includes First Commercial, First Lens, and First Story, and lets advertisers reserve the first Commercial, Lens, or Snap Ad a Snapchatter sees.</mark> • Snapchat+, our subscription service that offers exclusive, experimental, and pre-release features, reached over 5 million subscribers in Q3 2023. • We integrated with Shopify Audiences, which enables Shopify Plus merchants to extend their reach and find new customers on Snapchat who have high intent to purchase their products. • At our 2023 Beauty Summit in September, we announced new advertising tools for beauty brands such as beauty AR Lenses and Bitmoji beauty drops. We invested in our augmented reality platform:
# • We launched the Real-Time Neural Rendering ML Model in Lens Studio, which enables developers to build AR assets from 2D images captured on a phone. • We launched Diffuse Indirect Lighting, a new Ray Tracing feature that brings a level of realism to how colors and lights reflect and glow onto other objects. • We introduced Lens Creator Rewards, a new opportunity for Snap AR creators, developers, and teams to be rewarded for building top-performing Lenses on Snapchat. • We partnered with MTV for their 2023 Video Music Awards to let the audience live cast their vote for the Best New Artist category through an innovative Snapchat Lens via Camera Kit. • For the 2023 NFL season, we partnered with the LA Rams and Disguise to deliver a sponsored Princess Cruises AR experience powered by Camera Kit in SoFi Stadium. • This summer, our AR technology enhanced music festivals across the world, including AR experiences for Lollapalooza Paris, in partnership with Live Nation. <mark>• For the 2023 FIFA Women’s World Cup, we debuted a USWNT “Team Tracker” AR Lens that used advanced AR technology, with 3D Bitmoji avatars, stats, news, fun facts, and highlights that updated in real time.</mark> As we enter Q4, we anticipate continued growth in our global community and, as a result, our financial forecast for Q4 is built on the assumption that DAU will reach 410 million to 412 million. We believe we are on the right path with our direct-response advertising platform and are focused on executing against our roadmap to deliver further improvements. That said, forward visibility of advertising demand remains limited due to several factors. First, revenue in Q4 is historically backweighted, and the revenue mix in Q4 has historically included a relatively higher share from brand advertising revenue, and brand advertising grew at a slower rate than direct-response advertising in Q3. In addition, we observed pauses in spending from a large number of primarily brand-oriented advertising campaigns immediately following the onset of the war in the Middle East, and this has been a headwind to revenue quarter-to-date. While some of these campaigns have now resumed, and the impact on our revenue has partially diminished, we continue to observe new pauses and the risk that these pauses could persist or increase in magnitude remains. Due to the unpredictable nature of war, we believe it would be imprudent to provide formal guidance for Q4. Our internal forecast assumes a revenue range of $1,320 million to $1,375 million, implying year-over-year revenue growth of approximately 2% to 6%. Within this range of revenue, we estimate that adjusted EBITDA will be between $65 million and $105 million. Snap Inc. will host a conference call to discuss the results at 2:30 p.m. Pacific / 5:30 p.m. Eastern today. The live audio webcast along with supplemental information will be accessible at investor.snap.com. A recording of the webcast will also be available following the conference call. Snap Inc. uses its websites (including snap.com and investor.snap.com) as means of disclosing material non-public information and for complying with its disclosure obligation under Regulation FD. Free Cash Flow is defined as net cash provided by (used in) operating activities, reduced by purchases of property and

# %% [markdown]
# ## Conclusion and key takeways
#
# Based on the provided key sentences from Google's earnings transcript, here are the top three conclusions or key takeaways:
#
# 1. **Integration and Optimization of Advertising Campaigns:**
#   - Google is making significant strides in integrating different types of advertisements, such as video and image ads, into unified campaigns. This integration offers advertisers access to a massive user base across platforms like YouTube and Google. Furthermore, the use of Google AI for optimizing and measuring campaign performance across the sales funnel signifies a major advancement in targeted and efficient advertising.
# 2. **Impact of AI on Advertising and Alignment with Alphabet's Goals:**
#   - AI is being viewed as a transformative force in the advertising industry. Sundar Pichai's emphasis on AI illustrates Alphabet and Google's commitment to leveraging this technology for innovation in advertising. The focus on how AI can reshape advertising strategies and its potential future impact underscores its importance as a central element in Alphabet's long-term vision and strategic alignment, particularly in enhancing advertising effectiveness and creating new opportunities.
# 3. **Ongoing Innovation and Focus on Key Priority Areas:**
#   - Google is actively experimenting with new ad formats and continuously innovating in areas like conversational experiences in Google Ads and updates to Performance Max. The identification of key priority areas – Google AI, Retail, and YouTube – indicates a clear strategy for driving long-term growth in advertising. These areas represent the forefront of Google's focus, aiming to blend technological advancement with user engagement and advertiser value.
#
# In summary, Google's approach is characterized by a deep integration of AI in advertising, continuous innovation in ad formats and campaign strategies, and a strategic focus on leveraging its platforms and AI capabilities to drive future growth in the advertising sector.

# %% [markdown]
# ## Recommendations
#
# Based on the conclusions drawn from Google's earnings transcript, here are the top three recommendations for someone considering investment:
#
# 1. **Invest in AI-Integrated Advertising Platforms:**
#   - Given the significant role of AI in transforming the advertising landscape, investing in companies that are integrating AI into their advertising platforms can be a strategic move. Look for companies, like Google, that are at the forefront of AI development and are applying these advancements to optimize advertising campaigns. These companies are likely to stay competitive and offer innovative solutions in the rapidly evolving digital advertising market.
# 2. **Focus on Companies with Diverse Advertising Channels:**
#   - Diversifying investments across companies that offer a range of advertising channels, including video, image, and conversational ad experiences, can be beneficial. This diversification aligns with the trend of integrated advertising campaigns. Companies that have a broad reach across platforms, like Google with its access to YouTube and the wider Google network, are positioned to capture a larger audience and deliver more effective advertising solutions.
# 3. **Prioritize Firms with a Strong Emphasis on Long-Term Growth Areas:**
#   - Target companies that have identified and are investing in key areas for long-term growth, such as AI, retail, and new media platforms like YouTube. These areas are likely to drive future advancements and revenue growth in the advertising sector. Firms that are not only innovating but also strategically aligning their goals with future industry trends, like Alphabet and Google, may offer more sustainable investment opportunities.
#
# In essence, an investment strategy that focuses on companies leveraging AI in advertising, offering diverse ad channels, and strategically investing in future growth areas could capitalize on the emerging trends and potential opportunities in the digital advertising space. As always, it's important to conduct thorough research and possibly consult with a financial advisor before making any investment decisions.
